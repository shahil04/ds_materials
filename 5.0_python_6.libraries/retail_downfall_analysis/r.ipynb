# %% [markdown]
# # Project: Retail Business Downfall Analysis & Recovery Dashboard
#
# Dataset: UCI Online Retail
#
# Tools: Python, Pandas, SQL, Excel, Streamlit
#
# ## 1. Understand the business problem
#
# Imagine your team has been hired as data analysts by a UK-based online retail company.
#
# The management team is concerned about business performance. They want to understand:
#
# * Why is revenue declining?
#
# * Which products and countries are underperforming?
#
# * Are customers purchasing less frequently?
#
# * Are cancellations and returns affecting revenue?
#
# * What actions can the company take to improve performance?
#
# Your task is to use the transaction data to investigate these questions and build a dashboard that helps management make data-driven decisions.
#
# Important: The sample records you shared contain unusual quantities, zero prices, missing descriptions, and missing customer IDs. These are useful examples for data-quality analysis, but they do not alone prove that the business is declining.
#
# ## 2. Dataset understanding
#
# Each row represents an invoice line item, not necessarily a complete order.
#
# |
# Column
#
# |
#
# Meaning
#
# |
# | --- | --- |
# |
#
# InvoiceNo
#
# |
#
# Invoice or transaction identifier
#
# |
# |
#
# StockCode
#
# |
#
# Product identifier
#
# |
# |
#
# Description
#
# |
#
# Product name
#
# |
# |
#
# Quantity
#
# |
#
# Number of units purchased or recorded
#
# |
# |
#
# InvoiceDate
#
# |
#
# Date and time of transaction
#
# |
# |
#
# UnitPrice
#
# |
#
# Price per unit
#
# |
# |
#
# CustomerID
#
# |
#
# Customer identifier
#
# |
# |
#
# Country
#
# |
#
# Customer's country
#
# |
#
# Create a new calculated column:
#
# Revenue = Quantity × UnitPrice
#
# For example, the first row has 80,995 units at £2.08 each. Its recorded line value is £168,469.60. However, this is an unusually large quantity and should be investigated before treating it as a normal sale.
#
#
# ## 3. Step-by-step project workflow
#
# 1. Step 1 — Understand the business
#
#    Define the problem, objectives, stakeholders, and KPIs.
#
# 2. Step 2 — Collect and inspect data
#
#    Load the full dataset and investigate its structure and quality.
#
# 3. Step 3 — Clean and prepare data
#
#    Handle missing values, duplicates, cancellations, and anomalies.
#
# 4. Step 4 — Analyze business performance
#
#    Investigate revenue, customers, products, geography, and cancellations.
#
# 5. Step 5 — Identify business problems
#
#    Find where performance has weakened and investigate possible causes.
#
# 6. Step 6 — Build a dashboard
#
#    Create an interactive Streamlit application with filters and charts.
#
# 7. Step 7 — Recommend solutions
#
#    Present evidence, practical actions, and expected business impact.
#
# ## Step 1. Define the business problem
#
# ### Business problem statement
#
# "The company wants to understand changes in its sales performance, customer purchasing behavior, and operational efficiency. The analytics team must identify measurable problems in the historical transaction data and recommend strategies to improve business performance."
#
# ### Business objectives
#
# 1. Measure overall sales and revenue trends.
#
# 2. Identify products and markets contributing to weak performance.
#
# 3. Understand customer purchasing and retention patterns.
#
# 4. Investigate cancellations, returns, and data-quality issues.
#
# 5. Recommend practical actions supported by the data.

# %% [markdown]
# ## Step 2. Load and explore the dataset using Pandas
#
# ### Business question

# %%
# data load 
import pandas as pd
df =pd.read_csv(r"C:\Users\hp\Documents\ds_materials\5.0_python_6.libraries\retail_downfall_analysis\Online Retail.csv")
df.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10384\55554837.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv(r"C:\Users\hp\Documents\ds_materials\5.0_python_6.libraries\retail_downfall_analysis\Online Retail.csv")
#   InvoiceNo StockCode                        Description  Quantity  \
# 0    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
# 1    541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 2    578841     84826     ASSTD DESIGN 3D PAPER STICKERS     12540
# 3    542504     37413                                NaN      5568
# 4    573008     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  09-12-2011 09:15       2.08     16446.0  United Kingdom
# 1  18-01-2011 10:01       1.04     12346.0  United Kingdom
# 2  25-11-2011 15:57       0.00     13256.0  United Kingdom
# ...

# %% [markdown]
# df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Inspect the dataset
print(df.shape)
df.describe(include="all")
# Out:
# (541909, 8)
#         InvoiceNo StockCode                         Description  \
# count    541909.0    541909                              540455
# unique    35663.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        918.0      2313                                2369
# mean          NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
#
#              Quantity       InvoiceDate      UnitPrice     CustomerID  \
# count   541909.000000            541909  541909.000000  406829.000000
# ...

# %%
# clean 
# Check missing values
print(df.isnull().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.head(5)
# Out:
#   InvoiceNo StockCode                        Description  Quantity  \
# 0    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
# 1    541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 2    578841     84826     ASSTD DESIGN 3D PAPER STICKERS     12540
# 3    542504     37413                                NaN      5568
# 4    573008     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  09-12-2011 09:15       2.08     16446.0  United Kingdom
# 1  18-01-2011 10:01       1.04     12346.0  United Kingdom
# 2  25-11-2011 15:57       0.00     13256.0  United Kingdom
# 3  28-01-2011 12:03       0.00         NaN  United Kingdom
# 4  27-10-2011 12:26       0.21     12901.0  United Kingdom

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df[df['StockCode']=='37413']
# Out:
#        InvoiceNo StockCode             Description  Quantity  \
# 3         542504     37413                     NaN      5568
# 7460      544296     37413  ICON MUG REVOLUTIONARY        96
# 7461      551747     37413  ICON MUG REVOLUTIONARY        96
# 11709     551998     37413  ICON MUG REVOLUTIONARY        60
# 26136     554999     37413  ICON MUG REVOLUTIONARY        30
# ...          ...       ...                     ...       ...
# 442096    572309     37413  ICON MUG REVOLUTIONARY         1
# 442097    573300     37413  ICON MUG REVOLUTIONARY         1
# 442098    573332     37413  ICON MUG REVOLUTIONARY         1
# 442099    575694     37413  ICON MUG REVOLUTIONARY         1
# 442100    580639     37413  ICON MUG REVOLUTIONARY         1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 3       28-01-2011 12:03       0.00         NaN  United Kingdom
# 7460    17-02-2011 12:47       0.39     14298.0  United Kingdom
# ...

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# 
df[df["Description"].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 56741     536554     84670         NaN        23  01-12-2010 14:35        0.0
# 264100    567207    35592T         NaN         4  19-09-2011 11:01        0.0
# 301198    538133    85018C         NaN         3  09-12-2010 15:56        0.0
# 382996    538137    62095B         NaN         2  09-12-2010 15:57        0.0
# 382997    538138     72814         NaN         2  09-12-2010 15:57        0.0
# ...          ...       ...         ...       ...               ...        ...
# 540896    561484     77081         NaN       -39  27-07-2011 13:41        0.0
# 540973    540683     84546         NaN       -45  10-01-2011 17:00        0.0
# 540974    548269     22036         NaN       -45  30-03-2011 11:35        0.0
# 541184    540987    17011A         NaN       -61  12-01-2011 16:15        0.0
# 541457    554320     16053         NaN      -102  23-05-2011 15:32        0.0
#
# ...

# %%
u_code = df["StockCode"][df["Description"].isnull()].unique()
u_code[0]
# Out:
# '84670'

# %%
s= df["StockCode"][df["Description"].isnull()].unique()[0]
s
# Out:
# '37413'

# %%
df[(df['StockCode']==s) & (df["Description"].isnull())].head()
# Out:
#   InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 3    542504     37413         NaN      5568  28-01-2011 12:03        0.0
#
#    CustomerID         Country
# 3         NaN  United Kingdom

# %%
df[(df['StockCode']==s) & (df["Description"].notnull())].head(1)
# Out:
#      InvoiceNo StockCode             Description  Quantity       InvoiceDate  \
# 7460    544296     37413  ICON MUG REVOLUTIONARY        96  17-02-2011 12:47
#
#       UnitPrice  CustomerID         Country
# 7460       0.39     14298.0  United Kingdom

# %%
p = df['Description'][(df['StockCode']==s) & (df["Description"].notnull())].head(1)
p = p.iloc[0]
p
# Out:
# 'ICON MUG REVOLUTIONARY'

# %%
p
# Out:
# 'ICON MUG REVOLUTIONARY'

# %%
df.head()
# Out:
#   InvoiceNo StockCode                        Description  Quantity  \
# 0    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
# 1    541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 2    578841     84826     ASSTD DESIGN 3D PAPER STICKERS     12540
# 3    542504     37413                                NaN      5568
# 4    573008     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  09-12-2011 09:15       2.08     16446.0  United Kingdom
# 1  18-01-2011 10:01       1.04     12346.0  United Kingdom
# 2  25-11-2011 15:57       0.00     13256.0  United Kingdom
# 3  28-01-2011 12:03       0.00         NaN  United Kingdom
# 4  27-10-2011 12:26       0.21     12901.0  United Kingdom

# %%
# Select rows where StockCode == s and Description is null, then update Description
df.loc[(df["StockCode"] == s) & (df["Description"].isnull()), "Description"]
# Out:
# 3    NaN
# Name: Description, dtype: object

# %%
# Select rows where StockCode == s and Description is null, then update Description
df.loc[(df["StockCode"] == s) & (df["Description"].isnull()), "Description"] = p

# %%
for i in u_code:
    valid_desc = df.loc[(df['StockCode'] == i) & df['Description'].notna(), 'Description']
    print(i)
    
    if valid_desc.empty:
        print(f"Skipping {i}: no valid description available")
        print('==============================================')
        continue
    
    p = valid_desc.iloc[0]
    df.loc[(df['StockCode'] == i) & df['Description'].isnull(), 'Description'] = p
    print(p)
    print('==============================================')
# Out:
# 37413
# ICON MUG REVOLUTIONARY
# ...
# 79063D
# ICON MUG REVOLUTIONARY
# ...
# 84611B
# ICON MUG REVOLUTIONARY
# ...
# POST
# ICON MUG REVOLUTIONARY
# ...
# DOT
# ICON MUG REVOLUTIONARY
# ...
# 79062D
# ICON MUG REVOLUTIONARY
# ...
# 23306
# ICON MUG REVOLUTIONARY
# ...
# 22444
# ICON MUG REVOLUTIONARY
# ...
# 79000
# MOROCCAN TEA GLASS
# ...
# 23348
# ICON MUG REVOLUTIONARY
# ...
# 16015
# ICON MUG REVOLUTIONARY
# ...
# 23084
# RABBIT NIGHT LIGHT
# ...
# 79063C
# ICON MUG REVOLUTIONARY
# ...
# 84535A
# ENGLISH ROSE NOTEBOOK A6 SIZE
# ...
# 20956
# ICON MUG REVOLUTIONARY
# ...
# 47021G
# ICON MUG REVOLUTIONARY
# ...
# 84596G
# ICON MUG REVOLUTIONARY
# ...
# 84029G
# ICON MUG REVOLUTIONARY
# ...
# 21830
# ICON MUG REVOLUTIONARY
# ...
# 21555
# ICON MUG REVOLUTIONARY
# ...
# 21484
# ICON MUG REVOLUTIONARY
# ...
# 23444
# ICON MUG REVOLUTIONARY
# ...
# 21578
# ICON MUG REVOLUTIONARY
# ...
# 84279B
# ICON MUG REVOLUTIONARY
# ...
# 85185B
# ICON MUG REVOLUTIONARY
# ...
# 10002
# ICON MUG REVOLUTIONARY
# ...
# 85032D
# ICON MUG REVOLUTIONARY
# ...
# 10080
# ICON MUG REVOLUTIONARY
# ...
# 71038
# ICON MUG REVOLUTIONARY
# ...
# 82494L
# ICON MUG REVOLUTIONARY
# ...

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description       111
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
