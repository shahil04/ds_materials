# %%
# https://www.ccbp.in/blog/articles/python-coding-questions

# %%
# Write a Python code to merge two dictionaries
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}

# Write a Python code to remove duplicates from a list
# list1 = [1, 2, 2, 3, 4, 4]

# Write a Python code to check if a string is a palindrome

# "radar" # True
# "hello"  # False


# Write a Python code to implement a simple calculator
# add ,subtract, divide,multiply

# %% [markdown]
# Getting Started with Python
# - download
# -  install
# - python3 in command prompt
# - Your First Python Program
# - Variables and Data Types
# - Basic Operators
# - comments
#     - adv
#         - Prevent Executing Code Using Comments
#         - Comments are valuable when debugging code.
#         -
#     - Single-line Comment
#     - Multi-line Comment
# - Why Use Comments?
# - We should use comments:
#
# - For future references, as comments make our code readable.
# - For debugging.
# - For code collaboration, as comments help peer developers to understand each other's code.
#
# * Basic Input/Output

# %% [markdown]
# * Python Variables
# In programming, a variable is a container (storage area) to hold data. For example,
#
# number = 10
# - Assigning values to Variables in Python
# - Changing the Value of a Variable in Python
# - Assigning multiple values to multiple variables - a, b, c = 5, 3.2,"hi"
#
# - Rules for Naming Python Variables
#     - Constant and variable names should have a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore (_). For example:
#     - Create a name that makes sense
#     - If you want to create a variable name having two words, use underscore
#     - Python is case-sensitive
# - Python Literals
#     - Literals are often used to assign values to variables or constants. For example,
#         - site_name = 'programiz.com'
#     - Python Numeric Literals
#         -  Integer Literals
#         - Floating-Point Literals
#         - Complex Literals
#     - Python String Literals
#     - Python Boolean Literals true,false
#     - Character Literals in Python 's'
#     - Special Literal in Python  value = None
#     - Collection Literals
#         - Let's see examples of four different collection literals. List, Tuple, Dict, and Set literals.
#         - list literal
#         - fruits = ["apple", "mango", "orange"]

# %%
# list literal
fruits = ["apple", "mango", "orange"] 
print(fruits)

# tuple literal
numbers = (1, 2, 3) 
print(numbers)

# dictionary literal
alphabets = {'a':'apple', 'b':'ball', 'c':'cat'} 
print(alphabets)

# set literal
vowels = {'a', 'e', 'i' , 'o', 'u'} 
print(vowels)

# %% [markdown]
# ### Python Type Conversion
# - There are two types of type conversion in Python.
#     - Implicit Conversion - automatic type conversion
#     - Explicit Conversion - manual type conversion  (int(), float(), str(), )
# - Converting integer to float 4+5.32
#
# -  Converting float to integer 5.32
# -  Converting string to integer  '123'
# -  Converting string to float '123.45'
# -  Converting string to boolean 'True'
# -  Converting boolean to string True
# -  Converting boolean to integer True
# -  Converting boolean to float True
# -  Converting list to string ['1', '2', '3']
# -  Converting list to integer [1, 2, 3]
# -  Converting list to float [1.0, 2.0, 3.
# -  Converting list to boolean [True, False, True]
#
# - Key Points to Remember
#     - Type Conversion is the conversion of an object from one data type to another data type.
#     - Implicit Type Conversion is automatically performed by the Python interpreter.
#     - Python avoids the loss of data in Implicit Type Conversion.
#     - Explicit Type Conversion is also called Type Casting, the data types of objects are converted using predefined functions by the user.
#     - In Type Casting, loss of data may occur as we enforce the object to a specific data type.

# %% [markdown]
# Your summary of basic input and output operations in Python is thorough and well-explained. Here’s a concise review with a bit more detail and additional examples for better understanding:
#
# ### Python Basic Input and Output
#
# #### Python Output
#
# - **Using `print()` Function:**
#   - The `print()` function is used to display output to the console.
#
#   ```python
#   print('Python is powerful')
#   ```
#
#   **Output:**
#   ```
#   Python is powerful
#   ```
#
# - **Syntax of `print()`:**
#   ```python
#   print(object(s), sep=separator, end=end, file=file, flush=flush)
#   ```
#   - **`object(s)`**: Values to be printed.
#   - **`sep`** (optional): Separator between multiple objects. Default is a space.
#   - **`end`** (optional): String appended after the last object. Default is a newline (`\n`).
#   - **`file`** (optional): File-like object where the output is directed. Default is `sys.stdout` (the console).
#   - **`flush`** (optional): Boolean that specifies whether to forcibly flush the stream. Default is `False`.
#
# - **Examples:**
#
#   1. **Basic Usage:**
#      ```python
#      print('Good Morning!')
#      print('It is rainy today')
#      ```
#      **Output:**
#      ```
#      Good Morning!
#      It is rainy today
#      ```
#
#   2. **Using `end` Parameter:**
#      ```python
#      print('Good Morning!', end=' ')
#      print('It is rainy today')
#      ```
#      **Output:**
#      ```
#      Good Morning! It is rainy today
#      ```
#
#   3. **Using `sep` Parameter:**
#      ```python
#      print('New Year', 2023, 'See you soon!', sep='. ')
#      ```
#      **Output:**
#      ```
#      New Year. 2023. See you soon!
#      ```
#
#   4. **Printing Variables:**
#      ```python
#      number = -10.6
#      name = "Programiz"
#
#      print(5)
#      print(number)
#      print(name)
#      ```
#      **Output:**
#      ```
#      5
#      -10.6
#      Programiz
#      ```
#
#   5. **Concatenating Strings:**
#      ```python
#      print('Programiz is ' + 'awesome.')
#      ```
#      **Output:**
#      ```
#      Programiz is awesome.
#      ```
#
#   6. **Formatted Output:**
#      ```python
#      x = 5
#      y = 10
#      print('The value of x is {} and y is {}'.format(x, y))
#      ```
#      **Output:**
#      ```
#      The value of x is 5 and y is 10
#      ```
#
#      **Note:** You can also use f-strings (formatted string literals) in Python 3.6+ for more readable formatting:
#      ```python
#      print(f'The value of x is {x} and y is {y}')
#      ```
#
# #### Python Input
#
# - **Using `input()` Function:**
#   - The `input()` function is used to take input from the user.
#
#   ```python
#   num = input('Enter a number: ')
#   print('You Entered:', num)
#   print('Data type of num:', type(num))
#   ```
#
#   **Output:**
#   ```
#   Enter a number: 10
#   You Entered: 10
#   Data type of num: <class 'str'>
#   ```
#
#   - By default, the `input()` function returns a string. To convert this input into another data type (like integer or float), you can use type conversion functions.
#
#   **Example - Converting Input to Integer:**
#   ```python
#   num = int(input('Enter a number: '))
#   print('You Entered:', num)
#   print('Data type of num:', type(num))
#   ```
#   **Output:**
#   ```
#   Enter a number: 10
#   You Entered: 10
#   Data type of num: <class 'int'>
#   ```
#
#   **Example - Converting Input to Float:**
#   ```python
#   num = float(input('Enter a number: '))
#   print('You Entered:', num)
#   print('Data type of num:', type(num))
#   ```
#   **Output:**
#   ```
#   Enter a number: 10.5
#   You Entered: 10.5
#   Data type of num: <class 'float'>
#   ```
#
# ### Summary
#
# - **Output**: Use the `print()` function for displaying output. Customize the display with parameters such as `sep`, `end`, `file`, and `flush`.
# - **Input**: Use the `input()` function to take user input. Remember that input is always a string by default, so convert it as needed for further use.
#
# Feel free to experiment with these functions to become more comfortable with handling input and output in Python!

# %% [markdown]
# Here’s a list of practice questions on Python input and output:
#
# 1. **Basic Output:** Print your name, age, and favorite hobby on separate lines.
# 2. **Custom Separator:** Take three words as input and print them in a single line separated by hyphens (`-`).
# 3. **Basic Input and Type Conversion:** Convert user input for height from centimeters to meters and print the result.
# 4. **Summation of Two Numbers:** Take two numbers as input, add them, and print the result.
# 5. **Multiplication Table:** Print the multiplication table of a number up to 10.
# 6. **Area and Perimeter of a Rectangle:** Calculate and print the area and perimeter of a rectangle from given length and width.
# 7. **String Formatting:** Print the user's first and last name in the format: "Hello, Lastname, Firstname!".
# 8. **Temperature Conversion:** Convert a temperature from Celsius to Fahrenheit and print the result.
# 9. **Simple Interest Calculation:** Calculate and print the simple interest based on principal, rate of interest, and time.
# 10. **Swapping Two Variables:** Swap the values of two variables without using a third variable.
# 11. **Distance Between Two Points:** Calculate and print the distance between two points given their coordinates.

# %% [markdown]
# ### Types of Python Operators
#
# Python offers several types of operators, each serving a unique purpose in programming. Below is a summary of the different types of Python operators:
#
# 1. **Arithmetic Operators**:
#    - Used for basic mathematical operations.
#    - **Operators**:
#      - `+` (Addition): Adds two operands.
#      - `-` (Subtraction): Subtracts the second operand from the first.
#      - `*` (Multiplication): Multiplies two operands.
#      - `/` (Division): Divides the first operand by the second.
#      - `//` (Floor Division): Divides and returns the integer part of the quotient.
#      - `%` (Modulo): Returns the remainder of the division.
#      - `**` (Exponentiation): Raises the first operand to the power of the second.
#
# 2. **Assignment Operators**:
#    - Used to assign values to variables.
#    - **Operators**:
#      - `=` (Simple Assignment): Assigns the value on the right to the variable on the left.
#      - `+=` (Addition Assignment): Adds the right operand to the left operand and assigns the result to the left operand.
#      - `-=` (Subtraction Assignment): Subtracts the right operand from the left operand and assigns the result to the left operand.
#      - `*=` (Multiplication Assignment): Multiplies the right operand with the left operand and assigns the result to the left operand.
#      - `/=` (Division Assignment): Divides the left operand by the right operand and assigns the result to the left operand.
#      - `%=` (Modulo Assignment): Takes the modulus using two operands and assigns the result to the left operand.
#      - `**=` (Exponentiation Assignment): Performs an exponential calculation on operands and assigns the result to the left operand.
#
# 3. **Comparison Operators**:
#    - Used to compare two values or variables.
#    - **Operators**:
#      - `==` (Equal to): Returns True if the operands are equal.
#      - `!=` (Not Equal to): Returns True if the operands are not equal.
#      - `>` (Greater than): Returns True if the left operand is greater than the right.
#      - `<` (Less than): Returns True if the left operand is less than the right.
#      - `>=` (Greater than or Equal to): Returns True if the left operand is greater than or equal to the right.
#      - `<=` (Less than or Equal to): Returns True if the left operand is less than or equal to the right.
#
# 4. **Logical Operators**:
#    - Used to combine conditional statements.
#    - **Operators**:
#      - `and`: Returns True if both operands are true.
#      - `or`: Returns True if at least one of the operands is true.
#      - `not`: Returns True if the operand is false.
#
# 5. **Bitwise Operators**:
#    - Operate on binary digits of integers.
#    - **Operators**:
#      - `&` (AND): Sets each bit to 1 if both bits are 1.
#      - `|` (OR): Sets each bit to 1 if one of two bits is 1.
#      - `~` (NOT): Inverts all the bits.
#      - `^` (XOR): Sets each bit to 1 if only one of the two bits is 1.
#      - `>>` (Right Shift): Shifts bits of the left operand to the right by the number of bits specified by the right operand.
#      - `<<` (Left Shift): Shifts bits of the left operand to the left by the number of bits specified by the right operand.
#
# 6. **Special Operators**:
#    - Python provides special operators for certain conditions.
#    - **Identity Operators**:
#      - `is`: Returns True if both operands refer to the same object.
#      - `is not`: Returns True if both operands do not refer to the same object.
#    - **Membership Operators**:
#      - `in`: Returns True if a value is found in the specified sequence.
#      - `not in`: Returns True if a value is not found in the specified sequence.

# %% [markdown]
# ## 10 practice questions based on the different types of Python operators:
#
# 1. **Arithmetic Operators**:
#    Write a Python program that takes two numbers as input and performs all the arithmetic operations (addition, subtraction, multiplication, division, floor division, modulo, and exponentiation) on them. Print the results.
#
# 2. **Assignment Operators**:
#    Given a variable `x = 10`, write a Python program to increment its value by 5 using an assignment operator. Then, use the appropriate assignment operators to multiply the value by 3 and finally subtract 7 from it. Print the final result.
#
# 3. **Comparison Operators**:
#    Create a Python program that asks the user to input two numbers. Use comparison operators to check if the first number is greater than, less than, or equal to the second number. Print the appropriate messages for each condition.
#
# 4. **Logical Operators**:
#    Write a Python program that takes three boolean variables `a`, `b`, and `c`. Use logical operators to check the following conditions:
#    - If `a` and `b` are True.
#    - If `a` or `b` is True.
#    - If `a` is not True.
#    Print the results of each condition.
#
# 5. **Bitwise Operators**:
#    Given two integer variables `x = 12` and `y = 5`, use bitwise operators to perform the following operations:
#    - Bitwise AND
#    - Bitwise OR
#    - Bitwise XOR
#    - Bitwise NOT on `x`
#    - Left shift `x` by 2
#    - Right shift `y` by 1
#    Print the results of each operation.
#
# 6. **Identity Operators**:
#    Write a Python program that creates two lists `list1` and `list2` with identical elements. Use the `is` and `is not` operators to check if they refer to the same object in memory. Print the results.
#
# 7. **Membership Operators**:
#    Create a Python program that checks if the character `'a'` is present in the string `"Hello, world!"`. Additionally, check if the number `3` is a key in the dictionary `{1: 'one', 2: 'two', 4: 'four'}`. Use membership operators and print the results.
#
# 8. **Combining Arithmetic and Assignment Operators**:
#    Write a Python program that takes an integer input from the user. Use arithmetic and assignment operators to double the number, subtract 10, and then take the remainder when divided by 7. Print the final result.
#
# 9. **Logical Operators with Comparison**:
#    Given two variables `age = 25` and `salary = 50000`, use logical and comparison operators to write a Python program that checks if the age is greater than 18 and the salary is at least 30,000. Print whether both conditions are met.
#
# 10. **Bitwise and Identity Operators**:
#     Write a Python program that takes an integer input from the user. Perform a bitwise right shift on the number by 2 and store the result in a new variable. Use the `is` operator to check if the original number and the new number are stored in the same memory location. Print the result.

# %% [markdown]
# * Precedence and Associativity of operators in Python
# * Python Operator Overloading

# %% [markdown]
# ### Python `if...else` Statement - Short Notes
#
# **1. Python `if` Statement:**
# - **Purpose**: The `if` statement is used to execute a block of code only when a specified condition is met.
# - **Syntax**:
#   ```python
#   if condition:
#       # body of if statement
#   ```
# - **Example**:
#   ```python
#   number = int(input('Enter a number: '))
#   if number > 0:
#       print(f'{number} is a positive number.')
#   ```
#
# **2. Indentation in Python:**
# - Python uses indentation (usually 4 spaces) to define blocks of code, such as within an `if` statement.
# - Improper indentation leads to errors.
#
# **3. Python `if...else` Statement:**
# - **Purpose**: The `else` clause allows you to execute an alternative block of code if the condition in the `if` statement evaluates to False.
# - **Syntax**:
#   ```python
#   if condition:
#       # body of if statement
#   else:
#       # body of else statement
#   ```
# - **Example**:
#   ```python
#   number = int(input('Enter a number: '))
#   if number > 0:
#       print('Positive number')
#   else:
#       print('Not a positive number')
#   ```
#
# **4. Python `if…elif…else` Statement:**
# - **Purpose**: The `if…elif…else` statement is used to evaluate multiple conditions and execute corresponding blocks of code.
# - **Syntax**:
#   ```python
#   if condition1:
#       # code block 1
#   elif condition2:
#       # code block 2
#   else:
#       # code block 3
#   ```
# - **Example**:
#   ```python
#   number = -5
#   if number > 0:
#       print('Positive number')
#   elif number < 0:
#       print('Negative number')
#   else:
#       print('Zero')
#   ```
#
# **5. Python Nested `if` Statements:**
# - **Purpose**: You can place an `if` statement inside another `if` statement to check multiple conditions in a nested manner.
# - **Example**:
#   ```python
#   number = 5
#   if number >= 0:
#       if number == 0:
#           print('Number is 0')
#       else:
#           print('Number is positive')
#   else:
#       print('Number is negative')
#   ```
#
# **6. Python Ternary Operator:**
# - **Purpose**: A shorthand way to write simple `if...else` statements.
# - **Syntax**:
#   ```python
#   result = value_if_true if condition else value_if_false
#   ```
# **Compact if Statement**
# - if number > 0: print('Positive')
#
# - # add two conditions using and operator
#   - if age >= 30 and salary >= 5000:
#
# These concepts are essential for controlling the flow of a Python program based on specific conditions.

# %% [markdown]
# ### 20 practice questions
#  based on Python's `if...else`, `if…elif…else`, nested `if`, indentation, and ternary operators:
#
# ### Basic `if` Statement:
# 1. Write a Python program to check if a number entered by the user is positive.
# 2. How does Python determine which code block to execute within an `if` statement?
# 3. Write a Python program that checks if a number is even or odd using an `if` statement.
# 4. What is the importance of indentation in Python's `if` statement?
# 5. Write an `if` statement to check if the length of a string is greater than 5.
#
# ### `if...else` Statement:
# 6. Write a program that prompts the user for a number and prints "Positive" if the number is greater than 0, otherwise prints "Negative or Zero."
# 7. Explain how the `else` clause works in an `if...else` statement with an example.
# 8. Write a Python program to check if a user-inputted number is divisible by 2. If true, print "Even," otherwise print "Odd."
# 9. What happens if the condition in the `if` statement is `False` but there is no `else` clause?
# 10. Write a program to check if a number is zero or non-zero using the `if...else` statement.
#
# ### `if...elif...else` Statement:
# 11. Write a program to categorize a number as positive, negative, or zero using the `if…elif…else` structure.
# 12. How does the `elif` clause differ from `else` in Python?
# 13. Write a Python program that asks for a student's score and prints their grade based on the following criteria:
#     - Above 90: Grade A
#     - 75-90: Grade B
#     - 50-75: Grade C
#     - Below 50: Grade D
# 14. Explain with an example when we should use `elif` instead of multiple `if` statements.
# 15. Write a Python program that takes a user’s age and prints whether they are a child, teenager, adult, or senior citizen using `if...elif...else`.
#
# ### Nested `if` Statement:
# 16. Write a Python program that checks if a number is positive, and within that check, it also checks if the number is greater than 100.
# 17. Explain how nested `if` statements work with an example.
# 18. Write a program to classify a triangle as equilateral, isosceles, or scalene using nested `if` statements.
# 19. Write a Python program using nested `if` to determine if a number is both positive and even.
# 20. How do you avoid excessive nesting in Python's `if` statements? Provide an alternative solution.
#
# These questions will help you practice writing conditional logic and understand the flow of control in Python programs.

# %% [markdown]
# ### Short Notes on Python `for` Loop
#
# #### 1. **Introduction to Python `for` Loop**
# A `for` loop in Python is used to iterate over sequences such as lists, strings, tuples, dictionaries, and sets. The loop iterates over each element of the sequence and executes the code inside the loop body for each element.
#
# **Syntax:**
# ```python
# for variable in sequence:
#     # body of the loop
# ```
#
# #### 2. **Iterating Over a List**
# When using a `for` loop with a list, the loop will iterate over each item in the list in sequence.
#
# **Example:**
# ```python
# languages = ['Swift', 'Python', 'Go']
#
# for lang in languages:
#     print(lang)
# ```
#
# **Output:**
# ```
# Swift
# Python
# Go
# ```
# - Here, the loop iterates over the list `languages` and prints each element.
#
# #### 3. **Indentation in a `for` Loop**
# Indentation defines the block of code that belongs to the loop. The body of the loop must be indented consistently. If there is no indentation, Python will throw an error.
#
# **Example:**
# ```python
# languages = ['Swift', 'Python', 'Go']
#
# for lang in languages:
#     print(lang)
#     print('-----')
#
# print('Last statement')
# ```
# - All code inside the loop body is indented, and the `print('Last statement')` is outside the loop because it is not indented.
#
# #### 4. **Iterating Over a String**
# A string in Python can be iterated through character by character using a `for` loop.
#
# **Example:**
# ```python
# language = 'Python'
#
# for letter in language:
#     print(letter)
# ```
#
# **Output:**
# ```
# P
# y
# t
# h
# o
# n
# ```
# - Here, the loop iterates over each character of the string.
#
# #### 5. **Using `range()` in a `for` Loop**
# The `range()` function generates a sequence of numbers, which can be iterated over using a `for` loop.
#
# **Example:**
# ```python
# for i in range(4):
#     print(i)
# ```
#
# **Output:**
# ```
# 0
# 1
# 2
# 3
# ```
# - `range(4)` generates the numbers 0 to 3. The loop iterates over these numbers and prints them.
#
# #### 6. **`for` Loop with `else` Clause**
# An `else` clause can be used with a `for` loop. The `else` block is executed after the loop completes its iteration over the sequence, provided that no `break` statement was encountered.
#
# **Example:**
# ```python
# for i in range(3):
#     print(i)
# else:
#     print("Loop finished")
# ```
#
# **Output:**
# ```
# 0
# 1
# 2
# Loop finished
# ```
#
# #### 7. **Using a `for` Loop Without Accessing Items**
# You can use a `for` loop without directly accessing the items in the sequence. This is useful when you just need to perform an action a set number of times.
#
# **Example:**
# ```python
# for _ in range(3):
#     print("Hello!")
# ```
#
# **Output:**
# ```
# Hello!
# Hello!
# Hello!
# ```
# - The loop runs three times, but we don't use the variable (indicated by `_`).
#
# #### 8. **Nested `for` Loops**
# A `for` loop can be nested within another `for` loop. This allows you to iterate over multiple sequences simultaneously.
#
# **Example:**
# ```python
# for i in range(3):
#     for j in range(2):
#         print(f"i = {i}, j = {j}")
# ```
#
# **Output:**
# ```
# i = 0, j = 0
# i = 0, j = 1
# i = 1, j = 0
# i = 1, j = 1
# i = 2, j = 0
# i = 2, j = 1
# ```
# - The outer loop runs three times, and for each iteration of the outer loop, the inner loop runs twice.
#
# #### 9. **Exiting a Loop Early: `break` Statement**
# You can use the `break` statement to exit a loop before it finishes iterating over all the elements.
#
# **Example:**
# ```python
# for i in range(5):
#     if i == 3:
#         break
#     print(i)
# ```
#
# **Output:**
# ```
# 0
# 1
# 2
# ```
# - The loop terminates when `i` equals 3 because of the `break` statement.
#
# #### 10. **Skipping Iterations: `continue` Statement**
# The `continue` statement is used to skip the current iteration and move to the next one.
#
# **Example:**
# ```python
# for i in range(5):
#     if i == 2:
#         continue
#     print(i)
# ```
#
# **Output:**
# ```
# 0
# 1
# 3
# 4
# ```
# - When `i` equals 2, the `continue` statement is encountered, skipping the rest of the code for that iteration.
#
# - Python for loop with else clause
#     - A for loop can have an optional else clause. This else clause executes after the iteration completes.
#     - Note: The else block will not execute if the for loop is stopped by a break statement.
# ```
# digits = [0, 1, 5]
#
# for i in digits:
#     print(i)
# else:
#     print("No items left.")
#
# ```
#
# - Using for loop without accessing items
#  - # using _ for placeholder variable
# ```
# for _ in languages:
#     print('Hi')
# ```
# These are the key concepts of Python's `for` loop. It is a powerful tool for iterating over sequences in Python, making it essential for working with collections of data.

# %% [markdown]
# ## 30 coding questions
#  based on Python `for` loops that cover various topics such as iterating over sequences, using `range()`, nested loops, and more.
#
# ### Basic Iteration
# 1. **Print each element of a list**
#    Given a list of fruits `['apple', 'banana', 'cherry']`, write a `for` loop to print each fruit.
#
# 2. **Print characters of a string**
#    Write a `for` loop to print each character in the string `"Python"`.
#
# 3. **Sum of elements in a list**
#    Write a program that uses a `for` loop to calculate the sum of all elements in the list `[1, 2, 3, 4, 5]`.
#
# 4. **Print numbers from 1 to 10**
#    Use a `for` loop and the `range()` function to print numbers from 1 to 10.
#
# 5. **Print even numbers from 1 to 20**
#    Write a `for` loop to print all even numbers from 1 to 20 using `range()`.
#
# ### Iterating over Range and Lists
# 6. **Count the number of vowels in a string**
#    Write a program that iterates over the string `"hello world"` and counts how many vowels (`a, e, i, o, u`) are in the string.
#
# 7. **Print numbers in reverse order**
#    Use a `for` loop to print numbers from 10 to 1.
#
# 8. **Calculate factorial**
#    Write a program using a `for` loop that calculates the factorial of a number, say 5.
#
# 9. **Sum of even numbers from 1 to 50**
#    Write a `for` loop to find the sum of all even numbers between 1 and 50.
#
# 10. **Find the maximum element in a list**
#     Given a list `[10, 23, 45, 78, 89, 12]`, write a `for` loop to find the maximum value.
#
# ### Working with Nested Loops
# 11. **Print multiplication table**
#     Write a program to print the multiplication table (from 1 to 10) for a given number using a `for` loop.
#
# 12. **Pattern printing (right triangle)**
#     Write a program to print the following pattern using nested `for` loops:
#     ```
#     *
#     **
#     ***
#     ****
#     *****
#     ```
#
# 13. **Sum of each row in a 2D list**
#     Given a 2D list `[[1, 2, 3], [4, 5, 6], [7, 8, 9]]`, use a nested `for` loop to print the sum of each row.
#
#
# 14. **Check if a number is prime**
#     Write a `for` loop to check if a given number is prime.
#
# 15. **Fibonacci sequence**
#     Use a `for` loop to generate the first 10 numbers of the Fibonacci sequence.
#
# ### Loop with Conditionals
# 16. **Find the index of an element in a list**
#     Write a `for` loop to find the index of an element, say 23, in the list `[10, 23, 45, 78]`. If the element is not found, print "Element not found."
#
# 17. **Filter out negative numbers from a list**
#     Given a list `[1, -2, 3, -4, 5, -6]`, write a `for` loop to filter out all negative numbers and store the positive numbers in a new list.
#
#
# 18. **Find the first occurrence of a target element**
#     Write a `for` loop to find the first occurrence of a target element, say 50, in the list `[10, 20, 30, 40, 50, 60]`. Break the loop once the element is found.
#
# 19. **Find the sum of digits of a number**
#     Write a program using a `for` loop to find the sum of digits of a number, say 1234.
#
# 20. **Reverse a list**
#     Write a `for` loop to reverse a list `[1, 2, 3, 4, 5]`.
#
# ### Advanced Loops with Dictionaries and Sets
# 21. **Iterate over a dictionary**
#     Given a dictionary `{'name': 'John', 'age': 25, 'city': 'New York'}`, write a `for` loop to print each key-value pair.
#
# 22. **Count the frequency of elements in a list**
#     Write a program that uses a `for` loop to count the frequency of each element in a list `['apple', 'banana', 'apple', 'orange', 'banana']`.
#
# 23. **Find common elements in two lists**
#     Given two lists `[1, 2, 3, 4]` and `[3, 4, 5, 6]`, write a `for` loop to find common elements.
#
# 24. **Print the squares of numbers**
#     Write a `for` loop to print the square of numbers from 1 to 10.
#
# 25. **Iterate over a set**
#     Given a set `{10, 20, 30, 40}`, write a `for` loop to print each element of the set.
#
# ### More Complex Examples
# 26. **Flatten a 2D list**
#     Given a 2D list `[[1, 2], [3, 4], [5, 6]]`, write a `for` loop to flatten it into a 1D list.
#
# 27. **Transpose a matrix**
#     Write a program using a `for` loop to find the transpose of a matrix `[[1, 2, 3], [4, 5, 6]]`.
#
# 28. **Cumulative sum**
#     Given a list `[1, 2, 3, 4, 5]`, write a `for` loop to calculate the cumulative sum at each index, i.e., `[1, 3, 6, 10, 15]`.
#
# 29. **Calculate the average of numbers**
#     Write a program using a `for` loop to calculate the average of numbers in the list `[4, 7, 12, 19, 21]`.
#
# 30. **Find the product of all elements in a list**
#     Write a `for` loop to calculate the product of all elements in a list `[2, 3, 5, 7]`.
#
# These questions cover a wide range of topics and difficulty levels, making them suitable for practicing `for` loops in Python.

# %% [markdown]
# ### Short Notes on Python `while` Loop
#
# #### 1. **Introduction to Python `while` Loop**
# The `while` loop in Python is used to repeatedly execute a block of code as long as a specified condition remains true.
#
# **Syntax:**
# ```python
# while condition:
#     # body of the while loop
# ```
# - The loop evaluates the `condition`. If it evaluates to `True`, the code inside the loop is executed.
# - After each iteration, the condition is re-evaluated.
# - The loop continues until the condition becomes `False`.
#
# #### 2. **Example: Basic `while` Loop**
# ```python
# number = 1
#
# while number <= 3:
#     print(number)
#     number = number + 1
# ```
#
# **Output:**
# ```
# 1
# 2
# 3
# ```
# - The loop prints numbers 1 to 3 and stops when `number` becomes greater than 3.
#
# #### 3. **Termination of `while` Loop**
# To prevent an infinite loop, ensure the condition eventually evaluates to `False` by updating variables inside the loop.
#
# **Example:**
# ```python
# number = int(input('Enter a number: '))
#
# while number != 0:
#     print(f'You entered {number}.')
#     number = int(input('Enter a number: '))
#
# print('The end.')
# ```
#
# **Output:**
# ```
# Enter a number: 3
# You entered 3.
# Enter a number: 0
# The end.
# ```
# - The loop runs until the user inputs `0`, then it terminates.
#
# #### 4. **Infinite `while` Loop**
# If the loop's condition is always `True`, it forms an infinite loop.
#
# **Example:**
# ```python
# age = 32
#
# while age > 18:
#     print('You can vote')
# ```
#
# **Output:**
# ```
# You can vote
# You can vote
# ... (infinite)
# ```
#
# Alternatively, you can create an infinite loop explicitly:
#
# ```python
# while True:
#     print('You can vote')
# ```
#
# #### 5. **Exiting a `while` Loop with `break`**
# The `break` statement allows you to exit a loop prematurely before the condition becomes `False`.
#
# **Example:**
# ```python
# while True:
#     number = int(input("Enter a number: "))
#     if number == 0:
#         break
#     print(f'You entered {number}')
# ```
# - The loop terminates when the user enters `0`.
#
# #### 6. **`while` Loop with `else` Clause**
# An `else` clause can be added to a `while` loop. It executes when the loop finishes normally (i.e., not terminated by a `break` statement).
#
# **Example:**
# ```python
# number = 0
#
# while number < 3:
#     print(number)
#     number += 1
# else:
#     print("Loop finished")
# ```
#
# **Output:**
# ```
# 0
# 1
# 2
# Loop finished
# ```
# - The `else` block executes after the loop completes all its iterations.
#
# #### 7. **`for` Loop vs `while` Loop**
# - **`for` loop**: Used when you know the number of iterations in advance or are iterating over a sequence (like lists, strings).
# - **`while` loop**: Used when the number of iterations isn't known beforehand and depends on a condition that must be checked repeatedly.
#
# These are the key concepts of the Python `while` loop, including its syntax, examples, and different variations such as loops with `break`, `else`, and infinite loops.

# %% [markdown]
# Here are 30 coding questions focusing on the **`while`** loop in Python:
#
# ### Basic Iteration
# 1. **Print numbers from 1 to 10 using `while` loop**
#    Write a program using a `while` loop to print numbers from 1 to 10.
#
# 2. **Sum of natural numbers from 1 to 50**
#    Use a `while` loop to find the sum of natural numbers from 1 to 50.
#
# 3. **Count down from 10 to 1**
#    Write a program that counts down from 10 to 1 using a `while` loop and prints each number.
#
# 4. **Print the even numbers between 1 and 20**
#    Use a `while` loop to print all even numbers from 1 to 20.
#
# 5. **Print the reverse of a given number**
#    Write a program to print the digits of a given number in reverse order using a `while` loop.
#
# ### Loop Control and Breaks
# 6. **Find the first multiple of 7 greater than 50**
#    Use a `while` loop to find the first multiple of 7 that is greater than 50.
#
# 7. **Sum of digits of a number**
#    Write a program using a `while` loop to find the sum of digits of a given number, say 1234.
#
# 8. **Find factorial of a number**
#    Write a program to calculate the factorial of a number using a `while` loop.
#
# 9. **Print numbers until the user enters 0**
#    Continuously ask the user to input a number and print it until they enter 0. Use a `while` loop for this.
#
# 10. **Print the first 10 Fibonacci numbers**
#     Write a program that uses a `while` loop to print the first 10 numbers in the Fibonacci sequence.
#
# ### Conditional Loops
# 11. **Find the sum of numbers until it exceeds 100**
#     Write a program that keeps adding user-inputted numbers until the sum exceeds 100.
#
# 12. **Check if a number is prime**
#     Use a `while` loop to check whether a given number is prime.
#
# 13. **Find the greatest common divisor (GCD)**
#     Use the Euclidean algorithm and a `while` loop to find the GCD of two numbers.
#
# 14. **Find the number of digits in a number**
#     Write a `while` loop to count the number of digits in a given number.
#
# 15. **Check if a number is palindrome**
#     Write a `while` loop to check if a number is the same when reversed (i.e., palindrome).
#
# ### Nested While Loops
# 16. **Print a multiplication table for a number**
#     Use a `while` loop to print the multiplication table (up to 10) for a given number.
#
# 17. **Pattern printing (triangle)**
#     Use a nested `while` loop to print the following pattern:
#     ```
#     *
#     **
#     ***
#     ****
#     *****
#     ```
#
# 18. **Check if a number is an Armstrong number**
#     Write a program using a `while` loop to check if a number is an Armstrong number.
#
# 19. **Find the sum of even numbers between 1 and 100**
#     Use a `while` loop to find the sum of all even numbers between 1 and 100.
#
# 20. **Count vowels in a string**
#     Write a program that uses a `while` loop to count how many vowels are in a given string.
#
# ### Advanced While Loops
# 21. **Guess the number game**
#     Write a number-guessing game where the user has to guess a number between 1 and 100. Use a `while` loop to keep asking until they guess correctly.
#
# 22. **Find the largest number in a sequence**
#     Keep asking the user for numbers until they enter -1. Use a `while` loop to find the largest number in the sequence.
#
# 23. **Find the smallest number in a sequence**
#     Keep asking the user for numbers until they enter -1. Use a `while` loop to find the smallest number in the sequence.
#
# 24. **Generate prime numbers between 1 and 50**
#     Write a program using a `while` loop to generate prime numbers between 1 and 50.
#
# 25. **Generate all multiples of 3 less than 100**
#     Use a `while` loop to generate and print all multiples of 3 that are less than 100.
#
# ### Working with Infinite Loops
# 26. **Simple calculator using while loop**
#     Write a basic calculator using a `while` loop that keeps asking the user for two numbers and an operation (+, -, *, /) until they enter "exit."
#
# 27. **Create a simple login system**
#     Keep asking the user for a username and password until they enter the correct credentials using a `while` loop.
#
# 28. **Find the sum of all numbers in a user-defined list**
#     Allow the user to enter numbers into a list. Use a `while` loop to find the sum of all numbers in that list.
#
# 29. **Simulate a dice roll**
#     Write a program using a `while` loop that simulates rolling a dice until you get a 6.
#
# 30. **Calculate compound interest**
#     Write a program that calculates compound interest over time using a `while` loop. Ask the user for the initial amount, interest rate, and time, and keep looping until the time is up.
#
# These questions should give you a broad understanding of how to work with `while` loops in Python, covering everything from basic iterations to more advanced and nested loops.

# %%
while True:
    user_input = input("Enter a number (type 'exit' to quit): ")
    if user_input == 'exit':
        break
    print(f"You entered: {user_input}")

# %% [markdown]
# ## 10 real-world questions related to the use of `pass`, `break`, and `continue` in Python:
#
# ### 1. **Managing User Input**
#    - **Question**: Write a Python program that continuously asks the user to input a number. If the number is negative, use `break` to stop the loop.
#
# ### 2. **Skipping Invalid Entries**
#    - **Question**: In a list of user inputs, how would you skip processing any empty string using `continue` in a loop?
#
# ### 3. **Menu-Driven Application**
#    - **Question**: Create a simple menu-driven application where the user can select different options. Use `pass` as a placeholder for menu options that are not yet implemented.
#
# ### 4. **Exiting on Keyword**
#    - **Question**: Write a Python program that prompts users to input text. Use `break` to exit the loop if they type "quit".
#
# ### 5. **Skipping Specific Iterations**
#    - **Question**: In a range of numbers from 1 to 20, use `continue` to skip printing numbers that are divisible by 3. How would you do this?
#
# ### 6. **File Processing**
#    - **Question**: You are reading a file line by line in Python. Use `continue` to skip processing any lines that start with the character `#`.
#
# ### 7. **Search in a List**
#    - **Question**: You are searching for a specific item in a list. As soon as you find the item, use `break` to stop further searching and print "Item found!".
#
# ### 8. **Data Filtering**
#    - **Question**: You have a list of dictionaries representing employees. Write a loop that uses `continue` to skip employees who do not have a salary field defined.
#
# ### 9. **Infinite Loop Control**
#    - **Question**: Create a Python program that runs an infinite loop asking the user for input. Use `break` to stop the loop when the user enters a specific keyword (e.g., "stop").
#
# ### 10. **Skipping Errors in Data Processing**
#    - **Question**: You are processing a list of integers, but some elements might not be integers. Write a Python program that uses `continue` to skip non-integer elements without raising an error.
