# %% [markdown]
# ###  Types of Data Types

# %%
age = 25
age

# %%
type(age) #checking the data type of age variable
# Out:
# int

# %%
type(3.24)
# Out:
# float

# %%
a ="25"
type(a)
# Out:
# str

# %%
type("shahil")
# Out:
# str

# %%
type(True)

# %%
500+50

# %%
"500"+"50"

# %% [markdown]
# #### Type Casting & Conversion

# %%
age
# Out:
# 25

# %%
float(age) #converting age variable to float data type
# Out:
# 25.0

# %%
age
# Out:
# 25

# %%
a =float(a) 
a
# Out:
# 25.0

# %%
a
# Out:
# 25.0

# %%
a =float(age) #storing the converted value in a new variable a
a
# Out:
# 25.0

# %%
str(a)
# Out:
# '25.0'

# %%
age

# %% [markdown]
# ### types of Conversions
# 1. Implicit Conversion:
# 2. Explicit Casting:

# %%
4+ 5.7
# Out:
# 9.7

# %%
# 1.Implicit Conversion:

a= 5 + 2.5  #to minimize the loss of data, Python automatically converts the integer 5 to a float before performing the addition. 
a

# %%
# 2.Explicit Casting:
int(a)

# %%
a

# %%
a = int(a) #storing the converted value in a new variable a

# %%
a

# %%
# int(), float(), str(), bool(), list(), tuple(), set(), dict() ,complex() are some of the commonly used type conversion functions in Python.

# %%
str(a)

# %%
str(123) #converting an integer to a string
