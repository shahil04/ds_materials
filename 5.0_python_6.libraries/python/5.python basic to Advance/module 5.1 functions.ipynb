# %% [markdown]
# # Functions in Python
# - Functions in Python are named blocks of organized, reusable code designed to perform specific tasks.
#
# They are fundamental to modularizing and structuring Python programs, promoting code reusability and readability.
# Key Aspects of Python Functions:
#
# Definition: Functions are defined using the def keyword, followed by the function name, parentheses (which may contain parameters), and a colon. The function's body is indented.

# %% [markdown]
# Functions in Python are named blocks of organized, reusable code designed to perform specific tasks. They are fundamental to modularizing and structuring Python programs, promoting code reusability and readability.
#
# #### - Key Aspects of Python Functions:
# Definition: Functions are defined using the def keyword, followed by the function name, parentheses (which may contain parameters), and a colon. The function's body is indented.

# %%
nums =[5,6,7,8,3]
# sum all numbers
sum(nums)

# sum all numbers without using sum functions
total =0
for  i in nums:
    total = total +i
total
# #Syntax
# def functionname():
#     logic statements

# %%
# Create a Python Function 
def greet():
  print("hello parvinder")

# %%
# call functions using there name 
greet()  # this function only print text

# %%
# Python Function  with input to take data from user
def greet1():
  name = input("enter your name")
  print("hello ",name)
  print ( "how are you !")

# %%
greet1()

# %% [markdown]
# ## Types of Functions:
# 1. Built-in Functions: Functions provided by Python's standard library, readily available for use (e.g., print(), len(), sum()).
# 2. User-defined Functions: Functions created by the programmer to perform specific tasks.
#     * a. Normal def fucntion (without argunment/ with argunment)
#     * b. lambda function
#     * c. recursion Function / call itself
#
# **extra**
# * Some Advance Functions
#
# * Functions from Modules: Functions defined within modules that need to be imported before use (e.g., math.sqrt() from the math module).

# %% [markdown]
# ## 1. Built-in Functions:
# Functions provided by Python's standard library, readily available for use (e.g., print(), len(), sum()).

# %%
print()

# %%
len()

# %%
sum()

# %% [markdown]
# ### 2.without Functions create Cart Logic

# %%
# Q.define a product_name list and product_quantity_list and where take input from user.
# OR

# Also  Add to cart create using dictionry
# Q.define a product_name  and product_quantity in dictionary and where take input from user.

# %%
product_name =[]
product_quantity_list =[]

# %%
user_input = input("enter the product name")
product_name.append(user_input)
print(product_name)

user_input = input("enter the product quantity")
product_quantity_list.append(user_input)
print(product_quantity_list)

# %%
# Also  Add to cart create using dictionry
# Q.define a product_name  and product_quantity in dictionary and where take input from user.
cart={}
cart["product_name"]=[]
cart["product_quantity_list"]=[]
cart

# %%
# add product name
user_input = input("enter the product name")
cart["product_name"].append(user_input)
print(cart)

# %%
# add product Quanity
user_input = int(input("enter the product quantity"))
cart["product_quantity_list"].append(user_input)
print(cart)

# %%
# add product name
user_input = input("enter the product name")
cart["product_name"].append(user_input)

# add product Quanity
user_input = int(input("enter the product quantity"))
cart["product_quantity_list"].append(user_input)
print(cart)

# %% [markdown]
# ## 2. User-defined Functions:
# Functions created by the programmer to perform specific tasks.
#
#     * a. Normal def fucntion (without argunment/ with argunment)
#     * b. lambda function
#     * c. recursion Function / call itself

# %% [markdown]
# ### Create Add to Cart System like Flipkart -->using def functions

# %% [markdown]
# a. without Argunment functions def

# %%
cart={}
cart["product_name"]=[]
cart["product_quantity_list"]=[]

def add_to_cart():
    # add product name
    user_input = input("enter the product name")
    cart["product_name"].append(user_input)
    user_input = int(input("enter the product quantity"))
    cart["product_quantity_list"].append(user_input)
    print(cart)

# %%
add_to_cart()

# %%
cart
# sum(data)

# %% [markdown]
# ### b. with Argunment functions def
#
# ![](https://pynative.com/wp-content/uploads/2022/08/python_function_argument_and_parameter.jpg)

# %%
# without  parameter
def greet1():
  name = input("Enter your name: ")
  print("hello ",name)

# %%
greet1()

# %%
# use a parameter
def greet2(name):
  print("hello ",name)

# %%
greet2("raj") # put a value when function call

# %%
# def add_to_cart(): witout argunments 
#     # add product name
#     user_input = input("enter the product name")
#     cart["product_name"].append(user_input)
#     user_input = int(input("enter the product quantity"))
#     cart["product_quantity_list"].append(user_input)
#     print(cart)

# add_to_Cart() with argunment
def add_to_Card1(product_name, product_quantity):
  cart["product_name"].append(product_name)
  cart["product_quantity_list"].append(product_quantity)
  print("Item added Successfully to the cart.",product_name, product_quantity)

# %%
add_to_Card1("dell",5)
cart

# %%
# Remove the item from cart 
index = cart["product_name"].index('pc')  # use index method for find index number of product name value
index

# %%
# Remove the item from cart 
cart["product_name"].pop(index)
cart["product_quantity_list"].pop(index)

# %%
cart

# %%
def remove_item(product_name):
    index = cart["product_name"].index(product_name)  
    cart["product_name"].pop(index)
    cart["product_quantity_list"].pop(index)
    print(product_name , " item Discard Successfully ")
    print("Left items :",cart)

# %%
remove_item("dell")

# %%
# 1. add to cart
# 2.remove from cart
# 3.update the cart
# 4.view cart
# 5. delete all item from cart
# 6. buy items
cart={}
cart["product_name"]=[]
cart["product_quantity_list"]=[]

# %%
# update_qantity()
def update_qantity(product_name, new_quantity):
  print("Previues cart value ",cart )
  a = cart["product_name"].index(product_name)
  cart["product_quantity_list"][a] = new_quantity

  print("Item updated Successfully to the cart.", product_name,new_quantity)

# show_cart()
def show_cart():
  print(cart)

# %%
update_qantity("pc",5)
show_cart()

# %% [markdown]
# #### Create Menu functions

# %%
# 1. add_to_Card()
# 2. update_qantity()
# 3. delete_card_item()
# 4. show_card()
# 5. Buy
# 6. Exit
# create a options Menu
def menu():
  print("Welcome to Flipkart")
  print("====================")
  print("1. add_to_Card()")
  print("2. update_qantity()")
  print("3. delete_card_item()")
  print("4. show_card()")
  print("5. Buy ")
  print("6. Exit")
  print("====================")
  user_input = int(input("enter the option: "))
  
  if user_input ==1:
    n =input("enter the product name ")
    q =input('enter the quantity')
    add_to_Card1(n,q)

  elif user_input ==2:
    n =input("enter the product name ")
    q =input('enter the new quantity')
    update_qantity(n,q)
  elif user_input ==3:
    n =input("enter the product name ")
    remove_item(n)
  elif user_input ==4:
    show_cart()
  elif user_input ==5:
    show_cart()
    print("Buy Product Successfully:")
  elif user_input ==6:
    print("for Exit press n")
  else:
    print("Invalid option")

# %%
menu()

# %%
menu()

# %%
# create a options Menu with LOOP
while True:
  menu()
  print("==========================")
  user_input = input("Do you want to continue? (y/n): ")
  if user_input != "y":
    break

# %% [markdown]
# ##  Parameters and Arguments:
# Parameters: Variables defined within the function's parentheses that receive input values when the function is called.
#
# Arguments: The actual values passed to the function when it is called.

# %%
# def functions with parameter
# Parameters --> name ,age
def greet(name, age):
  print("hello ",name , age)

# %%
# Arguments --> like actual vaule --> ayush ,23
greet("ayush",23)

# %% [markdown]
# Return Values:
# Functions can return a value using the return statement. If no return statement is present, the function implicitly returns None.

# %% [markdown]
# ### Types of Argnuments
# 1. positional Argunment --> use same sequence like we define
# 2. keyword Argunment
# 3. default arg
# 4. *args and **args

# %%
add_to_Card1("car",2) # 1.positional Argunment --> use same sequence like we define

# %%
add_to_Card1(3, "bike")

# %%
show_cart()

# %% [markdown]
# 2.keyword Argunment

# %%
add_to_Card1(product_quantity=5, product_name="mobile") # 2.keyword Argunment

# %%
show_cart()

# %% [markdown]
#  default argunment

# %%
# default argunment
# add_to_Card() with argunment
def add_to_Card2(product_name="Membership", product_quantity=1):
  cart["product_name"].append(product_name)
  cart["product_quantity_list"].append(product_quantity)
  print("Item added Successfully to the cart.",product_name, product_quantity)

# %%
add_to_Card1()

# %%
add_to_Card2()

# %%
show_cart()

# %%
add_to_Card2(product_quantity=20,product_name="bike")

# %%
show_cart()

# %%
# write a python functions of login system.
usename_db ="sha"
user_pass_db =123

def login():
	user = input("enter the  user name")
	passd = int(input("enter the password"))
	if usename_db== user and passd== user_pass_db :
		print("login successful")
	else:
		print("login failed")

# write a python functions of login system pass username and passwords in argunmnets .
def login1(user, passd=123):
	
	if usename_db== user and passd== user_pass_db :
		print("login successful")
	else:
		print("login failed")

# %%
# login1("sha",123) # positional 
# login1(passd=123, user="sha") # Keyword argnuments

login1("sha") #default argnmunts passd =123

# %%
# create 2 number sum functions
def add(n1, n2):
  print(n1+n2)

# %%
add(3,203)

# now create n number of sum functions where value length in unknown
# write a python function to add N numbers using argunments

# %% [markdown]
# ### Arbitrary Arguments
# 1. (*args)
# 2. (**kwargs)

# %%
# add n number from argunments
# Arbitrary Arguments (*args)
# *args argunmnets --> store as a tuple
def add1(*n):
  print(n)
  print(sum(n))

# %%
add1(2,3,56,34,4,8,9)

# %% [markdown]
# Arbitrary Keyword Arguments (**kwargs)

# %%
#  Arbitrary Keyword Arguments (**kwargs)
def my_function(**kwargs):
    print("Received keyword arguments:", kwargs)

# %%
my_function(name="rohit",roll=23,)

# %%
name= "raj" # show the f string example
r =34
print("hello my name is ",name , "and i am a teacher",r)
print(f"hello my name is {name} and i am a teacher {r}")

# %%
def func(**kwargs):
    print("Received keyword arguments:", kwargs)
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
func(name="Alice", age=30, city="New York",xyz="abc")

# %% [markdown]
# ## functions  Advantages:
# 1. Modularity: Breaks down complex programs into smaller, manageable units.
# 2. Reusability: Avoids code duplication by allowing the same code block to be used multiple times.
# 3. Readability and Maintainability: Improves code organization and makes it easier to understand and modify.

# %% [markdown]
# ##### Global Variables:
# - Definition:
# Global variables are defined outside of any function or class, typically at the top level of a script.
# - Scope:
# Their scope spans the entire program. They can be accessed and, with the global keyword, modified from anywhere in the code, including inside functions.
# - Lifetime:
# They are created when the program starts and remain in memory until the program terminates.
# - Modification within Functions:
# To modify a global variable from within a function, you must explicitly declare it as global inside that function using the global keyword. If you assign a new value to a variable with the same name as a global variable inside a function without using global, you are creating a new local variable with that name, not modifying the global one.

# %%
global_var = "I am global"

def modify_global():
    global global_var  # Declare intent to modify the global variable
    global_var = "I have been modified globally"

def access_global():
    print(global_var)

access_global()
modify_global()
access_global()

# %%
a =5
def variable():
  global a # global var inside function
  b =3  # local variable


  print("inside from function", a)
  a = 7
  print("after reassign", a)

print("outside from function", a)

# %%
variable()

# %%
a

# %% [markdown]
# #### Nonlocal Variables (in Nested Functions):
# Nonlocal variables are used in the context of nested functions (where one function is defined inside another).
#
# The nonlocal keyword allows an inner function to modify a variable that belongs to its immediate enclosing (outer) function's scope, but is not a global variable.

# %% [markdown]
# ### Return Keyword usecase

# %%
# WAP to Add number and subtract 10 outside of functions
def add2(*n):
  total = sum(n)
  print(total)

# %%
add2(2,3,4,5,6,7,8,9)

# %%
a = add2(2,3,4,5,6,7,8,9)

# %%
a-10

# %%
def add2(*n):
  return (sum(n))

# %%
b = add2(2,3,4,5,6,7,8,9)

# %%
b

# %%
b-10
#  Return use

# %% [markdown]
# * use with functions
# * return a value from function for future return the value and store in variable for future use

# %% [markdown]
# ### 1. Write a Python program to calculate the area of a rectangle 4,5 -->20
# ### 2. How do you calculate the factorial of a number in Python? 5 -->120
# ### 3. Write a Python program to calculate the sum of digits in a number. 345 -->12
#
#
# https://www.ccbp.in/blog/articles/python-coding-questions

# %%
def rectangle_area(height,width):
    area =height*width
    return f"rectange area is {area}"

# %%
rectangle_area(12,10)

# %%
def factorial(number):
    fact =1
    for i in range(1, number+1):
        fact = fact* i

    return fact

# %% [markdown]
# ### **simple Hospital Management System in Python** using **basic functions only** — no class/object-oriented programming involved. HW
#
# ---
#
# ### ✅ Features Covered:
#
# * Add patient
# * View patient list
# * Search patient by ID
# * Discharge patient
# * Exit
#
# ---
#
# ### 🧠 Logic:
#
# * Store patient details in a **list of dictionaries**
# * Use a **menu-driven approach** with basic functions
#
# ---
#
# ### 💻 Code:
#
# ```python
# # Global list to store patients
# patients = []
#
# # Function to add a patient
# def add_patient():
# # Function to view all patients
# def view_patients():
# # Function to search for a patient by ID
# def search_patient():
# # Function to discharge a patient
# def discharge_patient():
#
# # Main function
# def hospital_menu():
# # Run the menu
# hospital_menu()
# ```
#
# ---
#
# ### 📝 Example Output:
#
# ```
# --- Hospital Management System ---
# 1. Add Patient
# 2. View Patients
# 3. Search Patient
# 4. Discharge Patient
# 5. Exit
# Enter your choice (1-5): 1
# Enter Patient ID: P001
# Enter Patient Name: John
# Enter Age: 45
# Enter Disease: Fever
# Enter Admission Date (DD-MM-YYYY): 19-06-2025
# Patient added successfully.
# ```
#
# ---

# %%
# Write a function to check the give number is positive or not
n=3
def check_positive(num):
  if num>0:
    print("positive")
    return num
  else:
    print("negative")

# %%
check_positive(23)

# %%
x = check_positive(23)

# %%
n

# %%
x

# %%
a = check_positive(-27)

# %%
a

# %%
#  Write a function to check the given positive number is prime or not and number take from 1st function.
def check_prime(number):
  for i in range(2,number):
    if number%i==0:
      print("not prime",number)
      break
  else:
    print("prime",number)

# %%
check_prime(x)

# %%
check_prime(check_positive(64))

# %% [markdown]
# ## Types of functions
#
# ## b.Lambda Functions (Anonymous Functions):
# These are small, anonymous functions defined using the lambda keyword. They are typically used for short, single-expression operations where a full function definition is not necessary.
# ```
#     add = lambda x, y: x + y
# ```
# •

# %%
# create Normal fuctions using def
def sqrt(a):
  return a*a

# %%
sqrt(50)

# %%
# syntax
# lambda arguments : logic/statements

# %%
#  create a lambda functions for square
b= lambda a : (a*a)
b(4)

# %%
# creat a function check the  number is even
def odd_even(num):
    if num%2 ==0:
        print(num ,"even Number")
    else:
        print(num,"odd number")

odd_even(44)

# %%
# check the  number is even or not using lambda
lambda x: x % 2 == 0

# if use if-else with lambda
# lambda argnmunt: "true case" if condition else "false case"
check = lambda num: "even number" if num%2==0 else "odd number"

# %%
check = lambda num: "+ve number" if num>0 else "-ve number"

# %%
  check(34)

# %%
check_odd_even = lambda num : "even" if num % 2 == 0 else "odd"

# %%
check_odd_even(43)

# %%
num =45
if num%2==0:
  print("even")
else:
  print("odd")

# %% [markdown]
# ### c.Recursive Functions:
# These are functions that call themselves to solve a problem. They are often used when a problem can be broken down into smaller, similar sub-problems. A base case is required to prevent infinite recursion.
#
# ![](https://www.programiz.com/sites/tutorial2program/files/python-recursion-function.png)

# %%
def hii():
  print("Hello")
  hii()

# %%
hii()

# %%
def check_positive(n):
  if n>0:
    print("positive",n)
    return check_positive(n-1)
  else:
    print("negative")

# %%
check_positive(5)

# %%
def fact(n):
  factorial = 1
  for i in range(1, n + 1):
    factorial *= i
  return factorial

# %%
fact(5)

# %%
# using recursion
def fact1(n):
  if n == 0:
    return 1
  else:
    return n * fact1(n - 1)

# %% [markdown]
# https://www.programiz.com/python-programming/recursion
# ![](https://cdn.programiz.com/sites/tutorial2program/files/python-factorial-function.png)

# %%
fact1(5)

# %%
# WaP to create 2 list 1st caergory and 2nd list sales amount
# and only sum the any one category like technology

# WAP to Find Fibonacci series of 10 using recursion

# %% [markdown]
# ## Recursive Functions:
#  These are functions that call themselves to solve a problem. They are often used when a problem can be broken down into smaller, similar sub-problems. A base case is required to prevent infinite recursion.

# %% [markdown]
# A recursive function in Python is a function that calls itself during its execution. This technique is used to solve problems that can be broken down into smaller, self-similar subproblems.
# Key components of a recursive function:
#
# Base Case:
# This is a condition that terminates the recursion. Without a base case, the function would call itself indefinitely, leading to a RecursionError (stack overflow). The base case provides a direct solution to the simplest instance of the problem.
#
# Recursive Case:
# This part of the function involves calling the function itself with a modified input, moving closer to the base case. The problem is broken down into a smaller version of the same problem.

# %%
def show(n):
  if n ==5:
    return n
  else:
    print(n)
    return show(n+1)

# %%
show(1)

# %%
# fibonaci series
[0,1,1,2,3,5,8,13,21]
# normal function
def fibonaci(n):
    fib =[0,1]
    n1 =0
    n2 =1
    for i in range(n):
        next =n1+n2
        n1 =n2
        n2 =next
        fib.append(next)

    return fib

fibonaci(5)

# %%
#  write a function to print the fibonacci series
def finc(n):
  num1 = 0
  num2 =1
  print(num1,end=" ")
  print(num2 ,end=" ")
  for i in range(n):
    next = num1+num2
    print(next, end=" ")
    num1 = num2
    num2 =next

finc(10)

# %%
# recursion
def fibonacci_recursive(n):
    if n <= 1:
        return n
    else:
        return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)

# Example usage:
n_terms = 10
print("Fibonacci sequence (recursive):")
for i in range(n_terms):
    print(fibonacci_recursive(i), end=" ")

# %% [markdown]
# ### Variable Scope - Global vs Local

# %% [markdown]
# variables are categorized as either local or global based on their scope, which dictates where they can be accessed and modified within a program.
# - Local Variables:
# Definition:
# Local variables are defined inside a function or a block of code.
#
# - Scope:
# Their scope is limited to the function or block in which they are defined. They are only accessible within that specific function or block.
#
# - Lifetime:
# They are created when the function is called and are destroyed when the function finishes execution.
#
# - Encapsulation:
# They promote encapsulation by keeping data isolated within functions, reducing the risk of unintended side effects in other parts of the program

# %%
a =5
def variable():
  a =4
  print("inside from function", a)

print("outside from function", a)
variable()

# %%
variable()

# %%
def my_function():
    local_var = "I am local"
    print(local_var)

my_function()
-# print(local_var)  # This would raise a NameError because

# %%
d ={"p":1,"r":2,"g":1}
d.keys()
d["r"]

# %%
# write a FUNCTIONS to calculate frequency of char in string
# progmramme --> p:1,r:2,g:1 ,m:
def frequency(word):
    data ={}
    for char in word:
        # print(char)
        if char not in data.keys():
            data[char]= 1
        else:
            data[char]+=1
    return data        

x =frequency("progmramme")

# %%
x
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 1, 'm': 3, 'a': 1, 'e': 1}

# %%
frequency("ppython cplass")
# Out:
# {'p': 3,
#  'y': 1,
#  't': 1,
#  'h': 1,
#  'o': 1,
#  'n': 1,
#  ' ': 1,
#  'c': 1,
#  'l': 1,
#  'a': 1,
#  's': 2}

# %%
sum([4,5,6,7,8,9,0,1,2,4,4,4])
# Out:
# 54
