# %% [markdown]
# # File Handling

# %% [markdown]
# File handling in Python refers to the process of interacting with files on a computer's file system, allowing for operations such as creating, opening, reading, writing, appending, renaming, and deleting files.
#
# ##### Key Concepts and Operations:
#
# 1. Opening a File:
#
# The open() function is used to open a file, returning a file object (also known as a file handle).
# ```
# Syntax: file_object = open(filename, mode)
#
# filename: The name or path of the file to open.
# ```
#
# mode: Specifies the purpose of opening the file (e.g., 'r' for read, 'w' for write, 'a' for append, 'x' for exclusive creation, 'b' for binary, 't' for text, '+' for read and write).
#
# **File Modes:**
# - 'r' (Read): Opens for reading (default).
# - 'w' (Write): Opens for writing, creates the file if it doesn't exist, and truncates (empties) it if it does.
# - 'a' (Append): Opens for appending, creates the file if it doesn't exist, and adds content to the end if it does.
# - 'x' (Exclusive Creation): Creates a new file, but raises an error if the file already exists.
# - 't' (Text): Opens in text mode (default for text files).
# - 'b' (Binary): Opens in binary mode (for non-text files like images).
#
# - Adding '+' to any mode (e.g., 'r+', 'w+') allows both reading and writing.
# Reading from a File:
#
# - read(size): Reads size bytes (or characters in text mode) from the file.
# - readline(): Reads a single line from the file.
# - readlines(): Reads all lines from the file and returns them as a list of strings.
#
# **Writing to a File:**
# - write(string): Writes a string to the file.
# - writelines(list_of_strings): Writes a list of strings to the file.
#
# **Closing a File:**
#
# - file_object.close(): Closes the opened file, releasing system resources.
# - Using with statement: The preferred method for opening files as it automatically handles file closing, even if errors occur.
#
# ```
#
#         with open("example.txt", "r") as file:
#             content = file.read()
#         # File is automatically closed here
# Example:
# Python
#
# # Writing to a file
# with open("my_file.txt", "w") as f:
#     f.write("Hello, Python!\n")
#     f.write("This is a new line.")
#
# # Reading from a file
# with open("my_file.txt", "r") as f:
#     content = f.read()
#     print(content)
#
# # Appending to a file
# with open("my_file.txt", "a") as f:
#     f.write("\nAppending more text.")
#
# ```

# %%
# open(filename, "a")
# create new file using code 
file = open("module 6.1 file_handling.txt","w")
file.write("this is a 1st line , this is new line")
file.close()

# %%
file = open("module 6.1 file_handling.txt","r")
data = file.readline() # read the 1st line text from file 
print(data)

# %%
file = open("module 6.1 file_handling.txt","r")
data = file.readlines() # return all text in a list from file 
print(data)

# %%
# read options  read(), readline(), readlines()
# read --> read all data in one go
# readline --> read 1 line at a time
# readlines --> read all data and store in a list
file = open("module 6.1 file_handling.txt","r")
data = file.read()
print(data)
# Out:
# this is a 1st line , this is new line 123
# this is 2nd line

# %%
# after read all data then cursor at the end of the line so we use tell() and seek() for cursor
file.readline()
# Out:
# ''

# %%
# tell --> show the index number of your cursor
file.tell()
# Out:
# 59

# %%
# seek --> move the cursor into a desire index
file.seek(5)  # pass int as a cursor index
# Out:
# 5

# %%
file.readline()
# Out:
# ''

# %%
file.tell()
# Out:
# 59

# %%
file.readlines()

# %%
# close file permanent for no furture use .
file.close()

# %% [markdown]
# ### Create a file and store the data and also read

# %%
# data
cart ={"phone":30,"pc":40}

# %%
# create a file
f2 = open("module 6.1 summary.txt","w")
f2.write("Add cart data \n")
f2.write(str(cart))

# f2.close()
# Out:
# 23

# %%
f2.read()
# it show error of not readable  --> why --> because w mode only write
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 f2.read()
#       2 # it show error of not readable  --> why --> because w mode only write
#
# UnsupportedOperation: not readable

# %%
# create a file
f2 = open("summary1.txt","w+")
f2.write("1 s is summary file\n")
f2.write(str(cart))
# Out:
# 23

# %%
f2.read()
# Out:
# ''

# %%
# now our cursor at the end of data after write
f2.seek(0)
f2.read()
f2.close()

# %%
f2 = open("module 6.1 summary.txt","w+")
f2.write("add new data")
f2.close()

# %% [markdown]
# - write mode -->  delete the old data of file and then store new data
# - so if store new data with old data-->  use append mode

# %%
# create a file
f2 = open("module 6.1 summary.txt","a+")
f2.write("\n this is new data add on using append")
f2.close()

# %% [markdown]
#  work with binary files

# %%
# !pip install requests

# %%
import requests

url = "https://blog.sothebysrealty.ae/hubfs/Imported_Blog_Media/14b6402b-ec05-4c28-8d67-3b304b437d71-1.jpg"
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
f = open('car.jpg', 'wb')
f.write(r.content)
f.close()

# %% [markdown]
# # With keyword
#
# The with statement in Python is a control flow structure used for resource management, primarily to ensure that resources are properly acquired and released,

# %%
with open('car1.jpg', 'wb') as f:
    f.write(r.content)

# %% [markdown]
# ## other Library for read and write in tabular data and binary data

# %%
open("/content/sample_data/california_housing_train.csv","r").read()

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# for  predefine open files  using pandas
import pandas as pd
pd.read_csv("titanic.csv")
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
#  Form Image read usig PIL Library
# pip install pillow
from PIL import Image
Image.open("car.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x900>

# %%
# with open() as filename:
  # statements
with open("3module 6.1 file_handling.txt", "r+") as file:
    content = file.read()

print("last line")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 3
#       1 # with open() as filename:
#       2   # statements
# ----> 3 with open("3module 6.1 file_handling.txt", "r+") as file:
#       4     content = file.read()
#       6 print("last line")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# ...

# %%
# FileNotFoundError

# # Error handling / Exceptions handling
# try:
#     # error code \

# except:
#     # print()
try:
    with open("module 6.1 file_handling.txt", "r+") as file:
        content = file.read()     
except Exception as e:
    print("Please check the file name and try again",e)
else:
    print(content)
finally:
    print("run all code")
print("last line")
# Out:
# this is a 1st line , this is new line 123
# this is 2nd line
# run all code
# last line

# %% [markdown]
# ## pickle module pickling and unpickling

# %% [markdown]
# The pickle module in Python provides a way to serialize and deserialize Python object structures. This process is often referred to as "pickling" and "unpickling," respectively.
#
# **Pickling (Serialization):**
#
# • This is the process of converting a Python object (e.g., a list, dictionary, custom class instance) into a byte stream.
# • This byte stream can then be stored in a file, transmitted over a network, or otherwise persisted.
# • The pickle.dump() function is used to write a pickled object to a file-like object.
# • The pickle.dumps() function returns the pickled object as a bytes object.
#
# **Unpickling (Deserialization):**
#
# • This is the reverse process of reconstructing the original Python object from its byte stream representation.
# • The pickle.load() function reads a pickled object from a file-like object.
# • The pickle.loads() function reconstructs an object from a bytes object.
#
#
# **Key Features and Considerations:**
#
# • Object Preservation: pickle aims to preserve the exact state of the object, including its data and structure, allowing for faithful reconstruction.
# • Python-Specific: pickle is a Python-native serialization format, meaning pickled objects generally cannot be unpickled in other programming languages.
#
# • Security Warning: Unpickling data from untrusted or unauthenticated sources is highly discouraged due to potential security risks, as malicious pickle data can execute arbitrary code during deserialization.
# • Use Cases: Commonly used for saving trained machine learning models, storing application state across sessions, or transferring complex Python objects between processes within a Python environment.
#
# ```
# Example Usage:
# import pickle
#
# # An object to pickle
# data = {'name': 'Alice', 'age': 30, 'city': 'New York'}
#
# # Pickling (serializing) to a file
# with open('data.pkl', 'wb') as f:
#     pickle.dump(data, f)
#
# # Unpickling (deserializing) from a file
# with open('data.pkl', 'rb') as f:
#     loaded_data = pickle.load(f)
#
# print(loaded_data)
#
# ```

# %%
import pickle
# joblib and hd5, hdfs5

# An object to pickle
data = {'name': 'Alice', 'age': 30, 'city': 'New York'}

# Pickling (serializing) to a file
with open('data.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
# Unpickling (deserializing) from a file
with open('data.pkl', 'rb') as f:
    loaded_data = pickle.load(f)

print(loaded_data)

# %%
# https://www.programiz.com/python-programming/exception-handling
# extra notes
# https://www.programiz.com/python-programming/user-defined-exception
