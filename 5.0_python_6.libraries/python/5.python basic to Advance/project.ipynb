# %%
import pandas  as pd
data = pd.read_excel("Finance Database.xlsx")
data.head()
# step 2
data = data.set_axis(list(data.iloc[0]), axis=1)
data = data[1:]
data.head()

#step 3
# piviot the table using melt
melted_df = pd.melt(data, id_vars=['Type', 'Component'], var_name='Date', value_name='Value')
melted_df["Date"] = pd.to_datetime(melted_df["Date"],format='%b-%y')
print(melted_df)


## single row and single value collect
for i in range(0,len(melted_df)):
  single =melted_df.iloc[i]
  type_choose = single[0]
  component = single[1]
  date = single[2]
  amount = single[3]
  print(single[0],single[1],single[2],single[3])

# type_choose
# component
# amount
# date
# Out:
#         Type         Component       Date  Value
# 0     Income            Salary 2018-01-01  30000
# 1     Income          Source 2 2018-01-01   1000
# 2    Savings      Mutual funds 2018-01-01   5000
# 3    Savings    Emergency Fund 2018-01-01   2000
# 4    Savings     Fixed Deposit 2018-01-01   2000
# ..       ...               ...        ...    ...
# 439  Expense  Groceries & Food 2021-01-01   9000
# 440  Expense            Health 2021-01-01   3000
# 441  Expense              EMIs 2021-01-01  12000
# 442  Expense           Leisure 2021-01-01   1500
# 443  Expense          Shopping 2021-01-01   3000
#
# [444 rows x 4 columns]
# Income Salary 2018-01-01 00:00:00 30000
# Income Source 2 2018-01-01 00:00:00 1000
# Savings Mutual funds 2018-01-01 00:00:00 5000
# Savings Emergency Fund 2018-01-01 00:00:00 2000
# Savings Fixed Deposit 2018-01-01 00:00:00 2000
# Savings Liquid Cash 2018-01-01 00:00:00 1000
# Expense House Rent 2018-01-01 00:00:00 10000
# Expense Groceries & Food 2018-01-01 00:00:00 6000
# Expense Health 2018-01-01 00:00:00 1000
# Expense EMIs 2018-01-01 00:00:00 2500
# Expense Leisure 2018-01-01 00:00:00 500
# Expense Shopping 2018-01-01 00:00:00 1000
# Income Salary 2018-02-01 00:00:00 30000
# Income Source 2 2018-02-01 00:00:00 1000
# Savings Mutual funds 2018-02-01 00:00:00 5000
# Savings Emergency Fund 2018-02-01 00:00:00 2000
# Savings Fixed Deposit 2018-02-01 00:00:00 2000
# Savings Liquid Cash 2018-02-01 00:00:00 0
# Expense House Rent 2018-02-01 00:00:00 10000
# Expense Groceries & Food 2018-02-01 00:00:00 6000
# Expense Health 2018-02-01 00:00:00 1000
# Expense EMIs 2018-02-01 00:00:00 2500
# Expense Leisure 2018-02-01 00:00:00 1500
# Expense Shopping 2018-02-01 00:00:00 1000
# Income Salary 2018-03-01 00:00:00 30000
# Income Source 2 2018-03-01 00:00:00 1000
# Savings Mutual funds 2018-03-01 00:00:00 5000
# Savings Emergency Fund 2018-03-01 00:00:00 2000
# Savings Fixed Deposit 2018-03-01 00:00:00 2000
# Savings Liquid Cash 2018-03-01 00:00:00 1000
# Expense House Rent 2018-03-01 00:00:00 10000
# Expense Groceries & Food 2018-03-01 00:00:00 6000
# Expense Health 2018-03-01 00:00:00 1000
# Expense EMIs 2018-03-01 00:00:00 2500
# Expense Leisure 2018-03-01 00:00:00 500
# Expense Shopping 2018-03-01 00:00:00 1000
# Income Salary 2018-04-01 00:00:00 30000
# Income Source 2 2018-04-01 00:00:00 1000
# Savings Mutual funds 2018-04-01 00:00:00 5000
# Savings Emergency Fund 2018-04-01 00:00:00 2000
# Savings Fixed Deposit 2018-04-01 00:00:00 2000
# Savings Liquid Cash 2018-04-01 00:00:00 0
# Expense House Rent 2018-04-01 00:00:00 10000
# Expense Groceries & Food 2018-04-01 00:00:00 6000
# Expense Health 2018-04-01 00:00:00 1000
# Expense EMIs 2018-04-01 00:00:00 2500
# Expense Leisure 2018-04-01 00:00:00 1500
# Expense Shopping 2018-04-01 00:00:00 1000
# Income Salary 2018-05-01 00:00:00 30000
# Income Source 2 2018-05-01 00:00:00 1000
# Savings Mutual funds 2018-05-01 00:00:00 5000
# Savings Emergency Fund 2018-05-01 00:00:00 2000
# Savings Fixed Deposit 2018-05-01 00:00:00 2000
# Savings Liquid Cash 2018-05-01 00:00:00 1000
# Expense House Rent 2018-05-01 00:00:00 10000
# Expense Groceries & Food 2018-05-01 00:00:00 6000
# Expense Health 2018-05-01 00:00:00 1000
# Expense EMIs 2018-05-01 00:00:00 2500
# Expense Leisure 2018-05-01 00:00:00 500
# Expense Shopping 2018-05-01 00:00:00 1000
# Income Salary 2018-06-01 00:00:00 30000
# Income Source 2 2018-06-01 00:00:00 1000
# Savings Mutual funds 2018-06-01 00:00:00 5000
# Savings Emergency Fund 2018-06-01 00:00:00 2000
# Savings Fixed Deposit 2018-06-01 00:00:00 2000
# Savings Liquid Cash 2018-06-01 00:00:00 0
# Expense House Rent 2018-06-01 00:00:00 10000
# Expense Groceries & Food 2018-06-01 00:00:00 6000
# Expense Health 2018-06-01 00:00:00 1000
# Expense EMIs 2018-06-01 00:00:00 2500
# Expense Leisure 2018-06-01 00:00:00 1500
# Expense Shopping 2018-06-01 00:00:00 1000
# Income Salary 2018-07-01 00:00:00 30000
# Income Source 2 2018-07-01 00:00:00 1000
# Savings Mutual funds 2018-07-01 00:00:00 5000
# Savings Emergency Fund 2018-07-01 00:00:00 2000
# Savings Fixed Deposit 2018-07-01 00:00:00 2000
# Savings Liquid Cash 2018-07-01 00:00:00 -1000
# Expense House Rent 2018-07-01 00:00:00 12000
# Expense Groceries & Food 2018-07-01 00:00:00 6000
# Expense Health 2018-07-01 00:00:00 1000
# Expense EMIs 2018-07-01 00:00:00 2500
# Expense Leisure 2018-07-01 00:00:00 500
# Expense Shopping 2018-07-01 00:00:00 1000
# Income Salary 2018-08-01 00:00:00 30000
# Income Source 2 2018-08-01 00:00:00 1000
# Savings Mutual funds 2018-08-01 00:00:00 5000
# Savings Emergency Fund 2018-08-01 00:00:00 0
# Savings Fixed Deposit 2018-08-01 00:00:00 2000
# Savings Liquid Cash 2018-08-01 00:00:00 0
# Expense House Rent 2018-08-01 00:00:00 12000
# Expense Groceries & Food 2018-08-01 00:00:00 6000
# Expense Health 2018-08-01 00:00:00 1000
# Expense EMIs 2018-08-01 00:00:00 2500
# Expense Leisure 2018-08-01 00:00:00 1500
# Expense Shopping 2018-08-01 00:00:00 1000
# Income Salary 2018-09-01 00:00:00 35000
# Income Source 2 2018-09-01 00:00:00 1000
# Savings Mutual funds 2018-09-01 00:00:00 5000
# Savings Emergency Fund 2018-09-01 00:00:00 0
# Savings Fixed Deposit 2018-09-01 00:00:00 0
# Savings Liquid Cash 2018-09-01 00:00:00 1000
# Expense House Rent 2018-09-01 00:00:00 12000
# Expense Groceries & Food 2018-09-01 00:00:00 6000
# Expense Health 2018-09-01 00:00:00 1000
# Expense EMIs 2018-09-01 00:00:00 5000
# Expense Leisure 2018-09-01 00:00:00 4000
# Expense Shopping 2018-09-01 00:00:00 2000
# Income Salary 2018-10-01 00:00:00 35000
# Income Source 2 2018-10-01 00:00:00 1000
# Savings Mutual funds 2018-10-01 00:00:00 5000
# Savings Emergency Fund 2018-10-01 00:00:00 2000
# Savings Fixed Deposit 2018-10-01 00:00:00 2000
# Savings Liquid Cash 2018-10-01 00:00:00 500
# Expense House Rent 2018-10-01 00:00:00 12000
# Expense Groceries & Food 2018-10-01 00:00:00 6000
# Expense Health 2018-10-01 00:00:00 1000
# Expense EMIs 2018-10-01 00:00:00 5000
# Expense Leisure 2018-10-01 00:00:00 1500
# Expense Shopping 2018-10-01 00:00:00 1000
# Income Salary 2018-11-01 00:00:00 35000
# Income Source 2 2018-11-01 00:00:00 1000
# Savings Mutual funds 2018-11-01 00:00:00 5000
# Savings Emergency Fund 2018-11-01 00:00:00 2000
# Savings Fixed Deposit 2018-11-01 00:00:00 0
# Savings Liquid Cash 2018-11-01 00:00:00 2500
# Expense House Rent 2018-11-01 00:00:00 12000
# Expense Groceries & Food 2018-11-01 00:00:00 6000
# Expense Health 2018-11-01 00:00:00 1000
# Expense EMIs 2018-11-01 00:00:00 5000
# Expense Leisure 2018-11-01 00:00:00 1500
# Expense Shopping 2018-11-01 00:00:00 1000
# Income Salary 2018-12-01 00:00:00 35000
# Income Source 2 2018-12-01 00:00:00 1000
# Savings Mutual funds 2018-12-01 00:00:00 7000
# Savings Emergency Fund 2018-12-01 00:00:00 2000
# Savings Fixed Deposit 2018-12-01 00:00:00 0
# Savings Liquid Cash 2018-12-01 00:00:00 -1500
# Expense House Rent 2018-12-01 00:00:00 12000
# Expense Groceries & Food 2018-12-01 00:00:00 8000
# Expense Health 2018-12-01 00:00:00 1000
# Expense EMIs 2018-12-01 00:00:00 5000
# Expense Leisure 2018-12-01 00:00:00 1500
# Expense Shopping 2018-12-01 00:00:00 1000
# Income Salary 2019-01-01 00:00:00 35000
# Income Source 2 2019-01-01 00:00:00 1000
# Savings Mutual funds 2019-01-01 00:00:00 7000
# Savings Emergency Fund 2019-01-01 00:00:00 2000
# Savings Fixed Deposit 2019-01-01 00:00:00 0
# Savings Liquid Cash 2019-01-01 00:00:00 -1000
# Expense House Rent 2019-01-01 00:00:00 12000
# Expense Groceries & Food 2019-01-01 00:00:00 8000
# Expense Health 2019-01-01 00:00:00 3000
# Expense EMIs 2019-01-01 00:00:00 5000
# Expense Leisure 2019-01-01 00:00:00 0
# Expense Shopping 2019-01-01 00:00:00 0
# Income Salary 2019-02-01 00:00:00 35000
# Income Source 2 2019-02-01 00:00:00 4000
# Savings Mutual funds 2019-02-01 00:00:00 7000
# Savings Emergency Fund 2019-02-01 00:00:00 2000
# Savings Fixed Deposit 2019-02-01 00:00:00 2000
# Savings Liquid Cash 2019-02-01 00:00:00 1500
# Expense House Rent 2019-02-01 00:00:00 12000
# Expense Groceries & Food 2019-02-01 00:00:00 7000
# Expense Health 2019-02-01 00:00:00 1500
# Expense EMIs 2019-02-01 00:00:00 6000
# Expense Leisure 2019-02-01 00:00:00 0
# Expense Shopping 2019-02-01 00:00:00 0
# Income Salary 2019-03-01 00:00:00 35000
# Income Source 2 2019-03-01 00:00:00 4000
# Savings Mutual funds 2019-03-01 00:00:00 7000
# Savings Emergency Fund 2019-03-01 00:00:00 2000
# Savings Fixed Deposit 2019-03-01 00:00:00 2000
# Savings Liquid Cash 2019-03-01 00:00:00 1500
# Expense House Rent 2019-03-01 00:00:00 12000
# Expense Groceries & Food 2019-03-01 00:00:00 7000
# Expense Health 2019-03-01 00:00:00 1500
# Expense EMIs 2019-03-01 00:00:00 6000
# Expense Leisure 2019-03-01 00:00:00 0
# Expense Shopping 2019-03-01 00:00:00 0
# Income Salary 2019-04-01 00:00:00 35000
# Income Source 2 2019-04-01 00:00:00 4000
# Savings Mutual funds 2019-04-01 00:00:00 7000
# Savings Emergency Fund 2019-04-01 00:00:00 2000
# Savings Fixed Deposit 2019-04-01 00:00:00 2000
# Savings Liquid Cash 2019-04-01 00:00:00 500
# Expense House Rent 2019-04-01 00:00:00 12000
# Expense Groceries & Food 2019-04-01 00:00:00 7000
# Expense Health 2019-04-01 00:00:00 1500
# Expense EMIs 2019-04-01 00:00:00 6000
# Expense Leisure 2019-04-01 00:00:00 1000
# Expense Shopping 2019-04-01 00:00:00 0
# Income Salary 2019-05-01 00:00:00 35000
# Income Source 2 2019-05-01 00:00:00 4000
# Savings Mutual funds 2019-05-01 00:00:00 7000
# Savings Emergency Fund 2019-05-01 00:00:00 2000
# Savings Fixed Deposit 2019-05-01 00:00:00 2000
# Savings Liquid Cash 2019-05-01 00:00:00 500
# Expense House Rent 2019-05-01 00:00:00 12000
# Expense Groceries & Food 2019-05-01 00:00:00 7000
# Expense Health 2019-05-01 00:00:00 1500
# Expense EMIs 2019-05-01 00:00:00 6000
# Expense Leisure 2019-05-01 00:00:00 1000
# Expense Shopping 2019-05-01 00:00:00 0
# Income Salary 2019-06-01 00:00:00 35000
# Income Source 2 2019-06-01 00:00:00 4000
# Savings Mutual funds 2019-06-01 00:00:00 7000
# Savings Emergency Fund 2019-06-01 00:00:00 2000
# Savings Fixed Deposit 2019-06-01 00:00:00 1000
# Savings Liquid Cash 2019-06-01 00:00:00 500
# Expense House Rent 2019-06-01 00:00:00 12000
# Expense Groceries & Food 2019-06-01 00:00:00 7000
# Expense Health 2019-06-01 00:00:00 1500
# Expense EMIs 2019-06-01 00:00:00 6000
# Expense Leisure 2019-06-01 00:00:00 1000
# Expense Shopping 2019-06-01 00:00:00 1000
# Income Salary 2019-07-01 00:00:00 35000
# Income Source 2 2019-07-01 00:00:00 4000
# Savings Mutual funds 2019-07-01 00:00:00 7000
# Savings Emergency Fund 2019-07-01 00:00:00 2000
# Savings Fixed Deposit 2019-07-01 00:00:00 1000
# Savings Liquid Cash 2019-07-01 00:00:00 0
# Expense House Rent 2019-07-01 00:00:00 12000
# Expense Groceries & Food 2019-07-01 00:00:00 7000
# Expense Health 2019-07-01 00:00:00 1500
# Expense EMIs 2019-07-01 00:00:00 7000
# Expense Leisure 2019-07-01 00:00:00 1500
# Expense Shopping 2019-07-01 00:00:00 0
# Income Salary 2019-08-01 00:00:00 35000
# Income Source 2 2019-08-01 00:00:00 4000
# Savings Mutual funds 2019-08-01 00:00:00 7000
# Savings Emergency Fund 2019-08-01 00:00:00 1000
# Savings Fixed Deposit 2019-08-01 00:00:00 1000
# Savings Liquid Cash 2019-08-01 00:00:00 1000
# Expense House Rent 2019-08-01 00:00:00 12000
# Expense Groceries & Food 2019-08-01 00:00:00 7000
# Expense Health 2019-08-01 00:00:00 1500
# Expense EMIs 2019-08-01 00:00:00 7000
# Expense Leisure 2019-08-01 00:00:00 1500
# Expense Shopping 2019-08-01 00:00:00 0
# Income Salary 2019-09-01 00:00:00 35000
# Income Source 2 2019-09-01 00:00:00 4000
# Savings Mutual funds 2019-09-01 00:00:00 7000
# Savings Emergency Fund 2019-09-01 00:00:00 0
# Savings Fixed Deposit 2019-09-01 00:00:00 2000
# Savings Liquid Cash 2019-09-01 00:00:00 0
# Expense House Rent 2019-09-01 00:00:00 12000
# Expense Groceries & Food 2019-09-01 00:00:00 8000
# Expense Health 2019-09-01 00:00:00 1500
# Expense EMIs 2019-09-01 00:00:00 7000
# Expense Leisure 2019-09-01 00:00:00 1500
# Expense Shopping 2019-09-01 00:00:00 0
# Income Salary 2019-10-01 00:00:00 35000
# Income Source 2 2019-10-01 00:00:00 4000
# Savings Mutual funds 2019-10-01 00:00:00 7000
# Savings Emergency Fund 2019-10-01 00:00:00 0
# Savings Fixed Deposit 2019-10-01 00:00:00 0
# Savings Liquid Cash 2019-10-01 00:00:00 1000
# Expense House Rent 2019-10-01 00:00:00 12000
# Expense Groceries & Food 2019-10-01 00:00:00 8000
# Expense Health 2019-10-01 00:00:00 1500
# Expense EMIs 2019-10-01 00:00:00 7000
# Expense Leisure 2019-10-01 00:00:00 1500
# Expense Shopping 2019-10-01 00:00:00 1000
# Income Salary 2019-11-01 00:00:00 35000
# Income Source 2 2019-11-01 00:00:00 4000
# Savings Mutual funds 2019-11-01 00:00:00 7000
# Savings Emergency Fund 2019-11-01 00:00:00 0
# Savings Fixed Deposit 2019-11-01 00:00:00 0
# Savings Liquid Cash 2019-11-01 00:00:00 -2000
# Expense House Rent 2019-11-01 00:00:00 15000
# Expense Groceries & Food 2019-11-01 00:00:00 8000
# Expense Health 2019-11-01 00:00:00 1500
# Expense EMIs 2019-11-01 00:00:00 7000
# Expense Leisure 2019-11-01 00:00:00 1500
# Expense Shopping 2019-11-01 00:00:00 1000
# Income Salary 2019-12-01 00:00:00 35000
# Income Source 2 2019-12-01 00:00:00 4000
# Savings Mutual funds 2019-12-01 00:00:00 0
# Savings Emergency Fund 2019-12-01 00:00:00 0
# Savings Fixed Deposit 2019-12-01 00:00:00 0
# Savings Liquid Cash 2019-12-01 00:00:00 500
# Expense House Rent 2019-12-01 00:00:00 15000
# Expense Groceries & Food 2019-12-01 00:00:00 10000
# Expense Health 2019-12-01 00:00:00 3000
# Expense EMIs 2019-12-01 00:00:00 7000
# Expense Leisure 2019-12-01 00:00:00 1500
# Expense Shopping 2019-12-01 00:00:00 2000
# Income Salary 2020-01-01 00:00:00 43000
# Income Source 2 2020-01-01 00:00:00 4000
# Savings Mutual funds 2020-01-01 00:00:00 7000
# Savings Emergency Fund 2020-01-01 00:00:00 0
# Savings Fixed Deposit 2020-01-01 00:00:00 0
# Savings Liquid Cash 2020-01-01 00:00:00 -1500
# Expense House Rent 2020-01-01 00:00:00 15000
# Expense Groceries & Food 2020-01-01 00:00:00 10000
# Expense Health 2020-01-01 00:00:00 3000
# Expense EMIs 2020-01-01 00:00:00 10000
# Expense Leisure 2020-01-01 00:00:00 1500
# Expense Shopping 2020-01-01 00:00:00 2000
# Income Salary 2020-02-01 00:00:00 43000
# Income Source 2 2020-02-01 00:00:00 4000
# Savings Mutual funds 2020-02-01 00:00:00 7000
# Savings Emergency Fund 2020-02-01 00:00:00 0
# Savings Fixed Deposit 2020-02-01 00:00:00 0
# Savings Liquid Cash 2020-02-01 00:00:00 -1500
# Expense House Rent 2020-02-01 00:00:00 15000
# Expense Groceries & Food 2020-02-01 00:00:00 10000
# Expense Health 2020-02-01 00:00:00 3000
# Expense EMIs 2020-02-01 00:00:00 10000
# Expense Leisure 2020-02-01 00:00:00 1500
# Expense Shopping 2020-02-01 00:00:00 2000
# Income Salary 2020-03-01 00:00:00 43000
# Income Source 2 2020-03-01 00:00:00 4000
# Savings Mutual funds 2020-03-01 00:00:00 7000
# Savings Emergency Fund 2020-03-01 00:00:00 0
# Savings Fixed Deposit 2020-03-01 00:00:00 0
# Savings Liquid Cash 2020-03-01 00:00:00 0
# Expense House Rent 2020-03-01 00:00:00 15000
# Expense Groceries & Food 2020-03-01 00:00:00 10000
# Expense Health 2020-03-01 00:00:00 3000
# Expense EMIs 2020-03-01 00:00:00 10000
# Expense Leisure 2020-03-01 00:00:00 1500
# Expense Shopping 2020-03-01 00:00:00 500
# Income Salary 2020-04-01 00:00:00 43000
# Income Source 2 2020-04-01 00:00:00 4000
# Savings Mutual funds 2020-04-01 00:00:00 7000
# Savings Emergency Fund 2020-04-01 00:00:00 0
# Savings Fixed Deposit 2020-04-01 00:00:00 0
# Savings Liquid Cash 2020-04-01 00:00:00 500
# Expense House Rent 2020-04-01 00:00:00 15000
# Expense Groceries & Food 2020-04-01 00:00:00 8000
# Expense Health 2020-04-01 00:00:00 3000
# Expense EMIs 2020-04-01 00:00:00 10000
# Expense Leisure 2020-04-01 00:00:00 1500
# Expense Shopping 2020-04-01 00:00:00 2000
# Income Salary 2020-05-01 00:00:00 43000
# Income Source 2 2020-05-01 00:00:00 4000
# Savings Mutual funds 2020-05-01 00:00:00 7000
# Savings Emergency Fund 2020-05-01 00:00:00 2000
# Savings Fixed Deposit 2020-05-01 00:00:00 0
# Savings Liquid Cash 2020-05-01 00:00:00 -1500
# Expense House Rent 2020-05-01 00:00:00 15000
# Expense Groceries & Food 2020-05-01 00:00:00 8000
# Expense Health 2020-05-01 00:00:00 3000
# Expense EMIs 2020-05-01 00:00:00 10000
# Expense Leisure 2020-05-01 00:00:00 1500
# Expense Shopping 2020-05-01 00:00:00 2000
# Income Salary 2020-06-01 00:00:00 43000
# Income Source 2 2020-06-01 00:00:00 4000
# Savings Mutual funds 2020-06-01 00:00:00 7000
# Savings Emergency Fund 2020-06-01 00:00:00 0
# Savings Fixed Deposit 2020-06-01 00:00:00 2000
# Savings Liquid Cash 2020-06-01 00:00:00 1500
# Expense House Rent 2020-06-01 00:00:00 15000
# Expense Groceries & Food 2020-06-01 00:00:00 8000
# Expense Health 2020-06-01 00:00:00 3000
# Expense EMIs 2020-06-01 00:00:00 10000
# Expense Leisure 2020-06-01 00:00:00 500
# Expense Shopping 2020-06-01 00:00:00 0
# Income Salary 2020-07-01 00:00:00 43000
# Income Source 2 2020-07-01 00:00:00 6000
# Savings Mutual funds 2020-07-01 00:00:00 7000
# Savings Emergency Fund 2020-07-01 00:00:00 1000
# Savings Fixed Deposit 2020-07-01 00:00:00 0
# Savings Liquid Cash 2020-07-01 00:00:00 -1500
# Expense House Rent 2020-07-01 00:00:00 15000
# Expense Groceries & Food 2020-07-01 00:00:00 10000
# Expense Health 2020-07-01 00:00:00 3000
# Expense EMIs 2020-07-01 00:00:00 10000
# Expense Leisure 2020-07-01 00:00:00 1500
# Expense Shopping 2020-07-01 00:00:00 3000
# Income Salary 2020-08-01 00:00:00 43000
# Income Source 2 2020-08-01 00:00:00 6000
# Savings Mutual funds 2020-08-01 00:00:00 7000
# Savings Emergency Fund 2020-08-01 00:00:00 1000
# Savings Fixed Deposit 2020-08-01 00:00:00 0
# Savings Liquid Cash 2020-08-01 00:00:00 -2000
# Expense House Rent 2020-08-01 00:00:00 15000
# Expense Groceries & Food 2020-08-01 00:00:00 10000
# Expense Health 2020-08-01 00:00:00 3000
# Expense EMIs 2020-08-01 00:00:00 10000
# Expense Leisure 2020-08-01 00:00:00 3000
# Expense Shopping 2020-08-01 00:00:00 2000
# Income Salary 2020-09-01 00:00:00 43000
# Income Source 2 2020-09-01 00:00:00 6000
# Savings Mutual funds 2020-09-01 00:00:00 7000
# Savings Emergency Fund 2020-09-01 00:00:00 1000
# Savings Fixed Deposit 2020-09-01 00:00:00 2000
# Savings Liquid Cash 2020-09-01 00:00:00 -2500
# Expense House Rent 2020-09-01 00:00:00 15000
# Expense Groceries & Food 2020-09-01 00:00:00 10000
# Expense Health 2020-09-01 00:00:00 3000
# Expense EMIs 2020-09-01 00:00:00 10000
# Expense Leisure 2020-09-01 00:00:00 1500
# Expense Shopping 2020-09-01 00:00:00 2000
# Income Salary 2020-10-01 00:00:00 43000
# Income Source 2 2020-10-01 00:00:00 6000
# Savings Mutual funds 2020-10-01 00:00:00 7000
# Savings Emergency Fund 2020-10-01 00:00:00 1000
# Savings Fixed Deposit 2020-10-01 00:00:00 2000
# Savings Liquid Cash 2020-10-01 00:00:00 -500
# Expense House Rent 2020-10-01 00:00:00 15000
# Expense Groceries & Food 2020-10-01 00:00:00 8000
# Expense Health 2020-10-01 00:00:00 3000
# Expense EMIs 2020-10-01 00:00:00 10000
# Expense Leisure 2020-10-01 00:00:00 1500
# Expense Shopping 2020-10-01 00:00:00 2000
# Income Salary 2020-11-01 00:00:00 51500
# Income Source 2 2020-11-01 00:00:00 6000
# Savings Mutual funds 2020-11-01 00:00:00 8000
# Savings Emergency Fund 2020-11-01 00:00:00 2000
# Savings Fixed Deposit 2020-11-01 00:00:00 2500
# Savings Liquid Cash 2020-11-01 00:00:00 1500
# Expense House Rent 2020-11-01 00:00:00 15000
# Expense Groceries & Food 2020-11-01 00:00:00 10000
# Expense Health 2020-11-01 00:00:00 3000
# Expense EMIs 2020-11-01 00:00:00 12000
# Expense Leisure 2020-11-01 00:00:00 1500
# Expense Shopping 2020-11-01 00:00:00 2000
# Income Salary 2020-12-01 00:00:00 51500
# Income Source 2 2020-12-01 00:00:00 6000
# Savings Mutual funds 2020-12-01 00:00:00 8000
# Savings Emergency Fund 2020-12-01 00:00:00 1000
# Savings Fixed Deposit 2020-12-01 00:00:00 2500
# Savings Liquid Cash 2020-12-01 00:00:00 500
# Expense House Rent 2020-12-01 00:00:00 15000
# Expense Groceries & Food 2020-12-01 00:00:00 10000
# Expense Health 2020-12-01 00:00:00 4000
# Expense EMIs 2020-12-01 00:00:00 12000
# Expense Leisure 2020-12-01 00:00:00 1500
# Expense Shopping 2020-12-01 00:00:00 3000
# Income Salary 2021-01-01 00:00:00 51500
# Income Source 2 2021-01-01 00:00:00 6000
# Savings Mutual funds 2021-01-01 00:00:00 8000
# Savings Emergency Fund 2021-01-01 00:00:00 3000
# Savings Fixed Deposit 2021-01-01 00:00:00 2500
# Savings Liquid Cash 2021-01-01 00:00:00 -500
# Expense House Rent 2021-01-01 00:00:00 16000
# Expense Groceries & Food 2021-01-01 00:00:00 9000
# Expense Health 2021-01-01 00:00:00 3000
# Expense EMIs 2021-01-01 00:00:00 12000
# Expense Leisure 2021-01-01 00:00:00 1500
# Expense Shopping 2021-01-01 00:00:00 3000

# %%
dlist =[]
for i in range(0,len(melted_df)):
  single =melted_df.iloc[i]
  type_choose = single[0]
  component = single[1]
  date = single[2]
  amount = single[3]
  dlist.append((type_choose,component, amount, date))
  # dlist.append((single[0],single[1],single[2],single[3]))
  # print(dlist[0][1])

for i in dlist:
  print(i)
# Out:
# ('Income', 'Salary', 30000, Timestamp('2018-01-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-01-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-01-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-01-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-01-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1000, Timestamp('2018-01-01 00:00:00'))
# ('Expense', 'House Rent', 10000, Timestamp('2018-01-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-01-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-01-01 00:00:00'))
# ('Expense', 'EMIs', 2500, Timestamp('2018-01-01 00:00:00'))
# ('Expense', 'Leisure', 500, Timestamp('2018-01-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-01-01 00:00:00'))
# ('Income', 'Salary', 30000, Timestamp('2018-02-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-02-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-02-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-02-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-02-01 00:00:00'))
# ('Savings', 'Liquid Cash', 0, Timestamp('2018-02-01 00:00:00'))
# ('Expense', 'House Rent', 10000, Timestamp('2018-02-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-02-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-02-01 00:00:00'))
# ('Expense', 'EMIs', 2500, Timestamp('2018-02-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2018-02-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-02-01 00:00:00'))
# ('Income', 'Salary', 30000, Timestamp('2018-03-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-03-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-03-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-03-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-03-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1000, Timestamp('2018-03-01 00:00:00'))
# ('Expense', 'House Rent', 10000, Timestamp('2018-03-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-03-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-03-01 00:00:00'))
# ('Expense', 'EMIs', 2500, Timestamp('2018-03-01 00:00:00'))
# ('Expense', 'Leisure', 500, Timestamp('2018-03-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-03-01 00:00:00'))
# ('Income', 'Salary', 30000, Timestamp('2018-04-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-04-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-04-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-04-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-04-01 00:00:00'))
# ('Savings', 'Liquid Cash', 0, Timestamp('2018-04-01 00:00:00'))
# ('Expense', 'House Rent', 10000, Timestamp('2018-04-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-04-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-04-01 00:00:00'))
# ('Expense', 'EMIs', 2500, Timestamp('2018-04-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2018-04-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-04-01 00:00:00'))
# ('Income', 'Salary', 30000, Timestamp('2018-05-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-05-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-05-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-05-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-05-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1000, Timestamp('2018-05-01 00:00:00'))
# ('Expense', 'House Rent', 10000, Timestamp('2018-05-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-05-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-05-01 00:00:00'))
# ('Expense', 'EMIs', 2500, Timestamp('2018-05-01 00:00:00'))
# ('Expense', 'Leisure', 500, Timestamp('2018-05-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-05-01 00:00:00'))
# ('Income', 'Salary', 30000, Timestamp('2018-06-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-06-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-06-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-06-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-06-01 00:00:00'))
# ('Savings', 'Liquid Cash', 0, Timestamp('2018-06-01 00:00:00'))
# ('Expense', 'House Rent', 10000, Timestamp('2018-06-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-06-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-06-01 00:00:00'))
# ('Expense', 'EMIs', 2500, Timestamp('2018-06-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2018-06-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-06-01 00:00:00'))
# ('Income', 'Salary', 30000, Timestamp('2018-07-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-07-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-07-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-07-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-07-01 00:00:00'))
# ('Savings', 'Liquid Cash', -1000, Timestamp('2018-07-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2018-07-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-07-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-07-01 00:00:00'))
# ('Expense', 'EMIs', 2500, Timestamp('2018-07-01 00:00:00'))
# ('Expense', 'Leisure', 500, Timestamp('2018-07-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-07-01 00:00:00'))
# ('Income', 'Salary', 30000, Timestamp('2018-08-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-08-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-08-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2018-08-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-08-01 00:00:00'))
# ('Savings', 'Liquid Cash', 0, Timestamp('2018-08-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2018-08-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-08-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-08-01 00:00:00'))
# ('Expense', 'EMIs', 2500, Timestamp('2018-08-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2018-08-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-08-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2018-09-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-09-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-09-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2018-09-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2018-09-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1000, Timestamp('2018-09-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2018-09-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-09-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-09-01 00:00:00'))
# ('Expense', 'EMIs', 5000, Timestamp('2018-09-01 00:00:00'))
# ('Expense', 'Leisure', 4000, Timestamp('2018-09-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2018-09-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2018-10-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-10-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-10-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-10-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2018-10-01 00:00:00'))
# ('Savings', 'Liquid Cash', 500, Timestamp('2018-10-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2018-10-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-10-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-10-01 00:00:00'))
# ('Expense', 'EMIs', 5000, Timestamp('2018-10-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2018-10-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-10-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2018-11-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-11-01 00:00:00'))
# ('Savings', 'Mutual funds', 5000, Timestamp('2018-11-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-11-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2018-11-01 00:00:00'))
# ('Savings', 'Liquid Cash', 2500, Timestamp('2018-11-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2018-11-01 00:00:00'))
# ('Expense', 'Groceries & Food', 6000, Timestamp('2018-11-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-11-01 00:00:00'))
# ('Expense', 'EMIs', 5000, Timestamp('2018-11-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2018-11-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-11-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2018-12-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2018-12-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2018-12-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2018-12-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2018-12-01 00:00:00'))
# ('Savings', 'Liquid Cash', -1500, Timestamp('2018-12-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2018-12-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2018-12-01 00:00:00'))
# ('Expense', 'Health', 1000, Timestamp('2018-12-01 00:00:00'))
# ('Expense', 'EMIs', 5000, Timestamp('2018-12-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2018-12-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2018-12-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-01-01 00:00:00'))
# ('Income', 'Source 2', 1000, Timestamp('2019-01-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-01-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2019-01-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2019-01-01 00:00:00'))
# ('Savings', 'Liquid Cash', -1000, Timestamp('2019-01-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-01-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2019-01-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2019-01-01 00:00:00'))
# ('Expense', 'EMIs', 5000, Timestamp('2019-01-01 00:00:00'))
# ('Expense', 'Leisure', 0, Timestamp('2019-01-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2019-01-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-02-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-02-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-02-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2019-02-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2019-02-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1500, Timestamp('2019-02-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-02-01 00:00:00'))
# ('Expense', 'Groceries & Food', 7000, Timestamp('2019-02-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-02-01 00:00:00'))
# ('Expense', 'EMIs', 6000, Timestamp('2019-02-01 00:00:00'))
# ('Expense', 'Leisure', 0, Timestamp('2019-02-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2019-02-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-03-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-03-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-03-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2019-03-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2019-03-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1500, Timestamp('2019-03-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-03-01 00:00:00'))
# ('Expense', 'Groceries & Food', 7000, Timestamp('2019-03-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-03-01 00:00:00'))
# ('Expense', 'EMIs', 6000, Timestamp('2019-03-01 00:00:00'))
# ('Expense', 'Leisure', 0, Timestamp('2019-03-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2019-03-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-04-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-04-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-04-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2019-04-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2019-04-01 00:00:00'))
# ('Savings', 'Liquid Cash', 500, Timestamp('2019-04-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-04-01 00:00:00'))
# ('Expense', 'Groceries & Food', 7000, Timestamp('2019-04-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-04-01 00:00:00'))
# ('Expense', 'EMIs', 6000, Timestamp('2019-04-01 00:00:00'))
# ('Expense', 'Leisure', 1000, Timestamp('2019-04-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2019-04-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-05-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-05-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-05-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2019-05-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2019-05-01 00:00:00'))
# ('Savings', 'Liquid Cash', 500, Timestamp('2019-05-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-05-01 00:00:00'))
# ('Expense', 'Groceries & Food', 7000, Timestamp('2019-05-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-05-01 00:00:00'))
# ('Expense', 'EMIs', 6000, Timestamp('2019-05-01 00:00:00'))
# ('Expense', 'Leisure', 1000, Timestamp('2019-05-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2019-05-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-06-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-06-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-06-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2019-06-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 1000, Timestamp('2019-06-01 00:00:00'))
# ('Savings', 'Liquid Cash', 500, Timestamp('2019-06-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-06-01 00:00:00'))
# ('Expense', 'Groceries & Food', 7000, Timestamp('2019-06-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-06-01 00:00:00'))
# ('Expense', 'EMIs', 6000, Timestamp('2019-06-01 00:00:00'))
# ('Expense', 'Leisure', 1000, Timestamp('2019-06-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2019-06-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-07-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-07-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-07-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2019-07-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 1000, Timestamp('2019-07-01 00:00:00'))
# ('Savings', 'Liquid Cash', 0, Timestamp('2019-07-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-07-01 00:00:00'))
# ('Expense', 'Groceries & Food', 7000, Timestamp('2019-07-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-07-01 00:00:00'))
# ('Expense', 'EMIs', 7000, Timestamp('2019-07-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2019-07-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2019-07-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-08-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-08-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-08-01 00:00:00'))
# ('Savings', 'Emergency Fund', 1000, Timestamp('2019-08-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 1000, Timestamp('2019-08-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1000, Timestamp('2019-08-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-08-01 00:00:00'))
# ('Expense', 'Groceries & Food', 7000, Timestamp('2019-08-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-08-01 00:00:00'))
# ('Expense', 'EMIs', 7000, Timestamp('2019-08-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2019-08-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2019-08-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-09-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-09-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-09-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2019-09-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2019-09-01 00:00:00'))
# ('Savings', 'Liquid Cash', 0, Timestamp('2019-09-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-09-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2019-09-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-09-01 00:00:00'))
# ('Expense', 'EMIs', 7000, Timestamp('2019-09-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2019-09-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2019-09-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-10-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-10-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-10-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2019-10-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2019-10-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1000, Timestamp('2019-10-01 00:00:00'))
# ('Expense', 'House Rent', 12000, Timestamp('2019-10-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2019-10-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-10-01 00:00:00'))
# ('Expense', 'EMIs', 7000, Timestamp('2019-10-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2019-10-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2019-10-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-11-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-11-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2019-11-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2019-11-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2019-11-01 00:00:00'))
# ('Savings', 'Liquid Cash', -2000, Timestamp('2019-11-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2019-11-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2019-11-01 00:00:00'))
# ('Expense', 'Health', 1500, Timestamp('2019-11-01 00:00:00'))
# ('Expense', 'EMIs', 7000, Timestamp('2019-11-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2019-11-01 00:00:00'))
# ('Expense', 'Shopping', 1000, Timestamp('2019-11-01 00:00:00'))
# ('Income', 'Salary', 35000, Timestamp('2019-12-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2019-12-01 00:00:00'))
# ('Savings', 'Mutual funds', 0, Timestamp('2019-12-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2019-12-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2019-12-01 00:00:00'))
# ('Savings', 'Liquid Cash', 500, Timestamp('2019-12-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2019-12-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2019-12-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2019-12-01 00:00:00'))
# ('Expense', 'EMIs', 7000, Timestamp('2019-12-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2019-12-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2019-12-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-01-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2020-01-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-01-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2020-01-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2020-01-01 00:00:00'))
# ('Savings', 'Liquid Cash', -1500, Timestamp('2020-01-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-01-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2020-01-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-01-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-01-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-01-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2020-01-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-02-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2020-02-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-02-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2020-02-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2020-02-01 00:00:00'))
# ('Savings', 'Liquid Cash', -1500, Timestamp('2020-02-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-02-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2020-02-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-02-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-02-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-02-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2020-02-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-03-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2020-03-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-03-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2020-03-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2020-03-01 00:00:00'))
# ('Savings', 'Liquid Cash', 0, Timestamp('2020-03-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-03-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2020-03-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-03-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-03-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-03-01 00:00:00'))
# ('Expense', 'Shopping', 500, Timestamp('2020-03-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-04-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2020-04-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-04-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2020-04-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2020-04-01 00:00:00'))
# ('Savings', 'Liquid Cash', 500, Timestamp('2020-04-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-04-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2020-04-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-04-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-04-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-04-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2020-04-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-05-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2020-05-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-05-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2020-05-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2020-05-01 00:00:00'))
# ('Savings', 'Liquid Cash', -1500, Timestamp('2020-05-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-05-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2020-05-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-05-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-05-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-05-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2020-05-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-06-01 00:00:00'))
# ('Income', 'Source 2', 4000, Timestamp('2020-06-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-06-01 00:00:00'))
# ('Savings', 'Emergency Fund', 0, Timestamp('2020-06-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2020-06-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1500, Timestamp('2020-06-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-06-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2020-06-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-06-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-06-01 00:00:00'))
# ('Expense', 'Leisure', 500, Timestamp('2020-06-01 00:00:00'))
# ('Expense', 'Shopping', 0, Timestamp('2020-06-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-07-01 00:00:00'))
# ('Income', 'Source 2', 6000, Timestamp('2020-07-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-07-01 00:00:00'))
# ('Savings', 'Emergency Fund', 1000, Timestamp('2020-07-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2020-07-01 00:00:00'))
# ('Savings', 'Liquid Cash', -1500, Timestamp('2020-07-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-07-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2020-07-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-07-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-07-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-07-01 00:00:00'))
# ('Expense', 'Shopping', 3000, Timestamp('2020-07-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-08-01 00:00:00'))
# ('Income', 'Source 2', 6000, Timestamp('2020-08-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-08-01 00:00:00'))
# ('Savings', 'Emergency Fund', 1000, Timestamp('2020-08-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 0, Timestamp('2020-08-01 00:00:00'))
# ('Savings', 'Liquid Cash', -2000, Timestamp('2020-08-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-08-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2020-08-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-08-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-08-01 00:00:00'))
# ('Expense', 'Leisure', 3000, Timestamp('2020-08-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2020-08-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-09-01 00:00:00'))
# ('Income', 'Source 2', 6000, Timestamp('2020-09-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-09-01 00:00:00'))
# ('Savings', 'Emergency Fund', 1000, Timestamp('2020-09-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2020-09-01 00:00:00'))
# ('Savings', 'Liquid Cash', -2500, Timestamp('2020-09-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-09-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2020-09-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-09-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-09-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-09-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2020-09-01 00:00:00'))
# ('Income', 'Salary', 43000, Timestamp('2020-10-01 00:00:00'))
# ('Income', 'Source 2', 6000, Timestamp('2020-10-01 00:00:00'))
# ('Savings', 'Mutual funds', 7000, Timestamp('2020-10-01 00:00:00'))
# ('Savings', 'Emergency Fund', 1000, Timestamp('2020-10-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2000, Timestamp('2020-10-01 00:00:00'))
# ('Savings', 'Liquid Cash', -500, Timestamp('2020-10-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-10-01 00:00:00'))
# ('Expense', 'Groceries & Food', 8000, Timestamp('2020-10-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-10-01 00:00:00'))
# ('Expense', 'EMIs', 10000, Timestamp('2020-10-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-10-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2020-10-01 00:00:00'))
# ('Income', 'Salary', 51500, Timestamp('2020-11-01 00:00:00'))
# ('Income', 'Source 2', 6000, Timestamp('2020-11-01 00:00:00'))
# ('Savings', 'Mutual funds', 8000, Timestamp('2020-11-01 00:00:00'))
# ('Savings', 'Emergency Fund', 2000, Timestamp('2020-11-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2500, Timestamp('2020-11-01 00:00:00'))
# ('Savings', 'Liquid Cash', 1500, Timestamp('2020-11-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-11-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2020-11-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2020-11-01 00:00:00'))
# ('Expense', 'EMIs', 12000, Timestamp('2020-11-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-11-01 00:00:00'))
# ('Expense', 'Shopping', 2000, Timestamp('2020-11-01 00:00:00'))
# ('Income', 'Salary', 51500, Timestamp('2020-12-01 00:00:00'))
# ('Income', 'Source 2', 6000, Timestamp('2020-12-01 00:00:00'))
# ('Savings', 'Mutual funds', 8000, Timestamp('2020-12-01 00:00:00'))
# ('Savings', 'Emergency Fund', 1000, Timestamp('2020-12-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2500, Timestamp('2020-12-01 00:00:00'))
# ('Savings', 'Liquid Cash', 500, Timestamp('2020-12-01 00:00:00'))
# ('Expense', 'House Rent', 15000, Timestamp('2020-12-01 00:00:00'))
# ('Expense', 'Groceries & Food', 10000, Timestamp('2020-12-01 00:00:00'))
# ('Expense', 'Health', 4000, Timestamp('2020-12-01 00:00:00'))
# ('Expense', 'EMIs', 12000, Timestamp('2020-12-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2020-12-01 00:00:00'))
# ('Expense', 'Shopping', 3000, Timestamp('2020-12-01 00:00:00'))
# ('Income', 'Salary', 51500, Timestamp('2021-01-01 00:00:00'))
# ('Income', 'Source 2', 6000, Timestamp('2021-01-01 00:00:00'))
# ('Savings', 'Mutual funds', 8000, Timestamp('2021-01-01 00:00:00'))
# ('Savings', 'Emergency Fund', 3000, Timestamp('2021-01-01 00:00:00'))
# ('Savings', 'Fixed Deposit', 2500, Timestamp('2021-01-01 00:00:00'))
# ('Savings', 'Liquid Cash', -500, Timestamp('2021-01-01 00:00:00'))
# ('Expense', 'House Rent', 16000, Timestamp('2021-01-01 00:00:00'))
# ('Expense', 'Groceries & Food', 9000, Timestamp('2021-01-01 00:00:00'))
# ('Expense', 'Health', 3000, Timestamp('2021-01-01 00:00:00'))
# ('Expense', 'EMIs', 12000, Timestamp('2021-01-01 00:00:00'))
# ('Expense', 'Leisure', 1500, Timestamp('2021-01-01 00:00:00'))
# ('Expense', 'Shopping', 3000, Timestamp('2021-01-01 00:00:00'))

# %%
len(dlist)
# Out:
# 444

# %%
import mysql.connector
host="localhost"
user = "root"
password = "Azsxdcf123@"
database = "personalfinancedb"
# connect to my sql
conn = mysql.connector.connect(host=host,user=user, password = password,
                               database =database)
cursor = conn.cursor()
data_to_insert =dlist

#sql query to insert data into table
insert_query = "INSERT INTO home_daily_add_model_demo (type_choose,component, amount, date) VALUES (%s,%s,%s,%s)"

cursor.executemany(insert_query,data_to_insert)

conn.commit()
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     301         try:
# --> 302             self._cmysql.connect(**cnx_kwargs)
#     303             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (99)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-149-ea82224d1b28> in <cell line: 7>()
#       5 database = "personalfinancedb"
#       6 # connect to my sql
# ----> 7 conn = mysql.connector.connect(host=host,user=user, password = password,
#       8                                database =database)
#       9 cursor = conn.cursor()
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     291
#     292     if CMySQLConnection and not use_pure:
# --> 293         return CMySQLConnection(*args, **kwargs)
#     294     return MySQLConnection(*args, **kwargs)
#     295
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in __init__(self, **kwargs)
#     126         if kwargs:
#     127             try:
# --> 128                 self.connect(**kwargs)
#     129             except Exception:
#     130                 self.close()
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#    1215
#    1216         self.disconnect()
# -> 1217         self._open_connection()
#    1218         # Server does not allow to run any other statement different from ALTER
#    1219         # when user's password has been expired.
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     305                 self.converter.str_fallback = self._converter_str_fallback
#     306         except MySQLInterfaceError as err:
# --> 307             raise get_mysql_exception(
#     308                 msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     309             ) from err
#
# DatabaseError: 2003 (HY000): Can't connect to MySQL server on 'localhost:3306' (99)

# %%
# home_transfer_amount_model (personalfinancedb)

# piviot the table using melt
melted_df = pd.melt(data, id_vars=['Type', 'Component'], var_name='Date', value_name='Value')
melted_df["Date"] = pd.to_datetime(melted_df["Date"],format='%b-%y')
print(melted_df)
melted_df.to_excel("finance_piviot.xlsx")
# Out:
#         Type         Component       Date  Value
# 0     Income            Salary 2018-01-01  30000
# 1     Income          Source 2 2018-01-01   1000
# 2    Savings      Mutual funds 2018-01-01   5000
# 3    Savings    Emergency Fund 2018-01-01   2000
# 4    Savings     Fixed Deposit 2018-01-01   2000
# ..       ...               ...        ...    ...
# 439  Expense  Groceries & Food 2021-01-01   9000
# 440  Expense            Health 2021-01-01   3000
# 441  Expense              EMIs 2021-01-01  12000
# 442  Expense           Leisure 2021-01-01   1500
# 443  Expense          Shopping 2021-01-01   3000
#
# [444 rows x 4 columns]

# %%
#  melted_df["Date"] = pd.to_datetime(melted_df["Date"],format='%b-%y')
#  melted_df
pd.read_excel("finance_piviot.xlsx")
# Out:
#      Unnamed: 0     Type         Component       Date  Value
# 0             0   Income            Salary 2018-01-01  30000
# 1             1   Income          Source 2 2018-01-01   1000
# 2             2  Savings      Mutual funds 2018-01-01   5000
# 3             3  Savings    Emergency Fund 2018-01-01   2000
# 4             4  Savings     Fixed Deposit 2018-01-01   2000
# ..          ...      ...               ...        ...    ...
# 439         439  Expense  Groceries & Food 2021-01-01   9000
# 440         440  Expense            Health 2021-01-01   3000
# 441         441  Expense              EMIs 2021-01-01  12000
# 442         442  Expense           Leisure 2021-01-01   1500
# 443         443  Expense          Shopping 2021-01-01   3000
#
# [444 rows x 5 columns]

# %%
import requests
from bs4 import BeautifulSoup

# Replace 'url_of_the_website' with the actual URL of the website you want to interact with
url = 'http://127.0.0.1:8000/dailyadd'

# Step 1: Use Requests to get the form and parse the HTML content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Step 2: Locate the form and its input fields (use the 'name' or 'id' attributes of the input fields)
form = soup.find('form', {'id': 'form_id'})
input_field1 = form.find('input', {'name': 'input_field1_name'})
input_field2 = form.find('input', {'name': 'input_field2_name'})

# Step 3: Fill the form with data you want to enter
data = {
    'input_field1_name': 'value_for_input_field1',
    'input_field2_name': 'value_for_input_field2',
    # Add more data for other input fields if needed
}

# Step 4: Submit the form using Requests
response = requests.post(url, data=data)

# Optional: Check the response to verify if the form was submitted successfully
print(response.text)
