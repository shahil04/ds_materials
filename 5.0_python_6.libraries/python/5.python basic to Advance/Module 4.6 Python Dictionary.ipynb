# %% [markdown]
# ## Dictionary data type
# A dictionary is a mutable, unordered collection of key-value pairs in Python where:

# %%
# syntax
#  variable = {key1: value1, key2: value2}

# %%
# d313 =[""]
# id313 =[""]

# d302 =[""]

# create a dictionary
d1 ={}
print(type(d1))

d2 = dict()
print(type(d1))

# syntax of dict
# {key : value/values}
d313 = {"name": "raj", "id":1}
print(type(d313))
d313

# %%
# create  a dicionary
std1 ={"name":"sumit", "id":2 , "class":"data science" }

# %%
# call/read value
std1["class"]
# Out:
# 'data science'

# %%
std1["id"] = 5
# assign value
d313["id"]  =10
d313

# %%
std1
# Out:
# {'name': 'sumit', 'id': 5, 'class': 'data science'}

# %%
# country name as key or country capital as value --> 4 country
countries = {"india":"delhi",
             "pakistan":"islamabad",
             "bangladesh":"dhaka",
             "nepal":"kathmandu"
             }

# %%
# accesss the value
countries["nepal"]
countries.get("nepal")
# Out:
# 'kathmandu'

# %%
# methods
# only want keys
countries.keys()

# only values
countries.values()

# items
countries.items()
# Out:
# dict_items([('india', 'delhi'), ('pakistan', 'islamabad'), ('bangladesh', 'dhaka'), ('nepal', 'kathmandu')])

# %%
# items
list(countries.items())[2][1]
# Out:
# 'dhaka'

# %%
# itrate a dictionary:
for i in countries.values():
    print(i)
# Out:
# new delhi
# islamabad
# dhaka
# kathmandu
# colombo

# %%
for  i,j in countries.items():
    print(f"country name {i} and there capital is {j}")
    print("====")
# Out:
# country name india and there capital is new delhi
# ====
# country name pakistan and there capital is islamabad
# ====
# country name bangladesh and there capital is dhaka
# ====
# country name nepal and there capital is kathmandu
# ====
# country name srilanka and there capital is colombo
# ====

# %% [markdown]
# # methods

# %%
# read value
countries.get("india")

countries["india"]
# Out:
# 'delhi'

# %%
# Add Items to a Dictionary
countries["srilanka"] = "colombo"

# add new value in dict
countries.update({"america":"Washington"})
countries

# %%
# Change/update Dictionary Items
countries["america"] = "washington DC"

countries.update({"india":"new delhi"})
countries

# %%
# Remove Dictionary Items
countries.pop("america") # delete specific key value

# %%
# delete the last key:value from dict use --> popitem()
countries.popitem()

# %%
# Iterate Through a Dictionary
for i,j in countries.items():
    print(f"country name {i} and there capital is {j}")
    print("====")
# country name india and there capital is new delhi

# %%
countries.fromkeys("nepal") # convert data change it as key
countries.setdefault("nepal")

# %%
# Find Dictionary Length
len(countries)

# %%
# Dictionary Membership Test
"india" in countries

# use
if  "india" in countries:
    print("yes")
else:
    print("no")

# %%
# Write a Program to merge two dictionaries.
d1 ={1:"a", 2:"b"}
d2 ={3:"c", 4:"d"}
d1.update(d2)
d1
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
# Q.questions
#
# Inventory Management System

# Maintain a dictionary for login credentials and verify user login.
# store a customers/students details.
student_details ={"id":1 , "name":"sumit","ph":76586767767,"gmail":"sumit@gmial.com", "class":"data science" }

# %%
student_details= {"id":[1,2],
                  "name":["sumit","yuvraj"],
                  "ph":[76586767767,9898954545],
                  "gmail":["sumit@gmial.com","yuvraj@gmail.com"],
                  "class":["data science" ,"dsda"]}

# %%
student_details
# Out:
# {'id': [1, 2],
#  'name': ['sumit', 'yuvraj'],
#  'ph': [76586767767, 9898954545],
#  'gmail': ['sumit@gmial.com', 'yuvraj@gmail.com'],
#  'class': ['data science', 'dsda']}

# %%
student_details["name"]
# Out:
# ['sumit', 'yuvraj', 'rahul', 'rahul']

# %%
# add a new student in student details
student_details["id"].append(3)
student_details["name"].append("rahul")
student_details["ph"].append(9898954545)
student_details["gmail"].append("rahul@gmail.com")
student_details["class"].append("data science")

# %%
student_details
# Out:
# {'id': [1, 2, 3],
#  'name': ['sumit', 'yuvraj', 'rahul'],
#  'ph': [76586767767, 9898954545, 9898954545],
#  'gmail': ['sumit@gmial.com', 'yuvraj@gmail.com', 'rahul@gmail.com'],
#  'class': ['data science', 'dsda', 'data science']}

# %%
# details of 1 students
# find the dtails of yuvraj
roll = 2
print(student_details["id"][roll])
print(student_details["name"][roll])
print(student_details["ph"][roll])
print(student_details["gmail"][roll])

# format the details in f string
print(f"roll is {student_details['id'][roll]}")

# %%
search = input("enter the name of student ")
index_number = student_details["name"].index(search)
index_number
# Out:
# enter the name of student sumit
# 0

# %%
roll =   student_details["id"][index_number]
name =   student_details["name"][index_number]
ph =     student_details["ph"][index_number]
gmail =  student_details["gmail"][index_number]
course = student_details["class"][index_number]

print(f"roll is {roll} \nname is {name} \nph is {ph} \ngmail is {gmail} \ncourse {course}")
# Out:
# roll is 1
# name is sumit
# ph is 76586767767
# gmail is sumit@gmial.com
# coursedata science

# %%
search = input("enter the name of student ")
if search in student_details["name"]:
  index_number = student_details["name"].index(search)
  index_number
  roll =   student_details["id"][index_number]
  name =   student_details["name"][index_number]
  ph =     student_details["ph"][index_number]
  gmail =  student_details["gmail"][index_number]
  course = student_details["class"][index_number]

  print(f"roll is {roll} \nname is {name} \nph is {ph} \ngmail is {gmail} \ncourse {course}")

else:
  print("student not found")
# Out:
# enter the name of student raj
# student not found

# %%
# 🛒 Shopping Cart management System:
#  Store items in a cart with item name as key and quantity as value. Allow adding, updating, and removing items.

# add
product= input("enter the product name")
quantity = int(input("enter the quantity"))

cart[product]=quantity
cart

# update the cart value
product= input("enter the product name which you want to update")
quantity = int(input("enter the new  quantity"))

cart[product]=quantity
cart

# %%
cart={}

# add
def add_to_cart():
  product= input("enter the product name")
  quantity = int(input("enter the quantity"))

  cart[product]=quantity
  cart

# update the cart value
def update_cart():
  product= input("enter the product name which you want to update")
  quantity = int(input("enter the new  quantity"))

  cart[product]=quantity
  cart

# Delete the product
def delete_product():
  product= input("enter the product name which you want to delete: ")
  print(cart.keys())
  if product in cart.keys():
    cart.pop(product)
  else:
    print("product not found")
  cart

# %%
def xyz():
  flag = True
  while flag:
    print("===========================")
    print("press 1 .to add product")
    print("press 2 .to update product")
    print("press 3 .to delete product")
    print("press 4 .to show cart")
    print("press 5 .to exit")

    user_choice = int(input("enter your choice"))
    if user_choice ==1:
      add_to_cart()

    elif user_choice ==2:
      update_cart()

    elif user_choice ==3:
      delete_product()

    elif user_choice ==4:
      print(cart)

    else:
      flag =False
      print("buy successfully ")
      print("exit")

# %%
cart={}

# add
def add_to_cart():
  product= input("enter the product name:  ")
  quantity = int(input("enter the quantity:  "))

  cart[product]=quantity  #
  cart

# update the cart value
def update_cart():
  product= input("enter the product name which you want to update: ")
  quantity = int(input("enter the new  quantity: "))
  cart[product]=quantity


# Delete the product
def delete_product():
  product= input("enter the product name which you want to delete: ")
  print(cart.keys())
  if product in cart.keys():
    cart.pop(product)
  else:
    print("product not found ")
  cart



def main():
    flag = True
    while flag:
        print()
        print("===========================")
        print("press 1 .to add product")
        print("press 2 .to update product")
        print("press 3 .to delete product")
        print("press 4 .to show cart")
        print("press 5 .to Buy")
        print("==========================")

        user_choice = int(input("enter your choice:  "))
        if user_choice ==1:
            add_to_cart()

        elif user_choice ==2:
            update_cart()

        elif user_choice ==3:
            delete_product()

        elif user_choice ==4:
            print(cart)

        else:
            flag =False
            print("buy successfully ")
            print("exit")


main()
