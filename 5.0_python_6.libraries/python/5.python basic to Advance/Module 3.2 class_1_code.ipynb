# %%
5

# %%
# functions

# %%
# print is a function to print the massage  -->
print("hello world")

# %% [markdown]
# # comments
# Comments are hints that we add to our code to make it easier to understand. Python comments start with #. For example,

# %%
# add and print 2 numbers
sum([4,5])

# %%
# multi-line comments
# you write a more than 1 line comments

# also use triple quote for multilne comments // doc string

"""
it is multiline string
Here, the code runs without any errors.

We have resolved the error using a comment.
Now if you need to calculate the product in the near future, you can uncomment it.
"""

print("add multiline comments")

# %% [markdown]
# ### Why Use Comments?
# We should use comments:
#
# For future references, as comments make our code readable.
#
# For debugging.
#
# For code collaboration, as comments help peer developers to understand
# each other's code.

# %%
# if you are using nootebook --> last line will be automatically print
4
5
56

# %%
print(4)
print(5)
7
print(46)
90

# %%
total = sum( [4,5,6,7])
print( total )

# %% [markdown]
# ## Variables

# %%
# rules of write variable
# 1. variable never start with number
# 2. use meaningful names as variable
# 3. if using long meaningful name use _ underscore or Camelcase
# 4. never use keywords as variables

# %%
# 1. variable never start with number
1total = sum( [4,5,6,7])

# %%
total1 = sum( [4,5,6,7])
print( total1 )

# %%
# 2. use meaningful names as variable
dsds = sum( [4,5,6,7])
print( dsds )

# %%
# 3. if using long meaningful name use _ underscore or Camelcase
total sales = sum( [4,5,6,7])

# %%
total_sales = sum( [4,5,6,7])

# %%
print(total_sales)

# %%
# camelcase
TotalSales = sum( [4,5,6,7])

# %%
# 4. never use keywords as variables
if = sum( [4,5,6,7])

# %%
# Keywords
# False, None, True, and, as, assert, async, await, break, class, continue, def, del, elif, else, except, finally, for, from, global, if, import, in, is, lambda, nonlocal, not, or, pass, raise, return, try, while, with, yield

# %% [markdown]
# <!-- ![](https://beginnersbook.com/wp-content/uploads/2019/03/Python_keywords-1024x485.jpg) -->
# ![]()

# %% [markdown]
# ## 2.Litrals
#
# Literals are representations of fixed values in a program. They can be numbers, characters, or strings, etc. For example, 'Hello, World!', 12, 23.0, 'C', etc.

# %%
name ="raj "
# here name  is variable
# and  "raj " is a  litrals (string litrals)

# %%
name

# %%
# none use for noting assign
name = None

# %%
roll_no

# it show the nameerror -- because it not define

# %%
"roll_no"

# %%
roll_no =34

# %%
roll_no
# how to call variable --> using variable name to call

# %% [markdown]
# ## Python Operators
#
# Operators in Python are special symbols or keywords that perform operations on variables and values.

# %%
# 1.airthmetic operators --> +-*%/
# 2.relational / comperisional operators

# 3.Assignment Operators
# 4.logical operators
# 5.tarniary operators
# 6.bitwise
# 7.Special Operators
    # membership operator
    # Identity operators

# %%
# operators
buy =100
sale =120
profit = sale - buy

sale
print(profit)
buy

# %%
# divide --> return float
20/3

# %%
# Floor Division --> return interger
20//3

# %%
round(6.666666666666667, 2)

# %%
# modulo --? %  -->return reminder
20 % 3

# %%
# power --> use for get the power of value
3**4

# %%
num1 = 2
num2 = 3

# %%
num1 + num2

# %%
print("sum of 2 number " , num1 + num2)

# %% [markdown]
# ### relational / comperisional operators -->  ><>=,<=, == ,!=
# == (Equal to)
# != (Not equal to)
# > (Greater than)
# < (Less than)
# >= (Greater than or equal to)
# <= (Less than or equal to)

# %%
# = and ==
std = "raj"   # = use for value assign
print(std)

# %%
# == use for compare the equality of value
"raj" =="raj"
# comperisional operators return only true or false

# %%
"raj" =="Raj"
5==5
# python case sensetive

# %%
# != not equal to
"raj" !="Raj"
5 !=5

# %%
# < less then
5<20

# %%
5<5

# %%
# less equal to
5<=5

# %%
# < greater then
5>20

# %%
# <= greater then equal
5>=20

# %% [markdown]
# ### 4.Python Assignment Operators

# %%
# Python Assignment Operators
# single = for assign operaotrs
sales =20

# %%
sales

# %%
sales = 45
sales

# %%
sales + 30

# %%
sales

# %%
# reassign in same variable
total_sales = sales +30
total_sales

# %%
# reassign in same variable
sales = sales +30
sales

# %%
# short forms += assign
sales += 20
# sales = sales +20

# %%
sales

# %%
sales =10
sales

# %% [markdown]
# += (Addition Assignment): x += y is equivalent to x = x + y
#
# -= (Subtraction Assignment): x -= y is equivalent to x = x - y
#
# *= (Multiplication Assignment): x *= y is equivalent to x = x * y
#
# /= (Division Assignment): x /= y is equivalent to x = x / y
#
# %= (Modulus Assignment): x %= y is equivalent to x = x % y
#
# **= (Exponentiation Assignment): x **= y is equivalent to
# x = x ** y
#
# //= (Floor Division Assignment): x //= y is equivalent to x = x // y

# %%
sales -=2

# %%
sales

# %%
sales *4

# %%
sales

# %%
# sales = sales *4
sales *=4
sales

# %%
sales
# Out:
# 32

# %% [markdown]
# ### 5. logical operators
# Used to combine multiple conditional statements.
# - and (Returns True if both statements are true)
# - or (Returns True if at least one statement is true)
# - not (Reverses the logical state of its operand)

# %%
a =45
b =5
c = 2
# a greater
print(a>b)
print(a>c)
# Out:
# True
# True

# %%
a>b and a>c
# Out:
# True

# %%
# not !
number =24
number /2
# Out:
# 12.0

# %%
# even
number % 2 # % modulo --> show the  remiender value
# Out:
# 0

# %%
number % 2 ==0
# Out:
# True

# %%
# conditional statements
# if else
number =33

if number % 2 ==0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %%
# tarniary operators
# value_if_true if condition else value_if_false
result = "Even" if number % 2 == 0 else "Odd"
print(result)
# Out:
# Odd

# %%
# Even numbers always end with a 0 in their least significant bit (LSB), which represents the 1's place (2⁰).
# Odd numbers always end with a 1
# bitwise Operators
if number & 1 == 0:
    print("Even")
else:
    print( "Odd")
# Out:
# Odd

# %%
# Special Operators
    # membership operator(in)
    # Identity operators(IS)

# %%
# Identity operators
# In Python, is and is not are used to check if two values are located at the same memory location.
a =5

# %%
id(a)

# %%
b= 6

# %%
id(b)

# %%
a is b

# %%
c =5

# %%
id(c)

# %%
a is c

# %%
a is not c

# %%
# membership operator
list1 =[2,3,4,5,6,7,8]
8 in list1

# %%
8 not in list1

# %%
# The ternary operator in Python is a concise way to write conditional expressions.
# It allows you to evaluate a condition and return one value if the condition is true,
# and another value if the condition is false.

# syntax
# value_if_true if condition else value_if_false
age = 20
status = "Adult" if age >= 18 else "Minor"
print(status)  # Output: Adult

# %% [markdown]
# # Conditional Statements
# 1. if
# 2. if-if Statements
# 3. if-else Statements
# 4. if-elif-else Statements
# 5. nested

# %%
# # if syntax

# if conditions:
#   statements
age =20

if  age>=18:
  print("Adult")
  print("hii")

print("extra")

# %%
age =2

if  age>=18:
  print("Adult")
  print("hii")

print("extra")

# %%
age =2

if  age>=18:
  print("Adult")

# %%
if  age>=18:
  print("Adult")

if age<18:
  print("Minor")

# %%
age=3
if  age>=18:
  print("Adult")

if age<18:
  print("Minor")

if age>=18:
  print("Eligible for vote")

# %%
# if else --> if you have only 1 condition return eiter true or False

if  age>=18:
  print("Adult")
else:
  print("Minor")

# %%
# Create a grade system using marks
# A,B,C,D ,Fail

# pass fail
marks = 34
if marks>=33:
  print("pass")
else:
  print("fail")

# %%
# assign grades  --> only using multiple if
marks = 97
# 33 <fail , 33and 45 --> D , 45 and 60 -->C , 60 and 75 --->B, 75 and --> A

if  marks<33:
  print("fail")

if marks>=33  and marks<45:
  print("D")

if marks >=45 and marks<60:
  print("C")

if marks>=60 and marks<75:
  print("B")

if marks>=75:
  print("A")

# %%
# if - elif- else
# assign grades  --> only using multiple
marks = 97
# 33 <fail , 33and 45 --> D , 45 and 60 -->C , 60 and 75 --->B, 75 and --> A

if  marks<33:
  print("fail")

elif marks>=33  and marks<45:
  print("D")

elif marks >=45 and marks<60:
  print("C")

elif marks>=60 and marks<75:
  print("B")

else:
  print("A")

# %%
# Nested
# if age is greater than 18 and if it has a voter id print eligible for vote
age =16
voter_id ="y"

if age>=18:
  print("adult")

if voter_id=="y":
  print("eligible for vote")

# %%
# if age is greater than 18 and if it has a voter id print eligible for vote
age =21
voter_id ="n"

if age>=18:
  print("adult")
  if voter_id=="y":
    print("eligible for vote")

# %%
# if age is greater than 18 and if it has a voter id print eligible for vote
age =21
voter_id ="n"

if age>=18:
  print("adult")
  if voter_id=="y":
    print("eligible for vote")

  else:
    print("not eligible for vote")

# %%
# if age is greater than 18 and if it has a voter id print eligible for vote
age =1
voter_id ="n"

if age>=18:
  print("adult")
  if voter_id=="y":
    print("eligible for vote")
  else:
    print("not eligible for vote")
else:
  print("minor")
