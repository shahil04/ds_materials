# %% [markdown]
# ## Tuple
#
# A tuple in Python is an ordered collection of elements that is immutable. This means that once a tuple is created, its elements cannot be changed, added, or removed.
#
# Key characteristics of Python tuples:
# - Ordered:
# - Immutable:
# - Heterogeneous:

# %% [markdown]
# ### Creating and Accessing Tuples

# %%
# Defining tuples using parentheses ()
# 1.An empty tuple
t = ()
type(t)

# %%
# 2.A tuple with mixed data types
my_tuple = ("apple", 10, 3.14, True)  #hetrogenious

# %%
# 3.crate tuple from others sequatial data types
languages =["a","b","c"]
t1 = tuple(languages)

# 4.using comma create tuple
t2 = 2,
print(type(t2))
# 5.create empty tuple using  tuple functions
t3 = tuple()

# %%
type(t)

# %% [markdown]
# #### Accessing elements using indexing & slicing

# %%
#  2.indexing possible if data in order
# indexing /
my_tuple[2]

# %%
my_tuple[2] =6 # 3.immutable/ not changable

# %%
# slicing
my_tuple[1:3]

# %% [markdown]
# ### Tuple Operations

# %%
# Concatenation (+)
t1+t2 # combine two  tuples

# %%
# repetition (*)
t1*3

# %%
# Membership testing (in, not in)
"a" in t1

# %%
# Iterating through tuples
for i in t1:
  print(i)

# %% [markdown]
# ### Methods

# %%
t1.index

# %%
t1.count("a") # a  how many times reapeat

names.index("c") # a index

# in built methods
min(names)
max(names)
len(names)

# methods
languages.count('Python')
languages.index("C++")

# inbuilt functions
min(languages)
max(languages)
len(languages)

# len(tuple): Returns the total length of the tuple.
# max(tuple): Returns the item from the tuple with the maximum value.
# min(tuple): Returns the item from the tuple with the minimum value.
# sum(tuple): Returns the sum of all numeric elements in the tuple.
# sorted(tuple): Returns a new sorted list of elements from the tuple, leaving the

# %%
min(my_tuple) # mix datatype so comparision  not possible

# %%
# Immutability of Tuples
t1 = (1, 2, 3)
t1[0] = 10  # This will raise a TypeError

# %%
# if tuple is immutable but it require to change some data
roll_no =(1,2,3,5)
# update --> by using change data type
roll_no = list(roll_no)

roll_no.index(5)
roll_no[3]=4

roll_no = tuple(roll_no)
roll_no

# %% [markdown]
# #### Packing and Unpacking Tuples

# %%
# Packing multiple values into a single tuple
my_data = 10, "hello", True

print(my_data)
print(type(my_data))

# %%
t1

# %%
# unpacking
x,y,z =t1
print(y,z,x)

# %%
x,_,z = my_data # if you want to blank any value

# %%
x,*z = my_data # store multiple values in 1 variavble after unpacking using *

# %%
z

# %%
# indivisual assignments
a=2
b =4
c =5
# Multiple assignments
a,b,c = 2,4,5
