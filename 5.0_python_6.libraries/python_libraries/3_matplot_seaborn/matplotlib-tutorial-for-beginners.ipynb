# %% [markdown]
# <a class="anchor" id="0"></a>
#
# # Matplotlib tutorial for beginners
#
#
# This project is all about Matplotlib, the basic data visualization tool of Python programming language. I have discussed Matplotlib object hierarchy, various plot types with Matplotlib and customization techniques associated with Matplotlib.
#
#
# This project is divided into various sections based on contents which are listed below:-

# %%
# !pip install matplotlib
# %pip install seaborn
# python -m pip install matplotlib

# %% [markdown]
# ## Table of Contents
#
# 1.	Introduction
# 2.	Overview of Python Data Visualization Tools
# 3.	Introduction to Matplotlib
# 4.	Import Matplotlib
# 5.	Displaying Plots in Matplotlib
# 7.	Matplotlib interfaces
# 8.	Pyplot
# 9.	Styles with Matplotlib Plots
# 6.	Add Informations in charts
# 10.	Adding a grid
# 28.	Handling axes
# 29.	Handling X and Y ticks
# 30.	Adding labels
# 31.	Adding a title
# 32.	Adding a legend
# 33.	Control colours
# 34.	Control line styles
# 10.	Figure and Subplots
# 11.	First plot with Matplotlib
# 12.	Multiline Plots
# 13.	Parts of a Plot
# 14.	Saving the Plot
# 15.	Line Plot
# 16. line area chart
# 18.	Bar Chart
# 19.	Horizontal Bar Chart
# 20.	Error Bar Chart
# 21.	Stacked Bar Chart
# 16.	Scatter Plot
# 17.	Histogram
# 22.	Pie Chart
# 23.	Box Plot
# 25.	Contour Plot
# 35.	Summary

# %% [markdown]
# ##### Seaborn
#
# 1. line
# 2.  bar
# - 2.1 stack bar
# - 2.2 cluster bar
# - 2.3 columns char
# 3.  line areachart
# 4.  scatter plot
# 5.  histogram
# 6.  pie
# 7.  box plot
# 8.  villon plot
# 9.  heatmap
# 10. pair plot, jointplot, regplot

# %% [markdown]
# ## 1. Introduction
#
#
# When we want to convey some information to others, there are several ways to do so. The process of conveying the information with the help of plots and graphics is called **Data Visualization**. The plots and graphics take numerical data as input and display output in the form of charts, figures and tables. It helps to analyze and visualize the data clearly and make concrete decisions. It makes complex data more accessible and understandable. The goal of data visualization is to communicate information in a clear and efficient manner.
#
#
# In this project, I shed some light on **Matplotlib**, which is the basic data visualization tool of Python programming language. Python has different data visualization tools available which are suitable for different purposes. First of all, I will list these data visualization tools and then I will discuss Matplotlib.

# %% [markdown]
# ## 2. Overview of Python Visualization Tools
#
#
#
# Python is the preferred language of choice for data scientists. Python have multiple options for data visualization. It has several tools which can help us to visualize the data more effectively. These Python data visualization tools are as follows:-
#
#
#
# •	Matplotlib
#
# •	Seaborn
#
# •	pandas
#
# •	Bokeh
#
# •	Plotly
#
# •	ggplot
#
# •	pygal
#
#
#
# In the following sections, I discuss Matplotlib as the data visualization tool.

# %% [markdown]
# ## 3. Introduction to Matplotlib
#
#
# **Matplotlib** is the basic plotting library of Python programming language. It is the most prominent tool among Python visualization packages. Matplotlib is highly efficient in performing wide range of tasks. It can produce publication quality figures in a variety of formats.  It can export visualizations to all of the common formats like PDF, SVG, JPG, PNG, BMP and GIF. It can create popular visualization types – line plot, scatter plot, histogram, bar chart, error charts, pie chart, box plot, and many more types of plot. Matplotlib also supports 3D plotting. Many Python libraries are built on top of Matplotlib. For example, pandas and Seaborn are built on Matplotlib. They allow to access Matplotlib’s methods with less code.
#
#
# The project **Matplotlib** was started by John Hunter in 2002. Matplotlib was originally started to visualize Electrocorticography (ECoG) data of epilepsy patients during post-doctoral research in Neurobiology. The open-source tool Matplotlib emerged as the most widely used plotting library for the Python programming language. It was used for data visualization during landing of the Phoenix spacecraft in 2008.

# %% [markdown]
# ## 4. Import Matplotlib
#
# Before, we need to actually start using Matplotlib, we need to import it. We can import Matplotlib as follows:-
#
# `import matplotlib`
#
#
# Most of the time, we have to work with **pyplot** interface of Matplotlib. So, I will import **pyplot** interface of Matplotlib as follows:-
#
#
# `import matplotlib.pyplot`
#
#
# To make things even simpler, we will use standard shorthand for Matplotlib imports as follows:-
#
#
# `import matplotlib.pyplot as plt`

# %%
# matplotlib ,seaborn
#extra -->  bokeh ,polty, 3.js

# install 
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ## 5. Displaying Plots in Matplotlib
#
#
# Viewing the Matplotlib plot is context based. The best usage of Matplotlib differs depending on how we are using it.
# There are three applicable contexts for viewing the plots. The three applicable contexts are using plotting from a script, plotting from an IPython shell or plotting from a Jupyter notebook.

# %% [markdown]
# ### Plotting from a script
#
#
#
# If we are using Matplotlib from within a script, then the **plt.show()** command is of great use. It starts an event loop,
# looks for all currently active figure objects, and opens one or more interactive windows that display the figure or figures.
#
#
# The **plt.show()** command should be used only once per Python session. It should be used only at the end of the script. Multiple **plt.show()** commands can lead to unpredictable results and should mostly be avoided.

# %% [markdown]
# ### Plotting from a Jupyter notebook
#
# Interactive plotting within a Jupyter Notebook can be done with the **%matplotlib** command. There are two possible options to work with graphics in Jupyter Notebook. These are as follows:-
#
#
# •	**%matplotlib notebook** – This command will produce interactive plots embedded within the notebook.
#
# •	**%matplotlib inline** – It will output static images of the plot embedded in the notebook.
#
#
# After this command (it needs to be done only once per kernel per session), any cell within the notebook that creates a plot will embed a PNG image of the graphic.

# %%
2

# %%
# DIRECT CODE  
# https://matplotlib.org/
# https://seaborn.pydata.org/

import matplotlib.pyplot as plt 
d1 = [1,2,3,4,5,6]
d1
plt.plot(d1)
plt.show()

# %%
# %matplotlib inline 
 # it is use in same page as a visual  
plt.plot(d1)
plt.show()

# %%
# basic plotings
# simple line 
plt.plot([12,2,10,13])
plt.show()

# %%
x2 =[223,6,18,9]
# plot use  for line chart  with some basic line design
plt.plot(x2,"-.b")
plt.show()

# %%
import numpy as np
x = np.random.randint(0,100, 50) # create 50 random numbers
y = np.random.rand(50)  # create 50 random numbers
x
y

# %%
plt.plot(x, y,"s" ,c="r")  # 'o' means scatter plot
plt.show()

# %% [markdown]
# #### Design on charts

# %%
2

# %%
import matplotlib.pyplot as plt
x2 =[223,6,18,9]
plt.plot(x2,'r' ,marker='o',mec='b',mfc='g',ms="10")  # r= red color ,o for circle point,g= green color 
# mec=marker edge color ,mfc=marker face color
plt.show()

# %% [markdown]
# ### line design

# %%
# line design 
# color, style, marker, markerfacecolor, markeredgecolor

plt.plot(x2, color ='black')
plt.plot(x2, c ='black')
# short form , full_name, RGB, hexa code
# https://matplotlib.org/stable/users/explain/colors/colors.html#colors-def

# Add Extra information in charts
plt.show()

# %%
plt.plot(x2, color =(0.3, 0.2, 0.9)) # RGB value  0 to  1 
plt.show()

# %%
plt.plot(x2, color ="#260849") # hexa color code use 
plt.show()

# %%
#  2.line style 
plt.plot(x2, "--",color ="#8a1818")
# https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D.set_linestyle
plt.show()

# %%
plt.plot(x2, linestyle = "-.", color ="#8a1818")
plt.show()

# %%
# 3. Add the line width
plt.plot(x2, linestyle = "-.",color ="#8a1818", linewidth='3')
plt.show()

# %%
plt.plot(x2,"sg") # short form then show marker only 
plt.show()

# %%
# 4. marker
plt.plot(x2,color ="#32e312", marker="s") #   show marker with line

# %%
# 4.1 marker & marker style
plt.plot(x2, linestyle = "-.",color ="#1d0202", linewidth='2', marker="s")
# https://matplotlib.org/stable/api/_as_gen/matplotlib.markers.MarkerStyle.html#matplotlib.markers.MarkerStyle
plt.show()

# %%
# 4.2 Add markerfacecolor
plt.plot(x2, linestyle = "-.",color ="#8a1818", linewidth='2', marker="s",markerfacecolor="#05d116")

# %%
#4.3 Add markerfacecolor-->mfc, markeredgecolor--> mec
plt.plot(x2, linestyle = "-.",color ="#8a1818", linewidth='2', marker="s",mfc="#05d116",mec="#f80606")
plt.show()

# %% [markdown]
# #### 2. Add multiple charts in a single chart

# %%
import numpy as np
x1 = np.linspace(0, 20, 10) # 10 number between 0 to 20 
x1

# %%
# use plt with plot
import matplotlib.pyplot as plt
plt.plot(x1,'bo--') # 'bo--' 1.color ,2.marker, 3. linestyle
# plt.plot(x2)
plt.plot(x1, x1**2, 'rD--') # red color , diamond marker, dashed line
plt.show()

# %% [markdown]
# #### 2.1 show both charts in individual

# %%
# use plt show 
plt.plot(x1, 'bo--')  # 'bo--' 1.color ,2.marker, 3. linestyle
plt.show()  # it render the individual charts in separate form

# plt.plot(x1)
plt.plot(x1) 
# without using show  both show in same charts 
plt.show()

# %% [markdown]
# ### 3 Add Extra informations in chart
# size, title , legend, gridline, x-axis,y-axis, tick ,limits

# %%
# 3.1 create a plot figure
# figsize=(8,4) width, height
fig = plt.figure(figsize=(10,2))  # create a figure/chart with specific size

plt.plot(x1, 'bo--')
plt.show()

# %%
#3.2 title
plt.figure(figsize=(5,2))  #figsize=(8,4) width, height
plt.plot(x2, 'bo--')
plt.plot(x1, 'r')
# title
plt.title("line chart")
plt.show()

# %%
# 3.3 Add Legend
plt.figure(figsize=(4,2))
plt.plot(x2, 'bo--',label='blue line/sale')
plt.plot(x1, 'r', label='red line/ profit')
plt.title("line chart")
# ADD LEGEND WITH LABELS
plt.legend() # it show the label in plot

plt.show()

# %%
# 3.4 Add Legend locations --> loc 
plt.figure(figsize=(4,2))
plt.plot(x2, 'bo--',label='blue line/sale')
plt.plot(x1, 'r', label='red line/ profit')
plt.title("line chart") # title
# add locations of legend
plt.legend(loc='lower left') # it show the label in plot
# plt.legend(loc=3)
plt.show()

# %%
# 3.5 Add x and y-axis name/label
plt.figure(figsize=(4,2))
plt.plot(x2, 'bo--',label='blue line/sale')
plt.plot(x1, 'r', label='red line/ profit')
plt.title("line chart") # title
plt.legend(loc='lower left') # it show the label in plot

# x and y label
plt.xlabel('x-axis value/profit')
plt.ylabel('y-axis')
plt.show()

# %%
# 3.6. Add grid lines
plt.figure(figsize=(4,2))
plt.plot(x2, 'bo--',label='blue line/sale')
plt.plot(x1, 'r', label='red line/ profit')
plt.title("line chart") # title
plt.legend(loc='upper right') # it show the label in plot
plt.xlabel('x-axis value') # x label
plt.ylabel('y-axis') # y label

# grid lines
plt.grid(c="g") # c= color of grid lines
plt.show()

# %%
# for sequence data use arange
import numpy as np 
np.arange(0,100,20) # 0 to 100 with step 10

# %%
# 6. ticks range of axis
fig = plt.figure(figsize=(4,3))
plt.plot(x2, 'bo--')
plt.plot(x1, 'r')
plt.grid(c="g")

# ticks for value lable range
plt.yticks(np.arange(0,251,20)) # np.arange(start, stop, step) 0 to 25 with step 2
plt.xticks(np.arange(0,10,1))
plt.show()

# %%
# 7. limit of axis range
fig = plt.figure(figsize=(4,3))
plt.plot(x2, 'bo--')
plt.plot(x1, 'r')
plt.grid(c="g")
plt.yticks(np.arange(0,251,20)) # np.arange(start, stop, step) 0 to 25 with step 2
plt.xticks(np.arange(0,10,1)) # ticks for value lable range

# limit the range of the axis 
plt.ylim(0,300)
plt.xlim(0,20)
plt.show()

# %%
# Final all Codes of basic Designing of line chart
plt.figure(figsize=(4,2))
plt.plot(x1*2, 'bo--',label='blue line/sale')
plt.plot(x1, 'r', label='red line/ profit')
plt.title("line chart") # title
plt.legend(loc='upper right') # it show the label in plot
plt.xlabel('x-axis value') # x label
plt.ylabel('y-axis') # y label
# grid lines
plt.grid(c="g") # c= color of grid lines
# 7. limit of axis range
plt.yticks(np.arange(0,251,20)) # np.arange(start, stop, step) 0 to 25 with step 2
plt.xticks(np.arange(0,10,2)) # ticks for value lable range
# limit the range of the axis 
plt.ylim(0,300)
plt.xlim(0,13)
plt.show()

# %% [markdown]
# ### SUBPLOTINGS
#
# Subplotting in Matplotlib allows you to create multiple plots (axes) within a single figure (canvas).
#
# * Syntax
# plt.subplot(2, 1, 1)   # (rows, columns, panel number)

# %% [markdown]
# <!-- # 2nd way to create
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Create data
# x = np.linspaaaace(0, 2 * np.pi, 400)
# y_sin = np.sin(x)
# y_cos = np.cos(x)
# # Create a figure and a 1x2 grid of subplots (1 row, 2 columns)
# fig, (ax1, ax2) = plt.subplots(1, 2)
#
# # Plot data on the first subplot (ax1)
# plt.plot(x, y_sin)
# ax1.set_title('Sine Wave')
# ax1.set_xlabel('X Value')
# ax1.set_ylabel('Y Value')
#
# # Plot data on the second subplot (ax2)
# ax2.plot(x, y_cos, 'r-')
# ax2.set_title('Cosine Wave')
# ax2.set_xlabel('X Value')
# ax2.set_ylabel('Y Value')
#
# # Adjust layout to prevent overlaps
# plt.tight_layout()
#
# # Display the figure
# plt.show()
#  -->

# %%
# Create data
d = [1,4,7,8,3,2] 
d2 = [2,5,6,9,4,3]

# %%
# create a charts  in a single charts
plt.plot(d)
plt.plot(d2)
# seperate the charts

# %%
# seperate the charts using show 
plt.plot(d)
plt.show()
plt.plot(d2)

#  we need chats in same figure size  but it create a saprete charts with diffrent size 

# So in fixed size for multiple graph using  subplot

# %%
# create a plot figure
plt.figure(figsize=(3,4))
# Create data
d = [1,4,7,8,3,2] 
d2 = [2,5,6,9,4,3] 
# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(d,label="line 1")
plt.title("line 1 ")

# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(d2,'r',label="line 2")
plt.title("line 2")

plt.legend()
plt.tight_layout()
plt.show()

# %%
# create a plot figure
plt.figure(figsize=(3,2))

# create the first of two panels and set current axis
plt.subplot(1, 2, 1)   # (rows, columns, panel number)
plt.plot(d,label="line 1")
plt.title("line 1 ")

# create the second of two panels and set current axis
plt.subplot(1, 2, 2)   # (rows, columns, panel number)
plt.plot(d2,'r',label="line 2")
plt.title("line 2")

plt.legend()
plt.tight_layout()

plt.show()

# %%
# create a plot figure
plt.figure(figsize=(5,5))

# create the first of two panels and set current axis
plt.subplot(2,2, 1)   # (rows, columns, panel number)
plt.plot(d,label="line 1")
plt.title("line 1 ")

# create the second of two panels and set current axis
plt.subplot(2,2, 4)   # (rows, columns, panel number)
plt.plot(d2,'r',label="line 4")
plt.title("line 4")

# create the second of two panels and set current axis
plt.subplot(2,2, 2)   # (rows, columns, panel number)
plt.plot(d2,'r',label="line 2")
plt.title("line 2")

plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# ### 2. Bar chart
# A bar graph (or bar chart) is a visual tool that uses rectangular bars to compare data across different categories.
# - data --> categorical , continous
# - use for compare the data

# %%
category= ['phone','laptop','charger']
value = [230,250,200]

plt.bar(category, value, color='r',alpha=0.5)
plt.show()

# %%
plt.plot(value) # line chart for tends

# %% [markdown]
# combine bar and line chart

# %%
# combine bar and line chart
plt.bar(category,value,color='r')
plt.plot(value)
plt.show()

# %%
# !pip install seaborn # intall seaborn library for advance visualization
# %pip install seaborn

# %%
import seaborn as  sns

# %%
sns.barplot(x=category,y=value, color="g") #simple color for all bars
plt.title("seaborn bar plot")
plt.show()

# %%
sns.barplot(x=category,y=value, palette=['g','r','b'])  # color with respect to category for older version
plt.title("seaborn bar plot")
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")  #  for ignoring the warning message

# %%
sns.barplot(x=category,y=value, hue=category) # hue is use for color with respect to category
plt.title("seaborn bar plot")
plt.show()

# %%
sns.barplot(x=category,y=value, palette='flare') # use palette for gradient color 
plt.title("bar")
plt.show()

# %% [markdown]
# show the multiple chart in single figure
# 1. column charts --> compare
# 2. line chart --> trends
# 3. combine chart --> compare with trends

# %%
plt.Figure(figsize=(4,4))

plt.subplot(2,2,1)
plt.bar(category,value,color='g')

plt.subplot(2,2,2) 
plt.title("line")
plt.plot(value)

plt.subplot(2,2,3)
sns.barplot(x=category,y=value, hue=category)
plt.plot(value)

plt.subplot(2,2,4)
plt.title("bar")
sns.barplot(x=category,y=value, palette="Greens")
plt.plot(value)

plt.tight_layout()
plt.show()

# %% [markdown]
# 2.2 Add Data Labels in bar charts
#
#
# https://www.geeksforgeeks.org/python/how-to-display-the-value-of-each-bar-in-a-bar-chart-using-matplotlib/

# %%
# define axis and  add lables in bars
ax = sns.barplot(x=category,y=value, palette='Greens')
plt.title("bar")
ax.bar_label(ax.containers[1])
plt.show()

# %%
# define axis and  add lables in bars
ax = sns.barplot(x=category,y=value, palette='Greens')
plt.title("bar")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
plt.show()

# %%
# 1st way to define label in bar chart 
ax = sns.barplot(x=category,y=value, palette='Greens')
plt.title("bar")
for i in range(len(category)):
    ax.bar_label(ax.containers[i])
    
plt.show()
# ax.bar_label(container, fmt='%.1f', label_type='edge', padding=3)

# %%
# 2nd way to add labels in bar chart
import matplotlib.pyplot as plt
# Create figure and axis
fig, ax = plt.subplots()
# Plot bars and save the container reference
bars = ax.bar(category, value)
# Add labels directly on top of the bars
ax.bar_label(bars)
plt.show()

# %% [markdown]
# #### Now use titanic datasets for visualizations with business questions

# %%
sns.get_dataset_names()  #sample data

# %%
# Load the 'titanic' dataset
titanic_df = sns.load_dataset('titanic')
titanic_df.head()

# %%
# 1.line
# 2. bar
# 2.1 stack bar 
# 2.2 cluster bar
# 2.3 columns char
# 3. line areachart
# 4. scatter plot
# 5. historam
# 6. pie
# 7. box plot
# 8. villon plot
# 9. heatmap
# 10.pair blot, jointplot,regplot

# %%
titanic_df.columns

# %% [markdown]
# ### questions based charts
# 1. # Q. show the class wise total fare

# %%
# Q. show the class wise total fare 
titanic_df.groupby('class')['fare'].sum()

# %%
titanic_df.groupby('class')['fare'].sum().reset_index()

# %%
classwise_fares = titanic_df.groupby('class')['fare'].sum().reset_index()

# %%
len(classwise_fares)

# %%
# visualizations bar
plt.figure(figsize=(3,2))
ax = sns.barplot(data=classwise_fares, x='class', y='fare', hue='class')  
for i in range(len(classwise_fares)):
    ax.bar_label(ax.containers[i])
plt.title("Class Wise Fare")
plt.show()

# %%
# Q> show the class wise total fare with respect to Gender in each.
# cluster bar chart
ax = sns.barplot(titanic_df,x='class',y='fare',hue='sex',errorbar=None)
# Add data labels
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')
plt.legend()
plt.show()

# %%
# stack bar chart
# plt.bar()

# %%
# Q. show the passanger count in each class who survived or not 
data = titanic_df.groupby(["class", "survived"]).size().reset_index(name="p_count")
data

# %%
pivot_data = data.pivot(index="class", columns="survived", values="p_count")
pivot_data

# %%
# Apply Seaborn style
sns.set_style("whitegrid")   
# Create stacked bar chart using Matplotlib under Seaborn style
pivot_data.plot(kind="bar", stacked=True, color=["salmon", "skyblue"], figsize=(7,5))  # old version stack bar chart implement
plt.show()

# %% [markdown]
# #### 3. line areachart
#
# An area chart combines the line chart and bar chart to show how one or more groups' numeric values change over the progression of a second variable, typically that of time.

# %%
# 3. line areachart
x =titanic_df["fare"][:200]
x

# %%
import numpy as np
y= np.arange(200)
y

# %%
# line chart
plt.plot(y,x, 'r')
plt.show()

# %%
# area chart
plt.fill_between(y,x, color='g', alpha=0.3,) # alpha use for color intensity
plt.show()

# %%
# draw the line of fare columns --> line-area chart
plt.plot(y,x, 'b')
plt.fill_between(y,x, color='g', alpha=0.7,) # alpha use for color intensity
plt.title("line area chart")
plt.show()

# %% [markdown]
# ## 4. scatter plot
#
# A scatter plot is a graph that uses dots to **represent the relationship between two numerical variables**, where each dot's position on the horizontal (\(x\)) and vertical (\(y\)) axes corresponds to the values of a single data point.

# %%
# Load the 'titanic' dataset
titanic_df = sns.load_dataset('titanic')
titanic_df.head()

# show the realtion ship between age and fare
plt.scatter(titanic_df['age'],titanic_df['fare'])
plt.show()

# %%
sns.scatterplot(titanic_df,x= 'age',y='fare') # using sns for scatterplot

# %%
sns.scatterplot(titanic_df,x= 'age',y='fare', hue='survived') # with color as survived or not

# %% [markdown]
# #### 5. histogram
#
# A histogram is a graphical representation of the distribution of numerical data, where the range of data is divided into "bins" or intervals, and each bin is shown as a rectangle

# %%
plt.hist(titanic_df['age'])  # matplotlib code 
plt.show()

# %%
sns.histplot(titanic_df, x='age',bins=20) #bins for number of bars in histogram
plt.show()

# %%
sns.histplot(titanic_df, x='age',bins=10,kde=True) #kde for distributions line draw 
plt.show()

# %%
sns.histplot(titanic_df, x='age',bins=10,kde=True,hue='sex', hue_order=['female','male'] )  # hue for different colour dist

plt.show()

# %% [markdown]
# #### 6. pie
#
# A pie chart is a circular graph that is divided into wedges or slices, where each slice represents a proportion or percentage of a whole. It's a visual tool used to show how a total amount is broken down into different components

# %%
# class wise fare contributions   data

# %%
# Prepare grouped data
data = titanic_df.groupby(["class"])["fare"].sum().reset_index()
data
# Out:
#     class        fare
# 0   First  18177.4125
# 1  Second   3801.8417
# 2   Third   6714.6951

# %%
plt.pie(data['fare'], labels=data['class'])
plt.show()

# %%
# lablel ,color , slice ,percentage, rotation
# explode [0 to 1]
ex = [0.2,0.1,0]

# Creating color parameters
col = ("orange", "cyan", "brown")

#  add percentage value  use autopct 
plt.pie(data['fare'], labels=data['class'], explode=ex, colors=col, autopct='%.2f%%')
plt.legend(title = "class wise ratio")
plt.show()
# https://www.w3schools.com/python/matplotlib_pie_charts.asp
# https://www.geeksforgeeks.org/data-science/plot-a-pie-chart-in-python-using-matplotlib/
# https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html

# %%
# Prepare grouped data
data = titanic_df.groupby(["class"])["fare"].sum().reset_index()
data

# %%
data = titanic_df.groupby(["class"])["fare"].sum().reset_index()
label = data['class']
value = data['fare']

explode = (0.1, 0.0, 0.2)
colors = ("orange", "cyan", "brown")
wp = {'linewidth': 1, 'edgecolor': "green"}

def func(pct, allvalues):
    absolute = int((pct/100) * np.sum(allvalues))
    return "{:.1f}%\n({:d})".format(pct, absolute)

fig, ax = plt.subplots(figsize=(10, 7))

wedges, texts, autotexts = ax.pie(
    value,
    autopct=lambda pct: func(pct, value),   # FIXED HERE
    explode=explode,
    labels=label,
    shadow=True,
    colors=colors,
    startangle=90,
    wedgeprops=wp,
    textprops=dict(color="black")
)
# Legend
ax.legend(
    wedges,
    label,
    title="Class",
    loc="center left",
    bbox_to_anchor=(1, 0, 0.5, 1)
)
plt.setp(autotexts, size=8, weight="bold")
ax.set_title("Customizing pie chart")
plt.show()

# %% [markdown]
# ### 7. box plot
# A boxplot (or box-and-whisker plot) is a standardized graphical method for displaying the distribution of numerical data based on a ***five-number summary***: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum.
#
# ```
# Min ----|====[ Q1 | Median | Q3 ]====|---- Max
# ```
# It highlights data center, spread, skewness, and outliers.

# %%
plt.boxplot(titanic_df["fare"]) # matplot
plt.show()

# %%
sns.boxplot(titanic_df,x='fare') # seaborn

# %% [markdown]
# ### 8. violin plot
#
# A violin plot is a hybrid visualization that combines a box plot and a kernel density plot to show the distribution of numerical data across different categories.

# %%
sns.violinplot(titanic_df,x='age')

# %% [markdown]
# #### 9. heatmap
#
# A heatmap is a data visualization technique that uses colors to represent the magnitude of values in a grid, making it easier to spot patterns and trends. It's used in many fields, from scientific data analysis to website and marketing analytics, to intuitively show areas of high and low density.

# %%
df= titanic_df[['fare','age','pclass','survived']]
df.corr()

# %%
sns.heatmap(df.corr(),annot=True) # corr -1 to 1 range

# %% [markdown]
# ### 10.pair blot
#
# A pair plot (or scatterplot matrix) is a visualization that displays the pairwise relationships between all numerical variables in a dataset. It is a fundamental tool for exploratory data analysis (EDA), helping to quickly identify trends, patterns, correlations, and potential outliers among features.

# %%
sns.pairplot(titanic_df)

# %%
sns.pairplot(titanic_df[['fare','age']])

# %% [markdown]
# #### 11. jointplot
#
# A jointplot is a plot created using the Seaborn library that displays the relationship between two variables, showing a bivariate plot (like a scatter plot) in the center and their individual distributions (like histograms or kernel density estimates) in the margins at the top and right. It is useful for comparing a joint distribution of two variables with their individual distributions at the same time

# %%
# Create the jointplot of 'age' and 'fare'
# sns.jointplot(x='age', y='fare', data=titanic_df)
sns.jointplot(x='age', y='fare', data=titanic_df,kind='reg')

# %% [markdown]
# #### 12. regplot
#
# regplot is a function in the Seaborn Python library that creates a scatter plot of data and fits and draws a linear regression model through the points. It is used to visualize the linear relationship between two variables and includes a 95% confidence interval for the regression line by default.

# %%
sns.regplot(x="age", y="fare", data=titanic_df)

# %% [markdown]
# ------
# --
# # EXTRA (OPTIONAL)

# %% [markdown]
# ### Figure and Axes
#
#
# I start by creating a figure and an axes. A figure and axes can be created as follows:
#
#
# `fig = plt.figure()`
#
# `ax = plt.axes()`
#
#
#
# In Matplotlib, the **figure** (an instance of the class plt.Figure) is a single container that contains all the objects representing axes, graphics, text and labels. The **axes** (an instance of the class plt.Axes) is a bounding box with
# ticks and labels. It will contain the plot elements that make up the visualization. I have used the variable name fig
# to refer to a figure instance, and ax to refer to an axes instance or group of axes instances.

# %%
fig = plt.figure()

ax = plt.axes()

# %% [markdown]
# ## 10. Figure and Subplots
#
#
#
# Plots in Matplotlib reside within a Figure object. As described earlier, we can create a new figure with plt.figure()
# as follows:-
#
#
# `fig = plt.figure()`
#
#
# Now, I create one or more subplots using fig.add_subplot() as follows:-
#
#
# `ax1 = fig.add_subplot(2, 2, 1)`
#
#
# The above command means that there are four plots in total (2 * 2 = 4). I select the first of four subplots (numbered from 1).
#
#
# I create the next three subplots using the fig.add_subplot() commands as follows:-
#
#
# `ax2 = fig.add_subplot(2, 2, 2)`
#
# `ax3 = fig.add_subplot(2, 2, 3)`
#
# `ax4 = fig.add_subplot(2, 2, 4)`

# %% [markdown]
# The above command result in creation of subplots. The diagrammatic representation of subplots are as follows:-
#
#
# ![Subplots.png](attachment:Subplots.png)

# %%
# Saving the figure
fig.savefig('plot1.png')

# %%
# Explore the contents of figure
from IPython.display import Image
Image('plot1.png')

# %%
# Explore supported file formats
fig.canvas.get_supported_filetypes()

# %%
data2 = [5. , 25. , 50. , 20.]
# Horizontal Bar Chart
plt.barh(range(len(data2)), data2)
plt.show()

# %%
A = [15., 30., 45., 22.]

B = [15., 25., 50., 20.]

z2 = range(4)
# Stack bar chart plt
plt.bar(z2, A, color = 'b')
plt.bar(z2, B, color = 'r', bottom = A)

plt.show()

# %% [markdown]
# The optional **bottom** parameter of the plt.bar() function allows us to specify a starting position for a bar. Instead of running from zero to a value, it will go from the bottom to value. The first call to plt.bar() plots the blue bars. The second call to plt.bar() plots the red bars, with the bottom of the red bars being at the top of the blue bars.

# %% [markdown]
# ## 25. Contour Plot
#
#
# **Contour plots** are useful to display three-dimensional data in two dimensions using contours or color-coded regions.
# **Contour lines** are also known as **level lines** or **isolines**. **Contour lines** for a function of two variables are
# curves where the function has constant values. They have specific names beginning with iso- according to the nature of the variables being mapped.
#
#
# There are lot of applications of **Contour lines** in several fields such as meteorology(for temperature, pressure, rain, wind
# speed), geography, magnetism, engineering, social sciences and so on.
#
#
# The density of the lines indicates the **slope** of the function. The **gradient** of the function is always perpendicular to the contour lines. When the lines are close together, the length of the gradient is large and the variation is steep.
#
#
# A **Contour plot** can be created with the **plt.contour()** function as follows:-

# %%
# Create a matrix
matrix1 = np.random.rand(10, 20)
cp = plt.contour(matrix1)
plt.show()

# %% [markdown]
# The **contour()** function draws contour lines. It takes a 2D array as input.Here, it is a matrix of 10 x 20 random elements.
#
# The number of level lines to draw is chosen automatically, but we can also specify it as an additional parameter, N.
#
# `plt.contour(matrix, N)`

# %% [markdown]
# ## 26. Styles with Matplotlib Plots
#
#
# The Matplotlib version 1.4 which was released in August 2014 added a very convenient `style` module. It includes a number of
# new default stylesheets, as well as the ability to create and package own styles.
#
# We can view the list of all available styles by the following command.
#
#
# `print(plt.style.availabe)`

# %%
# View list of all available styles
print(plt.style.available)

# %% [markdown]
# We can set the **Styles** for Matplotlib plots as follows:-
#
#
# `plt.style.use('seaborn-bright')`

# %%
# Set styles for plots
plt.style.use('seaborn-bright')

# %% [markdown]
# I have set the **seaborn-bright** style for plots. So, the plot uses the **seaborn-bright** Matplotlib style for plots.

# %% [markdown]
# The **legend** function takes an optional keyword argument **loc**. It specifies the location of the legend to be drawn.
# The **loc** takes numerical codes for the various places the legend can be drawn. The most common **loc** values are as follows:-

# %% [markdown]
# ax.legend(loc=0)  # let Matplotlib decide the optimal location
#
# ax.legend(loc=1)  # upper right corner
#
# ax.legend(loc=2)  # upper left corner
#
# ax.legend(loc=3)  # lower left corner
#
# ax.legend(loc=4)  # lower right corner
#
# ax.legend(loc=5)  # right
#
# ax.legend(loc=6)  # center left
#
# ax.legend(loc=7)  # center right
#
# ax.legend(loc=8)  # lower center
#
# ax.legend(loc=9)  # upper center
#
# ax.legend(loc=10) # center

# %% [markdown]
# The colour names and colour abbreviations are given in the following table:-
#
#
# **Colour abbreviation**      **Colour name**
#
# b                               blue
#
# c                               cyan
#
# g                               green
#
# k                               black
#
# m                               magenta
#
# r                               red
#
# w                               white
#
# y                               yellow

# %% [markdown]
# There are several ways to specify colours, other than by colour abbreviations:
#
# •	The full colour name, such as yellow
#
# •	Hexadecimal string such as ##FF00FF
#
# •	RGB tuples, for example (1, 0, 1)
#
# •	Grayscale intensity, in string format such as ‘0.7’.
