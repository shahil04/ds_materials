# %% [markdown]
# ## Data Visualization

# %%
# matplotlib ,seaborn

#extra -->  bokeh ,polty, 3.js


# install 
# pip install matplotlib
# pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# https://matplotlib.org/
# https://seaborn.pydata.org/

# %%
# data 
import numpy as np
import pandas as pd

d1 = [1,2,3,4,5,6]

# %%
# create  line graph using plot
plt.plot(d1)

# plt.show() # only display the plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)
y

# %%
plt.plot(x)

# %%
plt.scatter(x,y)

# %%
x = np.linspace(0,10, 100)
y = np.linspace(1,30)
x

# %%
# figsize=(2,3) width,height
# to define size of graph
plt.figure(figsize=(2,3))

plt.plot(x, np.sin(x),"--",color="red" ,marker="4",markerfacecolor="g",markeredgecolor="g",label="sin graph" )
plt.title("sin graph")

plt.plot(x, np.cos(x),"--", label="cos graph")

#create x and y label 
plt.xlabel("range 1 to 10")
plt.ylabel("sin value")

# define the range of the x and y
plt.xticks(np.arange(0,11, 1))
plt.yticks(np.arange(-1,1, 0.1))

# define range of x
plt.xlim(1,20)
plt.ylim(-2,1)
plt.grid()
plt.legend(loc="upper left")
# 'upper left': Places the legend in the upper left corner of the axes.
# 'upper right': Places the legend in the upper right corner of the axes. 
# 'lower left': Places the legend in the lower left corner of the axes.
# 'lower right': Places the legend in the lower right corner of the axes.
plt.show()

# %%
# figsize=(2,3) width,height

plt.plot(x, np.sin(x),"--",color="red" ,marker="4",markerfacecolor="g",markeredgecolor="g",label="sin graph" )
plt.title("sin graph")

plt.show()

plt.plot(x, np.cos(x),"--", label="cos graph")

# %%
plt.Figure(figsize=(5,5))

# subplot(row,column, ploting area )

plt.subplot(2,1,1)
plt.plot(x, np.sin(x),"--",color="red",label="sin graph")
plt.legend()

plt.subplot(2,1,2)
plt.plot(x, np.cos(x),"--", label="cos graph")

plt.legend()
plt.show()

# %%
plt.Figure(figsize=(5,5))

# subplot(row,column, ploting area )

plt.subplot(1,2,1)
plt.plot(x, np.sin(x),"--",color="red",label="sin graph")
plt.legend()
plt.subplot(1,2,2)
plt.plot(x, np.cos(x),"--", label="cos graph")

plt.legend()
plt.show()

# %%
plt.Figure(figsize=(5,5))

# subplot(row,column, ploting area )

plt.subplot(2,2,1)
plt.plot(x, np.sin(x),"--",color="red",label="sin graph")
plt.legend()

plt.subplot(2,2,4)
plt.plot(x, np.cos(x),"--", label="cos graph")


plt.subplot(2,2,2)
plt.plot(x, np.tan(x),"--", label="tan graph")

plt.legend()
plt.show()

# %%
df = pd.read_csv(r"C:\Users\hp\Documents\ds\ds_materials\class\clean_data.csv")
df

# %%
# age distributions
plt.hist(df["Age"], color="g", bins=10)

plt.title("Age Distribution",color="g")
plt.xlabel(" age ")
plt.show()

# %%
# age distributions
plt.hist(df["Age"], color="g", bins=10, histtype='bar', rwidth=0.8)

plt.title("Age Distribution",color="g")
plt.xlabel(" age ")
plt.show()

# %%
sns.histplot(df["Age"],kde=True)
plt.title("Age Distribution")

# %%
sns.histplot(df["Age"],kde=True)
plt.title("Age Distribution")

# %%
y =df["Sex"].value_counts()

# %%
df["Sex"].value_counts().index

# %%
plt.bar(df["Sex"].value_counts().index, df["Sex"].value_counts())

# %%
y[0]

# %%
sns.barplot(df, x="Sex",y="Age", hue="Sex", palette=["red","green"])

# %%
sns.barplot(df, x="Sex",y="Age", hue="Sex",legend=True)
plt.legend()

# %%
ax = sns.barplot(df, x="Sex",y="Age", hue="Sex",legend=True,errorbar=None)

for i in range(2):
    ax.bar_label(ax.containers[i])

# %%
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '30.5058')]

# %%
sns.scatterplot(data=df,x="Age",y="Fare",hue="Sex",)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>
