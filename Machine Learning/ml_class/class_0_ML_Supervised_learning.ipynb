# %% [markdown]
# [ML class](<ml_class_notes/class_1_Machine learning.pptx>)

# %% [markdown]
# <!-- ![image.png](attachment:image.png) -->
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![alt text](Supervised_and_unsupervised_learning.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Linear versus non-linear models
# ![Linear-versus-non-linear-classification-Illustration-of-the-separation-of-data-samples.png](attachment:Linear-versus-non-linear-classification-Illustration-of-the-separation-of-data-samples.png)

# %% [markdown]
# ![ml-intro-types-of-models.webp](attachment:ml-intro-types-of-models.webp)
