# %% [markdown]
#  PCA
#  Principal Component Analysis
#
# Introduction to Dimentionality Reduction
#
# What is PCA?
#
# Computing Compponents in PCA
#
# Dimentionality Reduction using PCA
# https://www.geeksforgeeks.org/principal-component-analysis-pca/
#
# https://builtin.com/data-science/step-step-explanation-principal-component-analysis   animations
#
# https://www.kaggle.com/code/tanmay111999/clustering-pca-k-means-dbscan-hierarchical
#
# https://www.kaggle.com/code/prashant111/eda-logistic-regression-pca

# %% [markdown]
# ![a.gif](https://builtin.com/sites/www.builtin.com/files/inline-images/national/Principal%2520Component%2520Analysis%2520second%2520principal.gif)

# %% [markdown]
# ### Principal Component Analysis (PCA)
#
# **Introduction to Dimensionality Reduction**
#
# Dimensionality reduction is a technique used in machine learning and statistics to reduce the number of input variables (features) in a dataset while preserving important information. High-dimensional datasets can be challenging to analyze and visualize, and they may suffer from the "curse of dimensionality," which can lead to overfitting. PCA is one of the most commonly used methods for dimensionality reduction.
#
# ---
#
# ### What is PCA?
#
# Principal Component Analysis (PCA) is a statistical technique that transforms a dataset into a set of orthogonal (uncorrelated) components, called principal components. These components capture the maximum variance in the data. PCA is often used for:
#
# - **Data visualization**: Reducing dimensions for easier plotting.
# - **Noise reduction**: Eliminating less significant features that may introduce noise.
# - **Feature extraction**: Creating new features based on existing ones.
#
# ---
#
# ### Computing Components in PCA
#
# The steps to compute the principal components in PCA are as follows:
#
# 1. **Standardization**: Scale the data so that each feature has a mean of 0 and a standard deviation of 1. This is important because PCA is sensitive to the variances of the features.
#
# 2. **Covariance Matrix**: Compute the covariance matrix to understand how the dimensions vary with respect to each other.
#
# 3. **Eigenvalues and Eigenvectors**: Calculate the eigenvalues and eigenvectors of the covariance matrix. The eigenvectors represent the direction of the new feature space, while the eigenvalues represent the magnitude (variance) along those directions.
#
# 4. **Sort Eigenvalues**: Sort the eigenvalues in descending order and choose the top k eigenvalues and their corresponding eigenvectors to form a new feature space.
#
# 5. **Transform the Data**: Project the original data onto the new feature space using the selected eigenvectors.
#
# ---
#
# ### Dimensionality Reduction using PCA
#
# Here’s how to implement PCA for dimensionality reduction in Python using the `scikit-learn` library. We will use the Iris dataset as an example.

# %% [markdown]
# - Principal Component Analysis (PCA) is a machine learning technique that reduces the dimensionality of large datasets while preserving the most relevant information:
#
# ### How it works
#
# PCA projects high-dimensional data into a lower-dimensional subspace, extracting the most informative features. It does this by finding the eigenvectors of the covariance matrix to identify the directions of maximum variance in the data.
#
# ### Benefits
# PCA reduces model complexity, minimizes multicollinearity and overfitting, and makes data easier to plot in 2D and 3D.
#
# #### Use cases
# PCA is commonly used for data preprocessing in machine learning algorithms, but it can also be used in pattern recognition, signal processing, and image processing.
# #### Unsupervised learning
#
# PCA is an unsupervised learning technique, which means that it can cluster similar data points without any supervision or labels.
# Here are some steps in the data science process that use PCA:
# - Collect relevant data
# - Explore and clean the data to discover patterns
# - Preprocess the data with PCA
# - Train your machine learning model
# - Evaluate the model with a variety of metrics

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load the Iris dataset
data = load_iris()
X = data.data  # Feature data
y = data.target  # Target labels

# Step 1: Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 2: PCA
pca = PCA(n_components=2)  # Reduce to 2 dimensions
X_pca = pca.fit_transform(X_scaled)

# Step 3: Explained variance
explained_variance = pca.explained_variance_ratio_
print(f'Explained variance by each component: {explained_variance}')

# Step 4: Plotting the PCA result
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.title('PCA of Iris Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(scatter, label='Classes')
plt.grid()
plt.show()
# Out:
# Explained variance by each component: [0.72962445 0.22850762]

# %% [markdown]
# ### Explanation of the Code
#
# 1. **Import Libraries**: The necessary libraries for data manipulation, PCA, and visualization are imported.
#
# 2. **Load the Dataset**: The Iris dataset is loaded, consisting of four features and three classes.
#
# 3. **Standardization**: The feature data is standardized to ensure each feature contributes equally.
#
# 4. **PCA**: PCA is applied to reduce the dimensionality of the dataset to 2 dimensions.
#
# 5. **Explained Variance**: The explained variance of the principal components is printed, showing how much variance each component captures.
#
# 6. **Plotting**: A scatter plot of the first two principal components is created, colored by the target classes, to visualize the results.
#
# ---
#
# ### Conclusion
#
# PCA is a powerful tool for dimensionality reduction that can simplify complex datasets while retaining essential information. It can help improve the performance of machine learning models, facilitate visualization, and reduce computational costs. By understanding how to implement and interpret PCA, you can effectively analyze and visualize high-dimensional data.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the Iris dataset
data = load_iris()
X = data.data  # Feature data
y = data.target  # Target labels

# %%
# Step 1: Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Step 2: Visualization before PCA (using only the first two features for simplicity)
plt.figure(figsize=(12, 5))

# Scatter plot of original data (first two features)
plt.subplot(1, 2, 1)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y, cmap='viridis', edgecolor='k')
plt.title('Original Data (First Two Features)')
plt.xlabel('Feature 1 (Standardized)')
plt.ylabel('Feature 2 (Standardized)')
plt.grid()

# Step 3: PCA
pca = PCA(n_components=2)  # Reduce to 2 dimensions
X_pca = pca.fit_transform(X_scaled)

# Step 4: Visualization after PCA
plt.subplot(1, 2, 2)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k')
plt.title('PCA Reduced Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid()

# Show both plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Sure! Here’s how to visualize the Iris dataset both before and after applying PCA. This will help you see the effect of dimensionality reduction visually. We'll use 2D scatter plots to show the data in its original 4D space (projected onto two dimensions) and its PCA-reduced 2D space.
#
# ### Explanation of the Code
#
# 1. **Import Libraries**: We import the necessary libraries for data handling, PCA, and visualization.
#
# 2. **Load the Dataset**: The Iris dataset is loaded, which has four features and three classes.
#
# 3. **Standardization**: The features are standardized to ensure equal contribution.
#
# 4. **Original Data Visualization**:
#    - We create a scatter plot of the original data using only the first two features. This helps visualize how the original data looks in its raw form.
#
# 5. **PCA**: PCA is applied to reduce the dataset to two dimensions.
#
# 6. **PCA Visualization**:
#    - We create a scatter plot of the data after applying PCA, showing how the dataset is represented in the new feature space.
#
# 7. **Show Plots**: Both plots are displayed side by side for comparison.
#
# ### Conclusion
#
# This visualization allows you to see how PCA transforms high-dimensional data into a lower-dimensional space while preserving the structure of the data. The original data may show some clustering, and PCA aims to capture the most important variance in this reduced form.

# %% [markdown]
# ### class Code

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.datasets import load_iris

# %%
data = load_iris()
X = data.data
y = data.target

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %%
X_train = pca.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-2.13962242e+00,  5.13610868e-01,  1.99419486e-01,
#         -2.31008729e-02],
#        [-1.99540185e+00,  8.82301128e-01,  5.29591179e-01,
#         -2.21415708e-01],
#        [ 2.56560809e+00,  2.52456203e+00,  3.36324212e-01,
#          2.37570906e-01],
#        [ 1.88179210e+00,  6.13593714e-01,  9.89270342e-02,
#         -2.09039180e-01],
#        [ 2.32153724e+00,  2.67012730e-01,  7.22437857e-01,
#          2.14630593e-01],
#        [ 1.84467374e+00, -2.44516671e-01, -3.16505830e-01,
#         -9.86626870e-02],
#        [ 1.15280787e+00, -3.50084715e-01, -1.09329969e-01,
#         -1.27100336e-01],
#        [ 4.79050797e-01,  9.52879660e-01, -3.61253884e-01,
#          1.00480704e-01],
#        [ 2.91219047e+00,  1.91581270e-01,  9.30781970e-01,
#          1.01054283e-01],
#        [ 8.67557056e-02, -1.11609550e-01, -1.08336251e-01,
#          2.25107361e-01],
#        [-2.30153266e+00,  4.10609890e-01, -7.68242776e-02,
#          1.23172991e-01],
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)


pca = PCA(n_components=4)
X_train = pca.fit_transform(X_train)

# %%
X_train

# %%
pca.components_
# Out:
# array([[ 0.539189  , -0.20375871,  0.58658648,  0.56892346],
#        [ 0.28543082,  0.95620505,  0.00732108,  0.06440146],
#        [ 0.74201139, -0.17785208, -0.12967908, -0.63322277],
#        [-0.27789129,  0.11190588,  0.79940355, -0.52077583]])

# %%
np.cumsum(pca.explained_variance_ratio_) #more than 90 percent variance you got, good to go
# Out:
# array([0.71618786, 0.95565244, 0.99547945, 1.        ])

# %%
import matplotlib.pyplot as plt

# unused but required import for doing 3d projections with matplotlib < 3.2
import mpl_toolkits.mplot3d  # noqa: F401
import numpy as np

from sklearn import datasets, decomposition

np.random.seed(5)

iris = datasets.load_iris()
X = iris.data
y = iris.target

fig = plt.figure(1, figsize=(4, 3))
plt.clf()

ax = fig.add_subplot(111, projection="3d", elev=48, azim=134)
ax.set_position([0, 0, 0.95, 1])


plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

for name, label in [("Setosa", 0), ("Versicolour", 1), ("Virginica", 2)]:
    ax.text3D(
        X[y == label, 0].mean(),
        X[y == label, 1].mean() + 1.5,
        X[y == label, 2].mean(),
        name,
        horizontalalignment="center",
        bbox=dict(alpha=0.5, edgecolor="w", facecolor="w"),
    )
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral, edgecolor="k")

ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.zaxis.set_ticklabels([])

plt.show()
