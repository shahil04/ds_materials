# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"c:\Users\hp\Downloads\archive (8)\loan_data_set.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
# data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# simple Linear regression --> y = mx+c 
#  one input or one output

# %%
df.dropna(axis=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 480 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            480 non-null    object
#  1   Gender             480 non-null    object
#  2   Married            480 non-null    object
#  3   Dependents         480 non-null    object
#  4   Education          480 non-null    object
#  5   Self_Employed      480 non-null    object
#  6   ApplicantIncome    480 non-null    int64
#  7   CoapplicantIncome  480 non-null    float64
#  8   LoanAmount         480 non-null    float64
#  9   Loan_Amount_Term   480 non-null    float64
#  10  Credit_History     480 non-null    float64
#  11  Property_Area      480 non-null    object
#  12  Loan_Status        480 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.5+ KB

# %%
# x or input variable
df["ApplicantIncome"]
# x = df[["ApplicantIncome"]]
# Out:
# 1      4583
# 2      3000
# 3      2583
# 4      6000
# 5      5417
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 480, dtype: int64

# %%
# y or target variable
df["LoanAmount"]

# y =df[["LoanAmount"]]
# Out:
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
# 5      267.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 480, dtype: float64

# %%
# split the for model creations in training and testing
from sklearn.model_selection import  train_test_split
x_train ,x_test, y_train, y_test = train_test_split(df[["ApplicantIncome"]],df[["LoanAmount"]],test_size=.2, random_state=3)

# %%
x_train
# Out:
#      ApplicantIncome
# 41              1800
# 462             3015
# 485             1958
# 164             9323
# 207             3975
# ..               ...
# 563             5800
# 169             8000
# 316             3717
# 195             3125
# 464             4166
#
# [384 rows x 1 columns]

# %%
x_test
# Out:
#      ApplicantIncome
# 37              3667
# 140             5042
# 85              2366
# 420             5829
# 384             4566
# ..               ...
# 315             3399
# 32              4692
# 224             6250
# 481             3095
# 489             2435
#
# [96 rows x 1 columns]

# %%
# model implement linear regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# train the model to find the cofficient and intercept (m, c)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[0.00765988]])

# %%
model.intercept_
# Out:
# array([103.88294744])

# %%
# y = 0.006X + 110
y_predict = model.predict(x_test)
y_predict
# Out:
# array([[131.97171304],
#        [142.50404266],
#        [122.00621426],
#        [148.53236514],
#        [138.85794164],
#        [147.7433979 ],
#        [164.76364256],
#        [243.02459651],
#        [128.24135339],
#        [180.48170828],
#        [123.08625679],
#        [146.13482392],
#        [116.65962075],
#        [151.75717297],
#        [171.28219711],
#        [141.54655815],
#        [123.79862526],
#        [149.25239349],
#        [141.10994521],
#        [230.46239973],
#        [157.11908623],
#        [191.33575269],
#        [128.61668732],
#        [127.33748801],
#        [216.35290798],
#        [178.20672509],
#        [124.30417708],
#        [121.01809024],
#        [118.2452151 ],
#        [132.79897966],
#        [215.58692038],
#        [139.24093545],
#        [162.55759825],
#        [130.7691125 ],
#        [176.71304925],
#        [138.98815954],
#        [140.97972732],
#        [123.10923641],
#        [137.4638442 ],
#        [122.90241976],
#        [131.36658283],
#        [121.56960132],
#        [133.50368826],
#        [132.04065193],
#        [137.07319052],
#        [150.57755205],
#        [122.87178026],
#        [139.16433669],
#        [123.23179443],
#        [128.95372187],
#        [149.84220395],
#        [141.31676187],
#        [149.84220395],
#        [136.72849609],
#        [218.77342883],
#        [128.13411513],
#        [176.68240975],
#        [138.98815954],
#        [124.76376965],
#        [134.43053327],
#        [167.71269485],
#        [126.05828871],
#        [128.74690521],
#        [132.60748276],
#        [133.44240925],
#        [403.7441165 ],
#        [164.64874442],
#        [132.25512846],
#        [224.59493465],
#        [145.17733941],
#        [122.45814695],
#        [119.54739404],
#        [137.64768122],
#        [151.75717297],
#        [105.03192886],
#        [129.97248539],
#        [153.03637227],
#        [142.18232786],
#        [132.60748276],
#        [160.88008538],
#        [119.14908048],
#        [144.2198549 ],
#        [163.53040251],
#        [127.42174665],
#        [136.8204146 ],
#        [145.76714987],
#        [122.96369877],
#        [128.45582992],
#        [137.15744915],
#        [123.62244811],
#        [128.141775  ],
#        [129.91886625],
#        [139.82308603],
#        [151.75717297],
#        [127.59026392],
#        [122.53474571]])

# %%
y_test
# Out:
#      LoanAmount
# 37        144.0
# 140       185.0
# 85        136.0
# 420       138.0
# 384       100.0
# ..          ...
# 315       111.0
# 32        106.0
# 224       128.0
# 481       113.0
# 489        75.0
#
# [96 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mean_absolute_error(y_test, y_predict)
# Out:
# np.float64(48.765371958066225)

# %%
# accuracy check
r2_score(y_test, y_predict)
# Out:
# -0.026403910468808967

# %% [markdown]
# ### MULTI- LINEAR REGRESSION

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# 5               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [480 rows x 13 columns]

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History
# count      480.000000
# mean         0.854167
# std          0.353307
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.dropna(inplace= True)

# %%
df[["ApplicantIncome","CoapplicantIncome","LoanAmount","Loan_Amount_Term","Credit_History"]]
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# 5               1.0
# ..              ...
# 609             1.0
# 610             1.0
# 611             1.0
# 612             1.0
# 613             0.0
#
# [480 rows x 5 columns]

# %%
x = df[["ApplicantIncome","CoapplicantIncome","Loan_Amount_Term","Credit_History"]]
x
# Out:
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History
# 1               4583             1508.0             360.0             1.0
# 2               3000                0.0             360.0             1.0
# 3               2583             2358.0             360.0             1.0
# 4               6000                0.0             360.0             1.0
# 5               5417             4196.0             360.0             1.0
# ..               ...                ...               ...             ...
# 609             2900                0.0             360.0             1.0
# 610             4106                0.0             180.0             1.0
# 611             8072              240.0             360.0             1.0
# 612             7583                0.0             360.0             1.0
# 613             4583                0.0             360.0             0.0
#
# [480 rows x 4 columns]

# %%
y = df[["LoanAmount"]]
y
# Out:
#      LoanAmount
# 1         128.0
# 2          66.0
# 3         120.0
# 4         141.0
# 5         267.0
# ..          ...
# 609        71.0
# 610        40.0
# 611       253.0
# 612       187.0
# 613       133.0
#
# [480 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=65)
model2 = LinearRegression()
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model2.coef_
# Out:
# array([[ 0.00771078,  0.00562096,  0.05675914, -0.8361798 ]])

# %%
model2.intercept_
# Out:
# array([74.92518009])

# %%
# predict
y_pred = model2.predict(x_test)
mean_squared_error(y_test,y_pred)
r2_score(y_test,y_pred)
# Out:
# 0.18327176016515767

# %%
model2.score(x_test,y_test)
# Out:
# 0.18327176016515767

# %%
model2.score(x_test,y_test)
# Out:
# 0.18327176016515767

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# 5               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [480 rows x 13 columns]

# %%
# !pip install streamlit

# %%
# from sklearn import svm
# from sklearn import datasets

# iris = datasets.load_iris()
# X, y = iris.data, iris.target

# clf = svm.SVC()
# clf.fit(X, y)  

# ##########################
# # SAVE-LOAD using pickle #
# ##########################
# import pickle

# # save
# with open('model.pkl','wb') as f:
#     pickle.dump(clf,f)

# # load
# with open('model.pkl', 'rb') as f:
#     clf2 = pickle.load(f)

# clf2.predict(X[0:1])

# %%
import pickle
# save
with open('linear_regression_model.pkl','wb') as f:
    pickle.dump(model2,f)

# %%
# Regression predictions

import pickle
# save
with open('linear_regression_model.pkl','wb') as f:
    pickle.dump(model2,f)
import streamlit as st
import pandas as pd
import numpy as np
import pickle

# Load the trained regression model
with open("linear_regression_model.pkl", "rb") as file:
    model = pickle.load(file)

st.title("Loan Amount Prediction")
st.write("Enter the required details to predict the loan amount.")

# Input fields for user
applicant_income = st.number_input("Applicant Income", min_value=0)
coapplicant_income = st.number_input("Coapplicant Income", min_value=0)
loan_amount_term = st.number_input("Loan Amount Term", min_value=0)
credit_history = st.selectbox("Credit History", [0, 1])

# Predict button
if st.button("Predict Loan Amount"):
    # Create a DataFrame with user input
    input_data = pd.DataFrame(
        [[applicant_income, coapplicant_income, loan_amount_term, credit_history]],
        columns=["ApplicantIncome", "CoapplicantIncome", "Loan_Amount_Term", "Credit_History"]
    )
    
    # Predict loan amount
    predicted_loan_amount = model.predict(input_data)[0]
    
    st.success(f"Predicted Loan Amount: {predicted_loan_amount:.2f}")

st.write("Upload a dataset for batch predictions")
uploaded_file = st.file_uploader("Upload CSV", type=["csv"])

if uploaded_file is not None:
    df = pd.read_csv(uploaded_file)
    predictions = model.predict(df)
    df["Predicted Loan Amount"] = predictions
    st.write(df)
    df.to_csv("predicted_loans.csv", index=False)
    st.download_button("Download Predictions", "predicted_loans.csv")

# streamlit run streamlit_loan.py
# Out:
# 2025-02-06 15:45:13.015 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.932
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-02-06 15:45:15.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.990 Session state does not function when running a script without `streamlit run`
# 2025-02-06 15:45:15.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:15.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:16.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# # Logistic regression
# y --> categorical data

# %%
df = pd.read_csv("loan_data_set.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
from sklearn.preprocessing import  LabelEncoder

l = LabelEncoder()
y  = l.fit_transform(df["Loan_Status"])
y = pd.DataFrame(y)

df["Loan_Status"] =  y

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area  Loan_Status
# 0               1.0         Urban            1
# 1               1.0         Rural            0
# 2               1.0         Urban            1
# 3               1.0         Urban            1
# 4               1.0         Urban            1
# ..              ...           ...          ...
# 609             1.0         Rural            1
# 610             1.0         Rural            1
# 611             1.0         Urban            1
# 612             1.0         Urban            1
# 613             0.0     Semiurban            0
#
# [614 rows x 13 columns]

# %%
df.drop("Loan_ID",axis=1, inplace=True)

# %%
for i in df.columns:
    if df[i].dtype =="O":
        print(i)
        y  = l.fit_transform(df[i])
        df[i] =  pd.DataFrame(y)

df
# Out:
# Gender
# Married
# Dependents
# Education
# Self_Employed
# Property_Area
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#      Property_Area  Loan_Status
# 0                2            1
# 1                0            0
# 2                2            1
# 3                2            1
# 4                2            1
# ..             ...          ...
# 609              0            1
# 610              0            1
# 611              2            1
# 612              2            1
# 613              1            0
#
# [614 rows x 12 columns]

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# Gender                 int64
# Married                int64
# Dependents             int64
# Education              int64
# Self_Employed          int64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int64
# Loan_Status            int64
# dtype: object

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# 5         1        1           2          0              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# 5               4196.0       267.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#      Property_Area  Loan_Status
# 1                0            0
# 2                2            1
# 3                2            1
# 4                2            1
# 5                2            1
# ..             ...          ...
# 609              0            1
# 610              0            1
# 611              2            1
# 612              2            1
# 613              1            0
#
# [529 rows x 12 columns]

# %%
# classifications  y --> categorical data
# regression  y --> continuous data
y = df["Loan_Status"]
y

x = df.drop("Loan_Status",axis=1)
x

x = df[["ApplicantIncome","CoapplicantIncome","Loan_Amount_Term","LoanAmount","Credit_History"]]
x
# Out:
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  LoanAmount  \
# 1               4583             1508.0             360.0       128.0
# 2               3000                0.0             360.0        66.0
# 3               2583             2358.0             360.0       120.0
# 4               6000                0.0             360.0       141.0
# 5               5417             4196.0             360.0       267.0
# ..               ...                ...               ...         ...
# 609             2900                0.0             360.0        71.0
# 610             4106                0.0             180.0        40.0
# 611             8072              240.0             360.0       253.0
# 612             7583                0.0             360.0       187.0
# 613             4583                0.0             360.0       133.0
#
#      Credit_History
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# 5               1.0
# ..              ...
# 609             1.0
# 610             1.0
# 611             1.0
# 612             1.0
# 613             0.0
#
# [529 rows x 5 columns]

# %%
from sklearn.linear_model import LogisticRegression

x_train,x_test,y_train, y_test = train_test_split(x,y , test_size=.2, random_state=30)

# model obj
lr = LogisticRegression(solver="liblinear")
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
lr.score(x_test,y_test)
# Out:
# 0.7924528301886793

# %%
import pandas as pd

# %%
input_data = pd.DataFrame(
        [[10000,20000,24, 10000,0]],
        columns=["ApplicantIncome","CoapplicantIncome","Loan_Amount_Term","LoanAmount","Credit_History"]
    )
input_data
# Out:
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  LoanAmount  \
# 0            10000              20000                24       10000
#
#    Credit_History
# 0               0

# %%
lr.predict(input_data)
# Out:
# array([0])

# %%
y_predict = lr.predict(x_test)

# %%
import pickle

with open("model1.pkl","wb") as f:
    pickle.dump(lr,f)

# %%
# evaluation matrix
from sklearn.metrics import accuracy_score, confusion_matrix ,classification_report
accuracy_score(y_test, y_predict)
# Out:
# 0.7924528301886793

# %%
print(confusion_matrix(y_test, y_predict))
# Out:
# [[11 21]
#  [ 1 73]]

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.34      0.50        32
#            1       0.78      0.99      0.87        74
#
#     accuracy                           0.79       106
#    macro avg       0.85      0.67      0.68       106
# weighted avg       0.82      0.79      0.76       106

# %%
import pickle
# save
with open('logistic_regression_model.pkl','wb') as f:
    pickle.dump(lr,f)

# %%
# logistic_regression_model predictions
import streamlit as st
import pandas as pd
import numpy as np
import pickle

# Load the trained regression model
with open("logistic_regression_model.pkl", "rb") as file:
    model = pickle.load(file)

st.title("Loan Amount Prediction")
st.write("Enter the required details to predict the loan amount.")

# Input fields for user
applicant_income = st.number_input("Applicant Income", min_value=0)
coapplicant_income = st.number_input("Coapplicant Income", min_value=0)
loan_amount_term = st.number_input("Loan Amount Term", min_value=0)
LoanAmount = st.number_input("Loan Amount ", min_value=0)
credit_history = st.selectbox("Credit History", [0, 1])

# Predict button
if st.button("Predict Loan Amount"):
    # Create a DataFrame with user input
    input_data = pd.DataFrame(
        [[applicant_income, coapplicant_income, loan_amount_term,LoanAmount, credit_history]],
        columns=["ApplicantIncome","CoapplicantIncome","Loan_Amount_Term","LoanAmount","Credit_History"]
    )
    
    # Predict loan amount
    predicted_loan_amount = model.predict(input_data)[0]
    
    if predicted_loan_amount:
        st.success(f"Hurry you are Eligible for Loan Amount: {predicted_loan_amount}")
    else:
        st.success(f"OH! No: No Eligible for Loan: {predicted_loan_amount}")

st.write("Upload a dataset for batch predictions")
uploaded_file = st.file_uploader("Upload CSV", type=["csv"])

if uploaded_file is not None:
    df = pd.read_csv(uploaded_file)
    predictions = model.predict(df)
    df["Predicted Loan Amount"] = predictions
    st.write(df)
    df.to_csv("predicted_loans.csv", index=False)
    st.download_button("Download Predictions", "predicted_loans.csv")

#  streamlit -m run streamlit_loan.py
# Out:
# 2025-02-06 15:45:19.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 15:45:19.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### Algorithms in ML
# classification Logistic Regression , KNN , SVM(SVC) , DT(DTC)-> boosting , random forest,
# Regrgssion --> Linear regresion ,SVM(SVR) , DT(DTR) (random forest)
#
# Unsupervised Learning --> K-means, DBSCAN,PCA, Hierarchical Clustering

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
# 5       1        1           2          0              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              2            1
# 3              2            1
# 4              2            1
# 5              2            1

# %%
# import MOdel
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=5,)
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pridict = knn_model.predict(x_test)
accuracy_score(y_test, y_pridict)
# Out:
# 0.6226415094339622

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.6226415094339622

# %%
param_grid ={  "n_neighbors": [1,3,5,7],
             "algorithms":['ball_tree', 'kd_tree']}

# %%
# hyperparameter tuning
from sklearn.model_selection import GridSearchCV

grid_model = GridSearchCV(knn_model,param_grid,cv=5,scoring="accuracy",verbose=3)
grid_model.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 5
#       2 from sklearn.model_selection import GridSearchCV
#       4 grid_model = GridSearchCV(knn_model,param_grid,cv=5,scoring="accuracy",verbose=3)
# ----> 5 grid_model.fit(x_train,y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:876, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     869 score_params_test = _check_method_params(X, params=score_params, indices=test)
#     871 if parameters is not None:
#     872     # here we clone the parameters, since sometimes the parameters
#     873     # themselves might be estimators, e.g. when we search over different
#     874     # estimators in a pipeline.
#     875     # ref: https://github.com/scikit-learn/scikit-learn/pull/26786
# --> 876     estimator = estimator.set_params(**clone(parameters, safe=False))
#     878 start_time = time.time()
#     880 X_train, y_train = _safe_split(estimator, X, y, train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:279, in BaseEstimator.set_params(self, **params)
#     277 if key not in valid_params:
#     278     local_valid_params = self._get_param_names()
# --> 279     raise ValueError(
#     280         f"Invalid parameter {key!r} for estimator {self}. "
#     281         f"Valid parameters are: {local_valid_params!r}."
#     282     )
#     284 if delim:
#     285     nested_params[key][sub_key] = value
#
# ValueError: Invalid parameter 'algorithms' for estimator KNeighborsClassifier(). Valid parameters are: ['algorithm', 'leaf_size', 'metric', 'metric_params', 'n_jobs', 'n_neighbors', 'p', 'weights'].

# %%
grid_model.best_score_
best_best = grid_model.best_estimator_

# %%
# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV ,RandomizedSearchCV

param_grid = {"n_neighbors": [3, 5, 6],
             'algorithm': ['ball_tree', 'brute', 'kd_tree'],
             'leaf_size': [20, 30, 40]}

# Grid Search
grid_model = GridSearchCV(knn_model, param_grid, cv=5, scoring='accuracy',verbose=3)
grid_model

# %%
grid_model.fit(x_train,y_train)

# %%
grid_model.best_score_

# %%
grid_model.best_params_

# %%
best_model = grid_model.best_estimator_

y_predict = best_model.predict(x_test)
accuracy_score(y_test, y_predict )
