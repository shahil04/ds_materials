# %%
import os
import json
import requests

# Path to your .txt file (update this if needed)
# Path to your .txt file (update this)
INPUT_FILE = r"C:\Users\hp\Documents\class work or project\ds_materials\ppt\aws_itv_fsd\aws_pp.txt"
BASE_DIR = "Presentations"
# Step 1: Read the .txt file and load JSON
with open(INPUT_FILE, "r", encoding="utf-8") as f:
    content = f.read().strip()
    data = json.loads(content)

# Step 2: Create base folder
os.makedirs(BASE_DIR, exist_ok=True)

# Helper function: sanitize names
def sanitize_filename(name):
    return "".join(c if c.isalnum() or c in " -_&" else "_" for c in name)

# Step 3: Loop through the data with sequence numbers
for module_idx, module in enumerate(data, start=1):
    heading = sanitize_filename(module["heading"]).strip()
    folder_name = f"{module_idx:02d}_{heading}"
    folder_path = os.path.join(BASE_DIR, folder_name)
    os.makedirs(folder_path, exist_ok=True)

    print(f"\n📁 Folder: {folder_name}")

    for item_idx, item in enumerate(module["items"], start=1):
        title = sanitize_filename(item["title"]).strip()
        link = item["link"]

        if not link:
            print(f"   ⚠️ Skipping '{title}' (no link)")
            continue

        # Detect or default extension
        ext = os.path.splitext(link)[1] or ".html"
        file_name = f"{item_idx:02d}_{title}{ext}"
        file_path = os.path.join(folder_path, file_name)

        print(f"   ⬇️ Downloading {title}...")

        try:
            resp = requests.get(link, timeout=20)
            resp.raise_for_status()
            with open(file_path, "wb") as f:
                f.write(resp.content)
            print(f"   ✅ Saved as: {file_name}")
        except Exception as e:
            print(f"   ❌ Failed to download {title}: {e}")

print("\n🎉 All downloads completed successfully!")
# Out:
# 📁 Folder: 01_Stepping into The World of Cloud Computing
#    ⬇️ Downloading Getting started with Cloud...
#    ✅ Saved as: 01_Getting started with Cloud.html
#    ⬇️ Downloading Exploring The World of AWS...
#    ✅ Saved as: 02_Exploring The World of AWS.html
#    ⬇️ Downloading IAM_ Unlocking AWS Security...
#    ✅ Saved as: 03_IAM_ Unlocking AWS Security.html
#    ⬇️ Downloading Crafting IAM Groups and Roles...
#    ✅ Saved as: 04_Crafting IAM Groups and Roles.html
#    ⬇️ Downloading Deep Dive Into IAM...
#    ✅ Saved as: 05_Deep Dive Into IAM.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 📁 Folder: 02_Getting started with Computing
#    ⬇️ Downloading EC2 Mastery_ Fundamentals to Pricing...
#    ✅ Saved as: 01_EC2 Mastery_ Fundamentals to Pricing.html
#    ⬇️ Downloading EC2 Launch Essentials...
#    ✅ Saved as: 02_EC2 Launch Essentials.html
#    ⬇️ Downloading Autoscaling Your Cloud Fleet...
#    ✅ Saved as: 03_Autoscaling Your Cloud Fleet.html
#    ⬇️ Downloading Mastering ELB_ Types & Algorithms...
#    ✅ Saved as: 04_Mastering ELB_ Types & Algorithms.html
#    ⬇️ Downloading Beyond Servers_ Architecting Modern Web Apps...
#    ✅ Saved as: 05_Beyond Servers_ Architecting Modern Web Apps.html
#    ⬇️ Downloading Monitoring The Cloud...
#    ✅ Saved as: 06_Monitoring The Cloud.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 📁 Folder: 03_Deep Dive Into Storage
#    ⬇️ Downloading S3 Mastery_ Unlocking Cloud Storage...
#    ✅ Saved as: 01_S3 Mastery_ Unlocking Cloud Storage.html
#    ⬇️ Downloading Optimize Storage with EBS...
#    ✅ Saved as: 02_Optimize Storage with EBS.html
#    ⬇️ Downloading Master RDS in a Flash...
#    ✅ Saved as: 03_Master RDS in a Flash.html
#    ⬇️ Downloading DynamoDB Unveiled_ Key Insights...
#    ✅ Saved as: 04_DynamoDB Unveiled_ Key Insights.html
#    ⬇️ Downloading Database Dynamics...
#    ✅ Saved as: 05_Database Dynamics.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 📁 Folder: 04_Exploring Networking essentials in AWS
#    ⬇️ Downloading Networking with VPC...
#    ✅ Saved as: 01_Networking with VPC.html
#    ⬇️ Downloading Understanding VPC Gateways...
#    ✅ Saved as: 02_Understanding VPC Gateways.html
#    ⬇️ Downloading Route 53 Mastery...
#    ✅ Saved as: 03_Route 53 Mastery.html
#    ⬇️ Downloading Cloudfront Magic_ Geo-targeted Delivery...
#    ✅ Saved as: 04_Cloudfront Magic_ Geo-targeted Delivery.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 📁 Folder: 05_Mastering Devops  Essentials
#    ⬇️ Downloading Cracking The DevOps Code...
#    ✅ Saved as: 01_Cracking The DevOps Code.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 📁 Folder: 06_Linux Fundamentals and Scripting Mastery
#    ⬇️ Downloading Diving Into Linux Essentials...
#    ✅ Saved as: 01_Diving Into Linux Essentials.html
#    ⬇️ Downloading The Art Of Editing & Securing Files...
#    ✅ Saved as: 02_The Art Of Editing & Securing Files.html
#    ⬇️ Downloading Unlocking The Power Of Shell Scripting...
#    ✅ Saved as: 03_Unlocking The Power Of Shell Scripting.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 📁 Folder: 07_Mastering DevOps & Docker Essentials
#    ⬇️ Downloading Docker_ Shipping Code Made Simple...
#    ✅ Saved as: 01_Docker_ Shipping Code Made Simple.html
#    ⬇️ Downloading Commanding the Container Ship...
#    ✅ Saved as: 02_Commanding the Container Ship.html
#    ⬇️ Downloading Scaling With Docker Storage Solutions...
#    ✅ Saved as: 03_Scaling With Docker Storage Solutions.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 📁 Folder: 08_Kubernetes In Action
#    ⬇️ Downloading Diving Into Kubernetes_ From Nodes To Pods...
#    ✅ Saved as: 01_Diving Into Kubernetes_ From Nodes To Pods.html
#    ⬇️ Downloading Mastering Deployments In  A Flash...
#    ✅ Saved as: 02_Mastering Deployments In  A Flash.html
#    ⬇️ Downloading Journey With Pods & Storage...
#    ✅ Saved as: 03_Journey With Pods & Storage.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 📁 Folder: 09_Unlocking CI_CD In AWS
#    ⬇️ Downloading Build & Automate With AWS...
#    ✅ Saved as: 01_Build & Automate With AWS.html
#    ⬇️ Downloading Transformers Of AWS DevOps...
#    ✅ Saved as: 02_Transformers Of AWS DevOps.html
#    ⚠️ Skipping 'Assignment' (no link)
#
# 🎉 All downloads completed successfully!
