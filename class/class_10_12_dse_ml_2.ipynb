# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"c:\Users\hp\Downloads\archive (8)\loan_data_set.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# simple Linear regression --> y = mx+c 
#  one input or one output

# %%
df.dropna(axis=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 480 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            480 non-null    object
#  1   Gender             480 non-null    object
#  2   Married            480 non-null    object
#  3   Dependents         480 non-null    object
#  4   Education          480 non-null    object
#  5   Self_Employed      480 non-null    object
#  6   ApplicantIncome    480 non-null    int64
#  7   CoapplicantIncome  480 non-null    float64
#  8   LoanAmount         480 non-null    float64
#  9   Loan_Amount_Term   480 non-null    float64
#  10  Credit_History     480 non-null    float64
#  11  Property_Area      480 non-null    object
#  12  Loan_Status        480 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.5+ KB

# %%
# x or input variable
df["ApplicantIncome"]
# x = df[["ApplicantIncome"]]
# Out:
# 1      4583
# 2      3000
# 3      2583
# 4      6000
# 5      5417
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 480, dtype: int64

# %%
# y or target variable
df["LoanAmount"]

# y =df[["LoanAmount"]]
# Out:
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
# 5      267.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 480, dtype: float64

# %%
# split the for model creations in training and testing
from sklearn.model_selection import  train_test_split
x_train ,x_test, y_train, y_test = train_test_split(df[["ApplicantIncome"]],df[["LoanAmount"]],test_size=.2, random_state=3)

# %%
x_train
# Out:
#      ApplicantIncome
# 41              1800
# 462             3015
# 485             1958
# 164             9323
# 207             3975
# ..               ...
# 563             5800
# 169             8000
# 316             3717
# 195             3125
# 464             4166
#
# [384 rows x 1 columns]

# %%
x_test
# Out:
#      ApplicantIncome
# 37              3667
# 140             5042
# 85              2366
# 420             5829
# 384             4566
# ..               ...
# 315             3399
# 32              4692
# 224             6250
# 481             3095
# 489             2435
#
# [96 rows x 1 columns]

# %%
# model implement linear regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# train the model to find the cofficient and intercept (m, c)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[0.00765988]])

# %%
model.intercept_
# Out:
# array([103.88294744])

# %%
# y = 0.006X + 110
y_predict = model.predict(x_test)
y_predict
# Out:
# array([[131.97171304],
#        [142.50404266],
#        [122.00621426],
#        [148.53236514],
#        [138.85794164],
#        [147.7433979 ],
#        [164.76364256],
#        [243.02459651],
#        [128.24135339],
#        [180.48170828],
#        [123.08625679],
#        [146.13482392],
#        [116.65962075],
#        [151.75717297],
#        [171.28219711],
#        [141.54655815],
#        [123.79862526],
#        [149.25239349],
#        [141.10994521],
#        [230.46239973],
#        [157.11908623],
#        [191.33575269],
#        [128.61668732],
#        [127.33748801],
#        [216.35290798],
#        [178.20672509],
#        [124.30417708],
#        [121.01809024],
#        [118.2452151 ],
#        [132.79897966],
#        [215.58692038],
#        [139.24093545],
#        [162.55759825],
#        [130.7691125 ],
#        [176.71304925],
#        [138.98815954],
#        [140.97972732],
#        [123.10923641],
#        [137.4638442 ],
#        [122.90241976],
# ...

# %%
y_test
# Out:
#      LoanAmount
# 37        144.0
# 140       185.0
# 85        136.0
# 420       138.0
# 384       100.0
# ..          ...
# 315       111.0
# 32        106.0
# 224       128.0
# 481       113.0
# 489        75.0
#
# [96 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mean_absolute_error(y_test, y_predict)
# Out:
# np.float64(48.765371958066225)

# %%
# accuracy check
r2_score(y_test, y_predict)
# Out:
# -0.026403910468808967

# %% [markdown]
# ### MULTI- LINEAR REGRESSION

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History
# count      480.000000
# mean         0.854167
# std          0.353307
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.dropna(inplace= True)

# %%
df[["ApplicantIncome","CoapplicantIncome","LoanAmount","Loan_Amount_Term","Credit_History"]]
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...

# %%
x = df[["ApplicantIncome","CoapplicantIncome","Loan_Amount_Term","Credit_History"]]
x
# Out:
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History
# 1               4583             1508.0             360.0             1.0
# 2               3000                0.0             360.0             1.0
# 3               2583             2358.0             360.0             1.0
# 4               6000                0.0             360.0             1.0
# 5               5417             4196.0             360.0             1.0
# ..               ...                ...               ...             ...
# 609             2900                0.0             360.0             1.0
# 610             4106                0.0             180.0             1.0
# 611             8072              240.0             360.0             1.0
# 612             7583                0.0             360.0             1.0
# 613             4583                0.0             360.0             0.0
#
# [480 rows x 4 columns]

# %%
y = df[["LoanAmount"]]
y
# Out:
#      LoanAmount
# 1         128.0
# 2          66.0
# 3         120.0
# 4         141.0
# 5         267.0
# ..          ...
# 609        71.0
# 610        40.0
# 611       253.0
# 612       187.0
# 613       133.0
#
# [480 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=65)
model2 = LinearRegression()
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model2.coef_
# Out:
# array([[ 0.00640131,  0.00680615,  0.05466418, -1.17761534]])

# %%
model2.intercept_
# Out:
# array([80.20006723])

# %%
# predict
y_pred = model2.predict(x_test)
mean_squared_error(y_test,y_pred)
r2_score(y_test,y_pred)
# Out:
# 0.3401627306106775

# %%
model2.score(x_test,y_test)
# Out:
# 0.3401627306106775

# %%
model2.score(x_test,y_test)
# Out:
# 0.3401627306106775

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Logistic regression
# y --> categorical data

# %%
df = pd.read_csv("loan_data_set.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
from sklearn.preprocessing import  LabelEncoder

l = LabelEncoder()
y  = l.fit_transform(df["Loan_Status"])
y = pd.DataFrame(y)

df["Loan_Status"] =  y

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.drop("Loan_ID",axis=1, inplace=True)

# %%
for i in df.columns:
    if df[i].dtype =="O":
        print(i)
        y  = l.fit_transform(df[i])
        df[i] =  pd.DataFrame(y)

df
# Out:
# Gender
# Married
# Dependents
# Education
# Self_Employed
# Property_Area
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# ...

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# Gender                 int64
# Married                int64
# Dependents             int64
# Education              int64
# Self_Employed          int64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int64
# Loan_Status            int64
# dtype: object

# %%
# classifications  y --> categorical data
# regression  y --> continuous data
y = df["Loan_Status"]
y

x = df.drop("Loan_Status",axis=1)
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# 5         1        1           2          0              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

x_train,x_test,y_train, y_test = train_test_split(x,y , test_size=.2, random_state=30)

# model obj
lr = LogisticRegression(solver="liblinear")
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
lr.score(x_test,y_test)
# Out:
# 0.7924528301886793

# %%
y_predict = lr.predict(x_test)

# %%
# evaluation matrix
from sklearn.metrics import accuracy_score, confusion_matrix ,classification_report
accuracy_score(y_test, y_predict)
# Out:
# 0.7924528301886793

# %%
print(confusion_matrix(y_test, y_predict))
# Out:
# [[11 21]
#  [ 1 73]]

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.34      0.50        32
#            1       0.78      0.99      0.87        74
#
#     accuracy                           0.79       106
#    macro avg       0.85      0.67      0.68       106
# weighted avg       0.82      0.79      0.76       106

# %% [markdown]
# ### Algorithms in ML
# classification Logistic Regression , KNN , SVM(SVC) , DT(DTC)-> boosting , random forest,
# Regrgssion --> Linear regresion ,SVM(SVR) , DT(DTR) (random forest)
#
# Unsupervised Learning --> K-means, DBSCAN,PCA, Hierarchical Clustering

# %%
df.head()

# %%
# import MOdel
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=5,)
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pridict = knn_model.predict(x_test)
accuracy_score(y_test, y_pridict)
# Out:
# 0.7169811320754716

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.7169811320754716

# %%
param_grid ={  "n_neighbors": [1,3,5,7],
             "algorithms":['ball_tree', 'kd_tree']}

# %%
# hyperparameter tuning
from sklearn.model_selection import GridSearchCV

grid_model = GridSearchCV(knn_model,param_grid,cv=5,scoring="accuracy",verbose=3)
grid_model.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.624 total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.671 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.576 total time=   0.1s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.607 total time=   0.1s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.619 total time=   0.1s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5;, score=0.635 total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5;, score=0.624 total time=   0.1s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5;, score=0.600 total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5;, score=0.690 total time=   0.0s
# ...

# %%
grid_model.best_score_
best_best = grid_model.best_estimator_

# %%
# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV ,RandomizedSearchCV

param_grid = {"n_neighbors": [3, 5, 6],
             'algorithm': ['ball_tree', 'brute', 'kd_tree'],
             'leaf_size': [20, 30, 40]}

# Grid Search
grid_model = GridSearchCV(knn_model, param_grid, cv=5, scoring='accuracy',verbose=3)
grid_model
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['ball_tree', 'brute', 'kd_tree'],
#                          'leaf_size': [20, 30, 40], 'n_neighbors': [3, 5, 6]},
#              scoring='accuracy', verbose=3)

# %%
grid_model.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.647 total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.659 total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.635 total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.643 total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3;, score=0.583 total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5;, score=0.659 total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5;, score=0.635 total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5;, score=0.682 total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5;, score=0.643 total time=   0.0s
# ...

# %%
grid_model.best_score_
# Out:
# np.float64(0.6452941176470588)

# %%
grid_model.best_params_
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 5}

# %%
best_model = grid_model.best_estimator_

y_predict = best_model.predict(x_test)
accuracy_score(y_test, y_predict )
# Out:
# 0.6226415094339622
