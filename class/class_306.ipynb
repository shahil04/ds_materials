# %%
print("hello World")
# Out:
# hello World

# %%
print(5)
# Out:
# 5

# %%
print(5)
8
6
# Out:
# 5
# 6

# %%
# functions add 

# create a functions to show the students details using std id number

# %%
Here is a **detailed, beginner-friendly note on File Handling in Python**, ideal for students, class handouts, or interview preparation.

---

# 📝 Python Notes: File Handling

---

## 📌 What is File Handling?

**File handling** in Python allows you to **create, read, write, and manage files** on your system. It is essential for storing data permanently (outside of memory).

---

## 🔑 Key File Operations

| Operation  | Mode           | Description                           |
| ---------- | -------------- | ------------------------------------- |
| Read       | `'r'`          | Opens a file for reading (default)    |
| Write      | `'w'`          | Opens a file for writing (overwrites) |
| Append     | `'a'`          | Opens a file for appending            |
| Read/Write | `'r+'`         | Opens for reading and writing         |
| Binary     | `'rb'`, `'wb'` | For binary files like images          |

---

## 🧱 Basic Syntax

```python
file = open("filename.txt", "mode")
# Perform operations
file.close()
```

---

## 🔓 1. Opening a File

```python
f = open("data.txt", "r")  # open file in read mode
```

### Modes Summary:

| Mode  | Meaning                       |
| ----- | ----------------------------- |
| `'r'` | Read (file must exist)        |
| `'w'` | Write (creates or overwrites) |
| `'a'` | Append to end                 |
| `'x'` | Create file, error if exists  |
| `'b'` | Binary mode                   |
| `'t'` | Text mode (default)           |

---

## 📖 2. Reading from a File

```python
f = open("data.txt", "r")

print(f.read())           # Read entire file
print(f.readline())       # Read one line
print(f.readlines())      # Read all lines into a list

f.close()
```

---

## ✍️ 3. Writing to a File

```python
f = open("data.txt", "w")   # Overwrites file
f.write("Hello, Python!\n")
f.write("Writing to a file.\n")
f.close()
```

> 🔥 Tip: If the file doesn’t exist, Python will create it.

---

## ➕ 4. Appending to a File

```python
f = open("data.txt", "a")   # Adds to the end of file
f.write("Adding a new line.\n")
f.close()
```

---

## 🔄 5. Using `with` Statement (Best Practice)

The `with` block automatically closes the file, even if an error occurs.

```python
with open("data.txt", "r") as f:
    content = f.read()
    print(content)
# File is automatically closed here
```

---

## 📊 6. File Object Methods

| Method              | Description                     |
| ------------------- | ------------------------------- |
| `.read()`           | Reads entire content            |
| `.readline()`       | Reads single line               |
| `.readlines()`      | Returns list of lines           |
| `.write(text)`      | Writes string to file           |
| `.writelines(list)` | Writes a list of strings        |
| `.close()`          | Closes the file                 |
| `.seek(pos)`        | Moves cursor to position `pos`  |
| `.tell()`           | Returns current cursor position |

---

## 🧪 Example: Read & Count Lines

```python
with open("data.txt", "r") as f:
    lines = f.readlines()
    print("Total lines:", len(lines))
```

---

## 🚨 Exception Handling with Files

```python
try:
    with open("info.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("❌ File does not exist.")
```

---

## 🗃️ Working with Binary Files

```python
with open("image.jpg", "rb") as f:
    data = f.read()
```

---

## 🧹 Deleting a File

```python
import os

if os.path.exists("data.txt"):
    os.remove("data.txt")
else:
    print("File does not exist.")
```

---

## 🔐 Check If File Exists

```python
import os

if os.path.exists("data.txt"):
    print("File is available.")
else:
    print("File not found.")
```

---

## 🧠 Summary Table

| Operation   | Function                 |
| ----------- | ------------------------ |
| Open File   | `open()`                 |
| Read File   | `.read()`, `.readline()` |
| Write File  | `.write()`               |
| Append File | `.append()`              |
| Close File  | `.close()`               |
| Auto-Close  | `with open() as`         |

---

Would you like:

* 📝 A **practice sheet with coding questions** on file handling?
* 📄 A **PDF handout** version of these notes?
* 🧪 A mini **project using file handling**, like a notepad or student marks record?
