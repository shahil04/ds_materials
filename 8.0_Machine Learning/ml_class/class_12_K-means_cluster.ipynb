# %% [markdown]
#  K-means
#  Introduction to Clustering
#
# What is K-Means Clustering?
#
# K-means Clustering Algorithm
#
# Choosing the optimum K value (Elbow Method)
#
# Various Distance Measure

# %% [markdown]
# https://www.kaggle.com/code/abdelrahmanekhaldi/k-mean-clustering-from-scratch/notebook
#
# https://www.kaggle.com/code/prashant111/k-means-clustering-with-python

# %%
https://www.geeksforgeeks.org/k-means-clustering-introduction/
# Out:
#   Cell In[1], line 1
#     https://www.geeksforgeeks.org/k-means-clustering-introduction/
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### K-Means Clustering
#
# **Introduction to Clustering**
#
# Clustering is an unsupervised machine learning technique used to group similar data points together based on their features. The goal is to partition the dataset into distinct groups, or clusters, where points in the same cluster are more similar to each other than to those in other clusters. Clustering can be used in various applications, such as market segmentation, social network analysis, and image segmentation.
#
# ---
#
# ### What is K-Means Clustering?
#
# K-Means Clustering is one of the simplest and most popular clustering algorithms. It partitions the dataset into \(K\) clusters, where each data point belongs to the cluster with the nearest mean (centroid). The algorithm iteratively refines the positions of the centroids until convergence.
#
# ---
#
# ### K-Means Clustering Algorithm
#
# The K-Means algorithm can be summarized in the following steps:
#
# 1. **Initialize Centroids**: Randomly select \(K\) data points as initial centroids.
#
# 2. **Assign Clusters**: Assign each data point to the nearest centroid, forming \(K\) clusters.
#
# 3. **Update Centroids**: Recalculate the centroids of the clusters by taking the mean of all points assigned to each cluster.
#
# 4. **Repeat**: Repeat steps 2 and 3 until the centroids no longer change significantly (convergence).
#
# 5. **Output**: The final clusters and their centroids.
#
# ### Pseudocode for K-Means
#
# ```plaintext
# 1. Initialize K centroids randomly from the data points
# 2. Repeat until convergence:
#    a. Assign each data point to the nearest centroid
#    b. Update each centroid to be the mean of the points assigned to it
# 3. Return the clusters and centroids
# ```
#
# ---
#
# ### Choosing the Optimum K Value (Elbow Method)
#
# The Elbow Method is a heuristic used to determine the optimal number of clusters \(K\) for K-Means. The idea is to run the K-Means algorithm for a range of \(K\) values and calculate the Within-Cluster Sum of Squares (WCSS) for each \(K\). WCSS measures the variance within each cluster:
#
# 1. Run K-Means for \(K = 1\) to \(K = n\).
# 2. Calculate the WCSS for each \(K\).
# 3. Plot \(K\) against WCSS.
# 4. Look for the "elbow point" in the plot where adding more clusters does not significantly reduce WCSS.
#
# ---
#
# ### Various Distance Measures
#
# K-Means typically uses Euclidean distance to measure the distance between data points and centroids. However, other distance measures can also be used, including:
#
# - **euclidean distance**
# - **Manhattan Distance**: Sum of absolute differences.
# - **Cosine Similarity**: Measures the cosine of the angle between two vectors, useful in high-dimensional spaces.
# - **Minkowski Distance**: Generalized distance measure that includes both Euclidean and Manhattan distances.
#
# ---
#
# ### Example Implementation of K-Means
#
# Here’s a Python implementation of K-Means clustering using the `scikit-learn` library, including the Elbow Method for choosing \(K\):

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
# Generate synthetic dataset
X, y_true = make_blobs(n_samples=300, centers=4, random_state=42)

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# Step 1: Using the Elbow Method to find the optimal K
wcss = []  # Within-Cluster Sum of Squares
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Plotting the Elbow Method
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.grid()
plt.show()

# Step 2: Applying K-Means with the optimal K
optimal_k = 4  # Assume we determined this from the Elbow Method
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
y_kmeans = kmeans.fit_predict(X)

# Step 3: Visualizing the results
plt.figure(figsize=(8, 5))
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis', marker='o', edgecolor='k', s=50)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', s=200, alpha=0.75, marker='X', label='Centroids')
plt.title('K-Means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Explanation of the Code
#
# 1. **Import Libraries**: The necessary libraries for data generation, clustering, and visualization are imported.
#
# 2. **Generate Synthetic Dataset**: A synthetic dataset with 300 samples and 4 centers is created.
#
# 3. **Elbow Method**:
#    - The WCSS is computed for \(K\) values from 1 to 10.
#    - A plot of \(K\) against WCSS is created to visualize the elbow point.
#
# 4. **Applying K-Means**: K-Means is applied using the optimal \(K\) determined from the elbow plot.
#
# 5. **Visualization**: A scatter plot is created to show the clusters and centroids.
#
# ### Conclusion
#
# K-Means clustering is a powerful and widely-used technique for grouping data into clusters. By understanding the algorithm, the method for choosing the optimal number of clusters, and different distance measures, you can effectively apply K-Means to various clustering problems.

# %% [markdown]
# ## Class Notes

# %% [markdown]
# [notes k meanns](<../ml2/29 June to 01 July/ML23 Kmeans clustering.pdf>)

# %% [markdown]
# k means -->(mean/average)
#
# average --> arithmetic center of the data set --> centroid
#
# ##### Steps of KMEANS OF CLUSTERS
# 1.  **Initialization**: Choose the initial centroids randomly from the data set. These centroids are the centers of the clusters. The number of centroids is equal to the number of clusters (K).
#     - CAN  be a random data point
#     - centroids of all data points
#     - A randomaly new data point
# 2. point nearer to the centroid will be labelled as teh group
#
# 3. Recalculate the centroids
#     - step 2 will be repeated until the centroids do not change anymore
# - label will change
# new centroid will be calculated

# %% [markdown]
# Distance calculate
# - euclidean
# - manhattan
# - minkowski
#
#
# how to decide which distance metric to use
# - depends on the problem and data type
# - euclidean for continuous data
# - manhattan for categorical data
# - minkowski for mixed data types
#
# how to decide k for k-means
#
# WC SS --> within cluster sum of squares distance
# wcss = summations of squared distances between points to nearest of cluster center
#
# - elbow method
# - silhouette method
#
#
# - elbow method: plot wcss against k, choose k where wcss starts to increase rapidly
# - silhouette method: plot silhouette score against k, choose k where silhouette score is highest
#
# - silhouette score: -1 to 1, 1 is best, -1 is worst
#
# - if wcss not changing  -->all the datapoints are correctly marked to the nearesrt cluster class --> optimal K.
#
# - how to K is Decided
#     - elbow method
#     - business team
#
# - random initialization of centroids k-trap
#
# ### Silhouette score
# - Silhouette score /cofficient -->
#     - 0.7 to 1 --> good clustering
#     - 0.5 to 0.7 --> fair clustering
#     - 0.3 to 0.5 --> poor clustering
#     - 0 to 0.3 --> random clustering
#     - -1 to 0 --> bad clustering
#     - -1 to -0.7 --> very bad clustering
#
# - when you say a given cluster is a good cluster?
#     - within cluster data points are compact/ dense/ similar/tightly packed
#         THE WCSS -->Should be minimize   , intra -cluster distance should be minimized

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# import warnings
# warnings.filterwarnings('ignore')

# %%
# Generate the data 
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples = 1000, centers=3, n_features = 2, random_state=1)

# %%
X

# %%
y#in unsl you will not use y

# %%
# create scatter plot of f1 and f2 using matplotlib color total number of y values
plt.scatter(X[: , 0], X[:, 1], c = y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((700, 2), (300, 2))

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters =3)

# %%
kmeans
# Out:
# KMeans(n_clusters=5)

# %%
kmeans.fit(X_train) #fit_predict
# Out:
# KMeans(n_clusters=3)

# %%
y_labels = kmeans.predict(X_train)
y_labels

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c = y_labels)

# %%
#how better the clustering model is
from sklearn.metrics import silhouette_score
silhouette_score(X_train, kmeans.labels_)
# Out:
# np.float64(0.5433540369354409)

# %%
kmeans.labels_

# %%
kmeans.inertia_ #for k=3, you have wcss distance
# Out:
# 1155.8577724775607

# %% [markdown]
# ### elbow method

# %%
#to sleect K(centroid)>> elbow method
wcss = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(X_train)
    wcss.append(kmeans.inertia_)

# %%
wcss

# %%
#plot an elbow curve
plt.plot(range(1, 10), wcss)
plt.xticks(range(1, 10))
plt.xlabel("No of clusters")
plt.ylabel("wcss")
plt.show()

# %%
#based on the above plot the optimal no of k cluster is 3

# %%
# !pip install kneed

# %%
from kneed import KneeLocator
k1 = KneeLocator(range(1, 10), wcss, curve='convex', direction = 'decreasing')

# %%
k1.elbow
# Out:
# np.int64(2)

# %%
silhouette_coeff = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_train)
    score = silhouette_score(X_train, kmeans.labels_)
    silhouette_coeff.append(score)

# %%
silhouette_coeff
# Out:
# [np.float64(0.7674998364431159),
#  np.float64(0.7179451230427786),
#  np.float64(0.5995089422854305),
#  np.float64(0.4861545066246),
#  np.float64(0.3302304065124146),
#  np.float64(0.5094920795962005),
#  np.float64(0.34233253812668857),
#  np.float64(0.32989967087750616)]
