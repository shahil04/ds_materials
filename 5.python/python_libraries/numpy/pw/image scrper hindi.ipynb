# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen as uReq
import logging
#import pymongo
import os

# %%
from bs4 import BeautifulSoup
import requests


url='https://www.imdb.com/gallery/rg1859820288?ref_=nv_ph_ls'
page=requests.get(url)
# print(page)
soup=BeautifulSoup(page.content,'lxml')
# print(soup)
lis=soup.find('div',{'class':'media_index_thumb_list'})
# print(lis)
title=list()
src=list()

for img_src in lis.find_all('img'):
    src.append(img_src['src'])

print(src)
for title_All in lis.find_all('a'):
    title.append(title_All['title'])
print(title)
for i in range(0,5):
    print(title)
    file=open(title[i]+".jpg",'wb')
    file.write(requests.get(src[i]).content)
    file.close()

import os 
os.getcwd()
# Out:
# ['https://m.media-amazon.com/images/M/MV5BZDJjNjg0NGQtODdmYi00ODcwLWFkYTUtNGRkNTRhYWI0MTE4XkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BMDQ2YmJiNzUtYTA4NC00M2JmLTljMmEtYzI0YTRhMzg1ZWYyXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BNTA1MTViZjgtNWIzMS00NjE3LWIxZGItN2E3YjI0NmNlZjI3XkEyXkFqcGc@._V1_UY100_CR69,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BODA0OGZmZDctMjdmNy00Y2IzLThkNzEtYzVlNGE3ZGIyNjUxXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BZWQxMDJmNWYtZWEwYS00M2ZkLWFkZmYtYjc2ODliYzVhMzc0XkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BYTRhZjgwNTEtMDk0Ni00MGViLTgzOTAtNzkxNTdhMTU1NGYxXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BMmQwZjIzNDktODJhOS00NWIzLTllYzItYTBkZDJlNWU4MDhhXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BNzg5NDkwODEtYmJmMy00ZDk0LWE0OTMtZWVmMDVhZWE5YTAyXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BMDk5MDFhYjQtYjRmZS00NTE5LTliMDgtY2VjZWEzNzAxN2YyXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BZWUyZWM2YTItMzEyZS00Mzg1LWFlM2ItY2Y1YjZhNzdjZjJmXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BODI2OTZiOGItNDU0Yi00ZDA2LWEwZTUtZTQ0OGJiZTc0NjE0XkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BZTAyNmY3MTAtYmRhYy00MTM3LWFkMjEtNzQwNzE5MzRiZjU0XkEyXkFqcGc@._V1_UY100_CR39,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BNDkyNjhlMGUtZmViNy00ZTY5LTk3ZTItZDg5NjcxZDczMWZiXkEyXkFqcGc@._V1_UY100_CR39,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BOWY1ODc1NDQtOWM5Yi00NzhkLThmNDktMmVhY2ViODI1OGY0XkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BNDBiZThjZWMtM2RkZS00MzQyLWI5OGUtNDhjNWY1YTUyYjhlXkEyXkFqcGc@._V1_UY100_CR12,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BZmI0NzgyZWMtZjY4MS00YzhiLTkyMjAtNDA5ZTc5NzQ2MTkzXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BYTNkMGY1NWQtM2E4YS00MzE3LTgyN2YtN2FjYTNiNTIzYzM2XkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BZDcwNjQwZTQtYTExYy00MGYxLTllOTYtMGM0YTI2MmFmMzk5XkEyXkFqcGc@._V1_UY100_CR71,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BMjA1YmU0MjUtODZmYi00NDkzLThhZmQtZTdjOTgxMDUwZTVjXkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BODZhNTgzYTUtOWQ0My00NWE3LWE0OWItOGI2MWZhMDg4YjE0XkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5BNTNjMDZhNDQtYTgzMC00YjljLWJjMzUtODg4ZTBmYWE1OTE3XkEyXkFqcGc@._V1_UY100_CR25,0,100,100_AL_.jpg', 'https://m.media-amazon.com/images/M/MV5B
', 'Michael Sheen in A Very Royal Scandal (2024)', 'Michael Sheen in A Very Royal Scandal (2024)', 'Ruth Wilson in A Very Royal Scandal (2024)', 'Michael Sheen and Ruth Wilson in A Very Royal Scandal (2024)', 'Joanna Scanlan in Slow Horses (2022)']
# ['Aaron Pierre in Rebel Ridge (2024)', 'Don Johnson and Aaron Pierre in Rebel Ridge (2024)', 'Aaron Pierre in Rebel Ridge (2024)', 'Meghann Fahy in The Perfect Couple (2024)', 'Liev Schreiber in The Perfect Couple (2024)', 'Nicole Kidman, Liev Schreiber, Dakota Fanning, Eve Hewson, Jack Reynor, Billy Howle, and Sam Nivola in The Perfect Couple (2024)', 'Dakota Fanning and Jack Reynor in The Perfect Couple (2024)', 'Nicole Kidman and Liev Schreiber in The Perfect Couple (2024)', 'Nicole Kidman in The Perfect Couple (2024)', 'Gael García Bernal and Diego Luna in La Máquina', 'Gael García Bernal and Diego Luna in La Máquina', 'Gael García Bernal and Diego Luna in La Máquina', 'Eiza González in La Máquina', 'Diego Luna in La Máquina', 'Gael García Bernal, Diego Luna, and Eiza González in La Máquina', 'Gael García Bernal and Eiza González in La Máquina', 'Gael García Bernal and Diego Luna in La Máquina', 'Hayden Panettiere and Tyler James Williams in Amber Alert (2012)', 'Niecy Nash in Grotesquerie (2024)', 'Brandy Norwood in The Front Room (2024)', 'Brandy Norwood in The Front Room (2024)', 'Kathryn Hunter in The Front Room (2024)', 'Brandy Norwood in The Front Room (2024)', 'Brandy Norwood and Andrew Burnap in The Front Room (2024)', 'Brandy Norwood and Andrew Burnap in The Front Room (2024)', 'Kathryn Hunter and Mary Catherine Wright in The Front Room (2024)', 'Kathryn Hunter in The Front Room (2024)', 'Kathryn Hunter in The Front Room (2024)', 'Brandy Norwood, Kathryn Hunter, and Andrew Burnap in The Front Room (2024)', 'Kathryn Hunter in The Front Room (2024)', 'Brandy Norwood in The Front Room (2024)', 'Brandy Norwood in The Front Room (2024)', 'Kathryn Hunter in The Front Room (2024)', 'Scott Speedman, Caleb Dolden, Yvonne Strahovski, and Emilie Bierre in Teacup (2024)', 'Caleb Dolden, Luciano Leroux, and Emilie Bierre in Teacup (2024)', 'Yvonne Strahovski in Teacup (2024)', 'Peter Mullan in The Lord of the Rings: The Rings of Power (2022)', 'Benjamin Walker in The Lord of the Rings: The Rings of Power (2022)', 'Sophia Nomvete and Owain Arthur in The Lord of the Rings: The Rings of Power (2022)', 'Robert Aramayo in The Lord of the Rings: The Rings of Power (2022)', 'Ismael Cruz Cordova in The Lord of the Rings: The Rings of Power (2022)', 'The Lord of the Rings: The Rings of Power (2022)', 'Charlie Vickers in The Lord of the Rings: The Rings of Power (2022)', 'Michael Sheen in A Very Royal Scandal (2024)', 'Michael Sheen in A Very Royal Scandal (2024)', 'Ruth Wilson in A Very Royal Scandal (2024)', 'Michael Sheen and Ruth Wilson in A Very Royal Scandal (2024)', 'Joanna Scanlan in Slow Horses (2022)']
# 'c:\\Users\\hp\\Downloads'

# %%
save_dir = "images/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"}

# %%
query = "sudhanshu kumar"
response = requests.get(f"https://www.google.com/search?q={query}&sxsrf=AJOqlzUuff1RXi2mm8I_OqOwT9VjfIDL7w:1676996143273&source=lnms&tbm=isch&sa=X&ved=2ahUKEwiq-qK7gaf9AhXUgVYBHYReAfYQ_AUoA3oECAEQBQ&biw=1920&bih=937&dpr=1#imgrc=1th7VhSesfMJ4M")

# %%
soup = BeautifulSoup(response.content ,'html.parser')

# %%
images_tags = soup.find_all("img")
print(images_tags)
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSxgssUkUKXMS9EdgAvATCeAKC8o-VDSOF8607y1DdA9NwXlRRSwxgqmMuGWQ&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcScLLrTJ7W5IouGlFwhC_yxgJ11pSvXYdOLvNe-WVXO00kgHMEONl1XQ3L7qQ&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjUkSyg4dtexnrXZIohPDgi0tWIM-7kZ7E1K6_k-R82L98WR2mEk7B5u2IIQ&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRT4-B0nl-K0t0F4G6JmfLtD4s_h-LPaSbSi5u724ckAdF5gGMzOyQ2oCRlEQ&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRLWgn0YmnyE6OhRXy2HTt_SpMYCF5WH7c2HKa9oFLIhoOQ__0asvkR1GzX8Q&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKcFDqSNocctdXX2hz4uqhkQ-jL0tMIU2fitur_CuqbKGMrcXI38mzdX-SYQ&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRfTvaxt136SwTeLNOcn_DhrPO_0OFZoGJn1SfWkFDUKVAs6_8Mn12pB0byL6E&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRJqqj91HwiCew3spWsT24wnAIxT7AkpLEeQYUcNPiU8bc61S0wQHADnuxl0j8&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTUNy1XXjjYhgLj_24gJAAOYAzjTbw-C6XSUNC5EWl8F0RbMSObq91gTxtskQ&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTmvB834oP1kq6N72QvBJiSrC7lBLwZeVczSHfnnqttoMnAMJRKOZ06CUHDgtw&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSV0emDoPWj5xeMLOp_DHzuDT2kyydng73UcOXIdGetpbVpGJRrk05gqjoOFw&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR5xX-YYgqLTs_oeoOR6Ga2xG2os9jXAt_pv9-47CZhD9k6m9KRbcPSwhCvkA&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSIQybgmlybpBGymlWP9RkFxj7CgScY0xx4sB2A45ZaIJcdodkUANpOHKXLxg&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6p48WTyIXmcJIRZS0dGxAmb_tefirSYcFbxWZq7zXHlo6akzsIEksWvm48Q&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTydxlexxz-7jJevK8eIoKEdoTgwmG4k8vijIDTm8cWWggL_MefshTvy8t94cI&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnA_h8zff7E-WqRo284_nm7CITF049sgJj6DJ4h259BLbztgcE1-naYgDfJw&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWOzoBHRfUKrN8-PIxpBUZOG_UN5eVLwZMGgPRVEeQtvDRIpNrcGh4hRwyTg&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSeeJWwvOjDhgBPFibXYz7pP-DCZpgff_4O_txU13hdOn3gsfRHaWCAeegBubc&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQoB1gact8_e5rkymWtjMnz3aP254Nde3T9TzVL9gHHwyFJ4jVZetUpGzbjIQs&amp;s"/>, <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRZN1MKCUAn6yeq2kaLZ5bfelIKu0EbrFI2V9aCJcrGnOcJ7YCFEaczUtGpsPM&amp;s"/>]

# %%
len(images_tags)
# Out:
# 21

# %%
del images_tags[0]

# %%
img_data_mongo = []
for i in images_tags:
    image_url = i['src']
    image_data = requests.get(image_url).content
    mydict = {"index":image_url , "image" : image_data}
    img_data_mongo.append(mydict)
    with open(os.path.join(save_dir,f"{query}_{images_tags.index(i)}.jpg"),"wb") as f :
              f.write(image_data)
# client = pymongo.MongoClient("mongodb+srv://pwskills:pwskills@cluster0.ln0bt5m.mongodb.net/?retryWrites=true&w=majority")
# db = client['image_scrap"]
# coll_image = db["image_scrap"]
# coll_image.insert_many(img_data_mongo)

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

def index():

    try:
        # searchString = request.form['content'].replace(" ","")
        flipkart_url = "https://www.flipkart.com/search?q=" + searchString
        uClient = uReq(flipkart_url)
        flipkartPage = uClient.read()
        uClient.close()
        flipkart_html = bs(flipkartPage, "html.parser")
        bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})
        del bigboxes[0:3]
        box = bigboxes[0]
        productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
        prodRes = requests.get(productLink)
        prodRes.encoding='utf-8'
        prod_html = bs(prodRes.text, "html.parser")
        print(prod_html)
        commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

        filename = searchString + ".csv"
        fw = open(filename, "w")
        headers = "Product, Customer Name, Rating, Heading, Comment \n"
        fw.write(headers)
        reviews = []
        for commentbox in commentboxes:
            try:
                #name.encode(encoding='utf-8')
                name = commentbox.div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text

            except:
                name = 'No Name'

            try:
                #rating.encode(encoding='utf-8')
                rating = commentbox.div.div.div.div.text


            except:
                rating = 'No Rating'

            try:
                #commentHead.encode(encoding='utf-8')
                commentHead = commentbox.div.div.div.p.text

            except:
                commentHead = 'No Comment Heading'
            try:
                comtag = commentbox.div.div.find_all('div', {'class': ''})
                #custComment.encode(encoding='utf-8')
                custComment = comtag[0].div.text
            except Exception as e:
                print("Exception while creating dictionary: ",e)

            mydict = {"Product": searchString, "Name": name, "Rating": rating, "CommentHead": commentHead,
                        "Comment": custComment}
            reviews.append(mydict)
        client = pymongo.MongoClient("mongodb+srv://pwskills:pwskills@cluster0.ln0bt5m.mongodb.net/?retryWrites=true&w=majority")
        db = client['review_scrap']
        review_col = db['review_scrap_data']
        review_col.insert_many(reviews)
        return render_template('results.html', reviews=reviews[0:(len(reviews)-1)])
    except Exception as e:
        print('The Exception message is: ',e)
        return 'something is wrong'
# return render_template('results.html')



index()
# Out:
# The Exception message is:  Working outside of request context.
#
# This typically means that you attempted to use functionality that needed
# an active HTTP request. Consult the documentation on testing for
# information about how to avoid this problem.
# 'something is wrong'

# %%
# searchString = requests.form['content'].replace(" ","")
# flipkart_url = "https://www.flipkart.com/search?q=" + searchString
flipkart_url = "https://www.flipkart.com/search?q=bag&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
uClient = uReq(flipkart_url)
flipkartPage = uClient.read()
uClient.close()
flipkart_html = bs(flipkartPage, "html.parser")
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})
del bigboxes[0:3]
box = bigboxes[0]
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
prodRes = requests.get(productLink)
prodRes.encoding='utf-8'
prod_html = bs(prodRes.text, "html.parser")
print(prod_html)
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 # searchString = requests.form['content'].replace(" ","")
#       2 # flipkart_url = "https://www.flipkart.com/search?q=" + searchString
#       3 flipkart_url = "https://www.flipkart.com/search?q=bag&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
# ----> 4 uClient = uReq(flipkart_url)
#       5 flipkartPage = uClient.read()
#       6 uClient.close()
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 429: Too Many Requests
