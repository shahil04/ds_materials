# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.linspace(1,50,20)
# Out:
# array([ 1.        ,  3.57894737,  6.15789474,  8.73684211, 11.31578947,
#        13.89473684, 16.47368421, 19.05263158, 21.63157895, 24.21052632,
#        26.78947368, 29.36842105, 31.94736842, 34.52631579, 37.10526316,
#        39.68421053, 42.26315789, 44.84210526, 47.42105263, 50.        ])

# %%
plt.plot(np.linspace(1,50,20))

# %%
data = np.random.randint(1,50,20)

# %%
plt.plot(data)
plt.show()

# %%
s = np.sin(np.linspace(0,10,100))
s
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %%
cos = np.cos(np.linspace(0,10,100))

# %%
plt.plot(s,'--',color="green",marker='.',markeredgecolor="red",le)
plt.plot(cos, "-.",color="red")
plt.title("Sin Cos Graph")
plt.show()
# Out:
#   Cell In[9], line 1
#     plt.plot(s,'--',color="green",marker='.',markeredgecolor="red",le)
#                                                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
plt.plot(s,'--',color="green",marker='.',markeredgecolor="red" ,label="Sine")
plt.plot(cos, "-.",color="red" ,label="cosine")
plt.title("Sin Cos Graph")
plt.xlabel("data in x")
plt.ylabel("sin/cos value")
plt.xlim((0,150))
plt.xticks(s,cos)
plt.legend(loc='upper right')
plt.show()

# %%
# create a plot figure
plt.figure()

# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(s)

# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(cos)

# %%
plt.figure()

plt.subplot(1,2,1)
plt.plot(s)

plt.subplot(1,2,2)
plt.plot(cos)

# %%
plt.figure()

plt.subplot(2,2,1)
plt.plot(s)

plt.subplot(2,2,3)
plt.plot(cos)

plt.subplot(2,2,4)
plt.plot(np.random.randn(50))

# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt

# %%
# multiple lines in single plot
plt.figure(figsize=(5,5))
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")
plt.legend()

plt.show()

# %%
import seaborn as sns

# %%
sns.lineplot(x=x,y=x, label='linear')
sns.lineplot(x=x,y=x**2, label='q')
sns.lineplot(x=x,y=x**3, label='c')
plt.title(" line graph")

plt.show()

# %%
cat = ["a","b","c"]
sales = [343,384,300]

plt.bar(cat,sales)
plt.title("categories_wise sales")
plt.xlabel("categories")
plt.ylabel("sales amount")
plt.show()

# %%
cat = ["a","b","c"]
sales = [343,384,300]

ax = sns.barplot(x=cat,y=sales ,hue=cat)
ax.bar_label(ax.containers[0], fontsize=10)
ax.bar_label(ax.containers[1], fontsize=10)
ax.bar_label(ax.containers[2], fontsize=10)
plt.title("categories_wise sales")
plt.xlabel("categories")
plt.ylabel("sales amount")
plt.show()

# %%
cat = ["a","b","c"]
sales = [343,384,300]
ax = sns.barplot(x=cat,y=sales ,hue=cat, legend=cat, palette=['red', 'blue', 'green'])
for i in range(len(cat)):
    ax.bar_label(ax.containers[i], fontsize=10)

plt.title("categories_wise sales")
plt.xlabel("categories")
plt.ylabel("sales amount")
plt.grid(axis="y")
plt.show()

# %%
cat = ["a","b","c"]
sales = [343,384,300]
ax = sns.barplot(x=cat,y=sales ,hue=cat, legend=cat, palette="Greens")
for i in range(len(cat)):
    ax.bar_label(ax.containers[i], fontsize=10)

plt.title("categories_wise sales")
plt.xlabel("categories")
plt.ylabel("sales amount")
plt.show()

# %%
# scatter  continous data  -- 
sales =[45,34,12,67,54,32,23,12,12]

profit = np.random.randint(5, 13, len(sales))

print(sales)
print(profit)
# Out:
# [45, 34, 12, 67, 54, 32, 23, 12, 12]
# [ 8 10  6  5 10  6 10 12  8]

# %%
plt.scatter(profit,sales)

# %%
gender = ['m','f','m','f','m','f','f','m','f']
sns.scatterplot(x=profit , y=sales,hue=gender)
# Out:
# <Axes: >

# %%
# pie chart
cat = ["a","b","c"]
sales = [143,384,300]
plt.figure(figsize=(4, 6))
exp = [0, 0.02, 0.1]
plt.pie(x=sales , labels=cat, autopct="%1.2f", explode=exp, shadow=True)


plt.legend(loc='upper left')
plt.show()

# %%
# histogram
d1 = np.random.randint(1,100, 1000)
d1
# Out:
# array([50, 52, 39, 12, 34, 53,  2,  3, 58, 89, 68, 78, 76, 84, 72, 44, 71,
#        84, 21, 20, 62, 73, 47, 95, 46, 58, 94, 37, 56, 92, 84, 55, 41, 68,
#        81, 93,  7, 13, 67, 19,  4, 89, 36,  1, 27, 12,  9, 51, 12,  2, 20,
#        10, 47, 90,  6, 45, 75, 68, 85, 96, 42, 61, 51, 81, 96, 94, 89, 38,
#        67, 88, 87, 93, 37, 71, 23,  7, 27, 59, 87, 89, 21, 57, 76, 47, 17,
#        59, 46, 71, 92,  1, 20, 31, 20, 47, 67, 73, 61, 97, 34,  3, 63, 82,
#        27, 16,  3, 21, 80, 25, 52, 31, 14, 10, 29, 87, 25, 36, 50, 24, 77,
#        79, 43, 45,  8, 77, 77, 71, 21, 96, 92, 20, 71, 37, 61, 46, 53, 54,
#         6, 18, 26, 53, 59, 33, 71, 72, 45, 64, 71, 77, 35, 10, 76, 99, 61,
#        93, 46, 26, 14, 73, 43, 90, 14, 25, 91, 74, 15,  5, 95, 70, 77, 73,
#         8, 76, 55, 46, 32, 65, 45, 88, 58, 19, 59, 11, 82,  3, 86, 39, 13,
#        22, 14,  6,  4, 73, 89, 61, 87, 67, 55, 65, 18, 95, 29, 67, 36, 14,
# ...

# %%
plt.hist(d1,bins=100)
# Out:
# (array([ 6., 10., 13., 12.,  9.,  6., 12., 12.,  9.,  9., 12., 11.,  9.,
#         12., 12., 11.,  8.,  8.,  5., 12.,  6., 11., 13., 11., 14., 12.,
#         11.,  7.,  4.,  5.,  9., 10.,  6., 13., 14., 14., 13.,  7., 10.,
#          6.,  8., 10.,  7.,  8., 13., 10., 13.,  4.,  7.,  0., 13., 13.,
#          8., 12.,  9., 10., 14.,  7., 14., 13.,  7., 14., 11.,  7., 11.,
#         12.,  4., 13., 11., 10., 10., 14.,  8., 11.,  8.,  8., 11., 18.,
#          8.,  6., 11.,  9.,  4.,  4., 17.,  8.,  6., 10., 13., 13., 10.,
#         10., 12., 17., 16.,  7., 13., 10., 10., 11.]),
#  array([ 1.  ,  1.98,  2.96,  3.94,  4.92,  5.9 ,  6.88,  7.86,  8.84,
#          9.82, 10.8 , 11.78, 12.76, 13.74, 14.72, 15.7 , 16.68, 17.66,
#         18.64, 19.62, 20.6 , 21.58, 22.56, 23.54, 24.52, 25.5 , 26.48,
#         27.46, 28.44, 29.42, 30.4 , 31.38, 32.36, 33.34, 34.32, 35.3 ,
#         36.28, 37.26, 38.24, 39.22, 40.2 , 41.18, 42.16, 43.14, 44.12,
# ...

# %%
sns.histplot(x=d1, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
d1 = np.random.randint(1,10, 1000)
d1
sns.countplot(x=d1)
# Out:
# <Axes: ylabel='count'>

# %%
data2 = np.random.randn(1000)

# %%
sns.histplot(x=data2, kde=True)
# Out:
# <Axes: ylabel='Count'>
