# %%
#matplotlib, seaborn >>important from interview, plotly >> interactive, bokeh

# %% [markdown]
# https://matplotlib.org/stable/tutorials/pyplot.html#sphx-glr-tutorials-pyplot-py

# %%
# pip install matplotlib
# pip install seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#plt.style.use('classic')\
#http://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
np.array([34,454,343,5])
# Out:
# array([ 34, 454, 343,   5])

# %%
type(np.array([34,454,343,5]))
# Out:
# numpy.ndarray

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.6658847 , 0.55066714, 0.93892095, 0.37114738, 0.16018707,
#        0.37541122, 0.92670412, 0.06498645, 0.00633137, 0.57822246,
#        0.01546583, 0.3198149 , 0.53032191, 0.94361861, 0.92418832,
#        0.16487602, 0.84220067, 0.01466417, 0.19636272, 0.20135289,
#        0.5468949 , 0.76359756, 0.83684678, 0.21301424, 0.29176838,
#        0.25678248, 0.7523288 , 0.25449755, 0.73536272, 0.07420722,
#        0.71220345, 0.19364266, 0.92385844, 0.3023655 , 0.96627553,
#        0.34708417, 0.17840348, 0.62893909, 0.74246877, 0.70608497,
#        0.16956291, 0.81666983, 0.98476187, 0.14472103, 0.15424174,
#        0.52328666, 0.52582399, 0.98852313, 0.79134679, 0.15439558])

# %%
y
# Out:
# array([0.72703774, 0.8922945 , 0.10845983, 0.41857761, 0.31018486,
#        0.41746344, 0.81919665, 0.94654122, 0.60382283, 0.94258057,
#        0.90071029, 0.44256557, 0.37372999, 0.7490003 , 0.13144198,
#        0.19059689, 0.27366728, 0.48074793, 0.62484566, 0.32160932,
#        0.16301309, 0.206977  , 0.1635683 , 0.98739218, 0.50165187,
#        0.64281572, 0.49551002, 0.33517762, 0.11400489, 0.08312921,
#        0.7068311 , 0.93519883, 0.20045671, 0.73544117, 0.84516885,
#        0.77747818, 0.24306212, 0.81472558, 0.95828343, 0.54840629,
#        0.32873192, 0.17382666, 0.27116892, 0.73057211, 0.048546  ,
#        0.29519952, 0.85739619, 0.42018446, 0.57120205, 0.55124929])

# %%
plt.scatter(x,y)

# %%
x = np.linspace(50,1)
y = np.linspace(1,30)

# %%
plt.scatter(x,y)

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['data'], index = pd.date_range('2020/04/21', periods = 1000))

# %%
df
# Out:
#                 data
# 2020-04-21  1.407944
# 2020-04-22 -0.457473
# 2020-04-23 -1.862965
# 2020-04-24  0.473283
# 2020-04-25 -0.712857
# ...              ...
# 2023-01-11  1.239548
# 2023-01-12 -1.949204
# 2023-01-13  1.235433
# 2023-01-14  0.492403
# 2023-01-15  1.529716
#
# [1000 rows x 1 columns]

# %%
# %matplotlib inline

df.plot(figsize = (5, 5)) # line chart with figure size
# Out:
# <Axes: >

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.plot(x, np.sin(x))
plt.show()

# %%
plt.plot(x, np.sin(x), '-.')

# %%
x1 = np.linspace(0, 10, 100)


plt.plot(x1, np.sin(x1), '-')
plt.plot(x1, np.cos(x1), '-')

plt.show()

# %%
# %matplotlib inline

plt.plot(x, np.sin(x), '--')
plt.show()

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
# sub plot 
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
# sub plot 
plt.figure()
plt.subplot(2,1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2,1, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
# ploting in 4 parts
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))


plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))


plt.subplot(2, 2, 4)
plt.plot(x, np.cos(x+1))
plt.show()

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x), color="red")

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))
plt.ylim(-1, 2)
plt.xlim(0,20)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.plot(x, np.sin(x-1), color = 'g')
plt.plot(x, np.sin(x-2), color = (1.0, 0.5, 0)) #rgb

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.title("This is sin plot before real dataset execution to understand basic syntax")
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.title("This is sin plot before real dataset execution to understand basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x), color = 'blue', label = 'Sinx')
plt.plot(x, np.cos(x), color = 'red', label = 'Cosx')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.title("This is sin plot before real dataset execution to understand basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
# plt.axis('equal')
plt.legend()
plt.show()

# %%
#Histogram

data = np.random.randn(1000) #10 bins
plt.hist(data, bins = 20, color ='green')
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y
# Out:
# array([ 1.        ,  1.59183673,  2.18367347,  2.7755102 ,  3.36734694,
#         3.95918367,  4.55102041,  5.14285714,  5.73469388,  6.32653061,
#         6.91836735,  7.51020408,  8.10204082,  8.69387755,  9.28571429,
#         9.87755102, 10.46938776, 11.06122449, 11.65306122, 12.24489796,
#        12.83673469, 13.42857143, 14.02040816, 14.6122449 , 15.20408163,
#        15.79591837, 16.3877551 , 16.97959184, 17.57142857, 18.16326531,
#        18.75510204, 19.34693878, 19.93877551, 20.53061224, 21.12244898,
#        21.71428571, 22.30612245, 22.89795918, 23.48979592, 24.08163265,
#        24.67346939, 25.26530612, 25.85714286, 26.44897959, 27.04081633,
#        27.63265306, 28.2244898 , 28.81632653, 29.40816327, 30.        ])

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.figure(figsize = (6, 2))
plt.scatter(x, y, c = 'r', alpha = .9, marker = "X" ) # alpha color intensity
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter plot")
plt.show()

# %%
x
# Out:
# array([0.65073241, 0.10137441, 0.42782747, 0.66235544, 0.23147853,
#        0.69174201, 0.81492621, 0.12646916, 0.4606457 , 0.60880882,
#        0.1150743 , 0.99972398, 0.01757297, 0.81125158, 0.04971696,
#        0.77839625, 0.08993846, 0.07791145, 0.71625738, 0.7720707 ,
#        0.23985803, 0.62175293, 0.97480672, 0.01402701, 0.71661587,
#        0.89760197, 0.9326467 , 0.98498602, 0.12635644, 0.35282744,
#        0.37333758, 0.65460671, 0.99112068, 0.29288172, 0.09453068,
#        0.42075321, 0.91902477, 0.9685762 , 0.88154187, 0.97942321,
#        0.5296654 , 0.22092769, 0.9167259 , 0.40059666, 0.0252317 ,
#        0.80266612, 0.54152467, 0.19399782, 0.88427111, 0.96848748])

# %%
y
# Out:
# array([0.53758382, 0.50454782, 0.14353291, 0.29145614, 0.07489409,
#        0.70402397, 0.9837618 , 0.99565522, 0.03540941, 0.51338456,
#        0.84072129, 0.84611792, 0.20391947, 0.81165216, 0.16634605,
#        0.5052589 , 0.09098785, 0.66320721, 0.60082593, 0.12908803,
#        0.73154233, 0.8083271 , 0.97198704, 0.19129056, 0.75940219,
#        0.709808  , 0.48240257, 0.12160379, 0.53116667, 0.03990282,
#        0.23913183, 0.73476336, 0.71317551, 0.29287498, 0.66226986,
#        0.65909033, 0.50080051, 0.93063113, 0.33474011, 0.2555373 ,
#        0.89908237, 0.94376839, 0.49400078, 0.22243712, 0.48479591,
#        0.17766247, 0.0306138 , 0.15913069, 0.59930776, 0.11557471])

# %%
x=["a", "b", "c", "d"]
y=[4, 6, 1, 2]

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# [4, 6, 1, 2]

# %%
plt.figure(figsize = (6, 3))
plt.bar(x, y, color = '#FF5733')
plt.title("This is my bar plot")
# Out:
# Text(0.5, 1.0, 'This is my bar plot')

# %%
plt.figure(figsize = (3, 3))
plt.barh(x, y, color = '#FF5733')
plt.title("This is my bar plot")
plt.show()

# %%
data = [1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 8]
plt.hist(data)
# Out:
# (array([1., 1., 4., 0., 1., 1., 0., 1., 1., 1.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
#pie chart

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = '%1.1f%%')
plt.title("Pie chart")
plt.show()

# %%
my_explode = (0.0, 0.1, 0.1)

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = '%1.1f%%', explode = my_explode, shadow =  True)
plt.title("Pie chart")
plt.show()

# %%
# 3 d plot

x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c = "#FF5733", alpha = .9)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
x
# Out:
# array([0.55138788, 0.44438276, 0.5358097 , 0.74945707, 0.99120773,
#        0.70211133, 0.66488267, 0.92921522, 0.62441898, 0.18258539,
#        0.49079378, 0.16847413, 0.68178064, 0.48028648, 0.98460245,
#        0.15917748, 0.69404074, 0.34557006, 0.65269922, 0.04525251])

# %%
y
# Out:
# array([0.3781861 , 0.79406215, 0.47944176, 0.53641031, 0.37532541,
#        0.96186001, 0.56568918, 0.93001466, 0.05812115, 0.56472316,
#        0.79631224, 0.60727398, 0.47130409, 0.37931311, 0.52649804,
#        0.20416729, 0.12158142, 0.30672667, 0.79273314, 0.31464821])

# %%
z
# Out:
# array([0.09793696, 0.60946575, 0.38854002, 0.17368957, 0.00677389,
#        0.57395651, 0.75664241, 0.43208656, 0.60275808, 0.09585485,
#        0.94088992, 0.24814294, 0.63199035, 0.13912302, 0.02251173,
#        0.66382139, 0.7927511 , 0.4611866 , 0.11175141, 0.82315383])

# %%
import pandas as pd

data = pd.read_csv("Bank_Churn.csv")
data.head()
# Out:
#           version https://git-lfs.github.com/spec/v1
# 0  oid sha256:ee2a5c9d8daf3aed0d91c4d883a84ebb77d...
# 1                                        size 674857

# %%
data.plot.scatter(x = 'Age', y = "Balance")

#insights
#maximum concentration >> 25-50
#maximum >>  40
#min>>0, it is present in all of the age group
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data.plot.scatter(x = 'Age', y = "Balance")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)
#    1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)
#    1746         ...                       colormap='viridis')
#    1747     """
# -> 1748     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1346, in ScatterPlot._make_plot(self, fig)
#    1343 else:
#    1344     label = None
#    1345 scatter = ax.scatter(
# -> 1346     data[x].values,
#    1347     data[y].values,
#    1348     c=c_values,
#    1349     label=label,
#    1350     cmap=cmap,
#    1351     norm=norm,
#    1352     s=self.s,
#    1353     **self.kwds,
#    1354 )
#    1355 if cb:
#    1356     cbar_label = c if c_is_column else ""
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Age'

# %%
#Age distribution
plt.title("Age dist")
plt.hist(data["Age"], color = "red")
plt.show()


plt.title("Balance dist")
plt.hist(data["Balance"], color = "red")
plt.show()

# maybe

# %%
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dbc0aa08d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dbc0712490>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dbc08fd210>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dbc08fd850>}

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips["total_bill"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_34272\1984207902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"], kde = False, bins = 30)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_34272\946594181.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"], kde = False, bins = 30)
# <Axes: xlabel='total_bill'>

# %%
sns.scatterplot(x = tips.total_bill, y=tips.tip, data = tips, hue= 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, hue = 'smoker')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = tips.tota   l_bill, y=tips.tip, data = tips, hue = 'size')
# Out:
#   Cell In[13], line 1
#     sns.relplot(x = tips.tota   l_bill, y=tips.tip, data = tips, hue = 'size')
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, style = 'smoker', hue = 'time')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip)

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="reg")

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="hex")

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="kde") #contour>>meterological

# %%
#pairplot>> it will plot all the pairwise relationship of the dataframe

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'smoker',)

# %%
sns.pairplot(tips, hue = 'smoker',palette = 'coolwarm')

# https://seaborn.pydata.org/generated/seaborn.color_palette.html
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
#Boxplot >> to know outliers
#1, 2, 3, 4, 5, 100 >>> extreme data, for each day give me outlier for total bill

sns.boxplot(x = 'day', y='total_bill', data=tips, palette = 'rainbow')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3224\789706031.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'day', y='total_bill', data=tips, palette = 'rainbow')
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.boxplot(data=tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: xlabel='size', ylabel='Density'>

# %%
#correlation >> to understand the relationship between

# %%
tips_num = tips[['total_bill', 'tip', 'size']]

# %%
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_num.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y='tip', data = tips, height = 20, aspect = 1)

# %%
sns.catplot(x = 'day', y = 'tip', data = tips, kind='swarm')
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\seaborn\categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
