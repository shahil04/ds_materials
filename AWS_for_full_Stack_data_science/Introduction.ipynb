# %%
AWS --start with Questions 

there is a webiste 
how to live 
1. free things
2. paid things

ok we host --> then how we manage server load like no of pepele 
cost of server  
server environment
mu
