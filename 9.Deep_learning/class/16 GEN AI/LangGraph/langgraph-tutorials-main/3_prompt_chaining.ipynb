# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "I. Introduction\n    A. Definition of AI\n    B. Importance of AI in today's technological landscape\n    C. Overview of the rise of AI in India\n\nII. Historical perspective of AI in India\n    A. Early adoption of AI technology in India\n    B. Role of government policies in promoting AI research and development\n    C. Evolution of Indian startups focusing on AI\n\nIII. Current state of AI in India\n    A. Growth of AI startups and companies in India\n    B. Role of Indian Institutes and research centers in AI development\n    C. Challenges faced by the AI industry in India\n\nIV. Applications of AI in various sectors in India\n    A. Healthcare\n    B. Agriculture\n    C. Finance\n    D. Retail\n    E. Manufacturing\n\nV. Impact of AI on the Indian economy\n    A. Job creation and workforce transformation\n    B. Increased productivity and efficiency\n    C. Potential for economic growth and innovation\n\nVI. Ethical considerations and challenges of AI in India\n    A. Data privacy and security concerns\n    B. Bias and discrimination in AI algorithms\n    C. Regulatory frameworks and policies\n\nVII. Future trends and opportunities in AI in India\n    A. Investments and funding in AI startups\n    B. Collaboration with global AI players\n    C. Potential for AI to address India's social challenges\n\nVIII. Conclusion\n    A. Summary of key points discussed in the blog\n    B. Outlook on the future of AI in India\n    C. Call to action for stakeholders to harness the potential of AI for India's growth and development.", 'content': "Introduction:\n\nArtificial Intelligence, or AI, is a rapidly emerging technology that is revolutionizing various industries and sectors around the world. AI refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. It encompasses a range of technologies such as machine learning, neural networks, natural language processing, and robotics. In today's technological landscape, AI is increasingly becoming a vital component in driving innovation, efficiency, and productivity across various domains.\n\nIn India, the rise of AI has been significant in recent years, with the government, academia, and industry coming together to promote AI research, development, and adoption. This blog aims to explore the historical perspective, current state, applications, impact, ethical considerations, future trends, and opportunities of AI in India.\n\nHistorical perspective of AI in India:\n\nIndia has a long history of adopting AI technologies, with research and development dating back to the 1980s. The role of government policies in promoting AI research and development has been instrumental in fostering a conducive environment for innovation in the country. Over the years, Indian startups focusing on AI have emerged, catering to various sectors and industries with innovative solutions.\n\nCurrent state of AI in India:\n\nThe growth of AI startups and companies in India has been remarkable, with a significant increase in investments and funding in recent years. Indian Institutes and research centers have also been actively involved in AI development and have contributed towards creating a skilled workforce in the AI domain. However, the AI industry in India faces challenges such as data privacy concerns, talent shortage, and regulatory uncertainties.\n\nApplications of AI in various sectors in India:\n\nAI has found widespread applications in various sectors in India, including healthcare, agriculture, finance, retail, and manufacturing. In healthcare, AI technologies are being used for diagnostics, personalized treatment, and drug discovery. In agriculture, AI solutions are helping farmers improve crop yields and optimize resources. In finance, AI-powered algorithms are being used for fraud detection, risk assessment, and trading. In retail, AI is being utilized for personalized marketing and customer engagement. And ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Definition of AI
#     B. Importance of AI in today's technological landscape
#     C. Overview of the rise of AI in India
#
# II. Historical perspective of AI in India
#     A. Early adoption of AI technology in India
#     B. Role of government policies in promoting AI research and development
#     C. Evolution of Indian startups focusing on AI
#
# III. Current state of AI in India
#     A. Growth of AI startups and companies in India
#     B. Role of Indian Institutes and research centers in AI development
#     C. Challenges faced by the AI industry in India
#
# IV. Applications of AI in various sectors in India
#     A. Healthcare
#     B. Agriculture
#     C. Finance
#     D. Retail
#     E. Manufacturing
#
# V. Impact of AI on the Indian economy
#     A. Job creation and workforce transformation
#     B. Increased productivity and efficiency
#     C. Potential for economic growth and innovation
#
# VI. Ethical considerations and challenges of AI in India
#     A. Data privacy and security concerns
#     B. Bias and discrimination in AI algorithms
#     C. Regulatory frameworks and policies
#
# VII. Future trends and opportunities in AI in India
#     A. Investments and funding in AI startups
#     B. Collaboration with global AI players
#     C. Potential for AI to address India's social challenges
#
# VIII. Conclusion
#     A. Summary of key points discussed in the blog
#     B. Outlook on the future of AI in India
#     C. Call to action for stakeholders to harness the potential of AI for India's growth and development.

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Artificial Intelligence (AI) is a branch of computer science that aims to create intelligent machines that can perform tasks that typically require human intelligence. These tasks can include speech recognition, decision-making, visual perception, and more.
#
# B. The field of AI has been steadily growing in India over the past few years, with advancements being made in various industries such as healthcare, finance, education, and more.
#
# C. The purpose of this blog is to explore the rise of AI in India and its implications on the economy, job market, society, and culture.
#
# II. Historical Context of AI in India
#
# A. India has a rich history in AI research, with institutions like the Indian Institute of Technology (IIT) and the Indian Statistical Institute (ISI) making significant contributions to the field.
#
# B. The Indian government has also taken steps to promote AI development in the country, with initiatives like the National AI Portal and the National Mission on Interdisciplinary Cyber-Physical Systems (NM-ICPS).
#
# C. The rise of AI startups in India has also been a key factor in driving innovation in the field, with companies like Flipkart, Zomato, and Ola using AI to improve their services.
#
# III. Current State of AI in India
#
# A. Major industries in India are leveraging AI technology to improve efficiency, reduce costs, and enhance customer experience. Industries like healthcare, fintech, and e-commerce are leading the way in AI adoption.
#
# B. Indian companies like Wipro, Infosys, and Tata Consultancy Services (TCS) are at the forefront of AI innovation, developing cutting-edge solutions for clients both in India and globally.
#
# C. The impact of AI on the Indian economy and job market has been significant, with AI creating new job opportunities in fields like data science, machine learning, and AI development.
#
# IV. Challenges and Opportunities
#
# A. Challenges faced by AI adoption in India include issues like data privacy, security concerns, and a lack of skilled professionals in the field.
#
# B. However, there are also many opportunities for growth and development in the AI sector, with the potential to create new revenue streams, improve efficiency, and drive innovation in various industries.
#
# C. The importance of AI education and skill development in India cannot be overstated, as a trained workforce is essential for the successful implementation of AI technologies.
#
# V. Future Outlook
#
# A. Predictions for the future of AI in India include continued growth in AI adoption across industries, with AI becoming an integral part of business operations in the country.
#
# B. Potential areas of growth and innovation in AI include the development of autonomous vehicles, AI-driven healthcare solutions, and personalized customer experiences.
#
# C. The implications of AI on society and culture in India are vast, with AI technology potentially changing the way we live, work, and interact with each other.
#
# VI. Conclusion
#
# A. In conclusion, the rise of AI in India presents both challenges and opportunities for the country, with the potential to drive economic growth, create new job opportunities, and improve the lives of citizens.
#
# B. It is important for readers to stay updated on AI developments in India and to continue learning about the field to fully understand its impact on society and the economy.
#
# C. As AI continues to evolve and grow in India, it is crucial for the country to embrace this technology and leverage its potential for the benefit of all.
