# %% [markdown]
# ### Intermediate Level
#
# * Zero-Shot Prompting
# * One-Shot Prompting
# * Few-Shot Prompting
# * Role Prompting
#
# ### Advanced Level
#
# * Chain of Thought (CoT)
# * Self-Consistency
# * ReAct
# * Structured Outputs
# * JSON Outputs
# * Prompt Chaining

# %% [markdown]
# For your **Prompt Engineering Course**, a practical Jupyter Notebook should demonstrate all major prompting techniques using **free Hugging Face models** so students can run everything without OpenAI API costs.
#
# ---
#
# # 📘 Prompt Engineering Practical Notebook
#
# ## Module-wise Hands-on Labs using Free Hugging Face Models
#
# ### Environment Setup
#
# ```python
# !pip install transformers accelerate torch sentencepiece
# !pip install huggingface_hub
# ```
#
# ---
#
# # Notebook 1: Introduction to LLMs
#
# ## Load Free Model
#
# ```python
# from transformers import pipeline
#
# generator = pipeline(
#     "text-generation",
#     model="google/gemma-2b-it"
# )
#
# prompt = "Explain Artificial Intelligence in simple words."
#
# response = generator(
#     prompt,
#     max_new_tokens=100
# )
#
# print(response[0]["generated_text"])
# ```
#
# ---
#
# # Notebook 2: Basic Prompt Engineering
#
# ## Weak Prompt vs Strong Prompt
#
# ```python
# weak_prompt = "Explain Python"
#
# strong_prompt = """
# Act as a Python Instructor.
#
# Explain Python Programming.
#
# Include:
# 1. Definition
# 2. Features
# 3. Applications
#
# Use simple language.
# """
#
# print(generator(weak_prompt,max_new_tokens=100)[0]["generated_text"])
#
# print("="*50)
#
# print(generator(strong_prompt,max_new_tokens=200)[0]["generated_text"])
# ```
#
# ---
#
# # Notebook 3: Zero-Shot Prompting
#
# ```python
# prompt = """
# Classify the sentiment:
#
# Text:
# I absolutely loved this product.
#
# Options:
# Positive
# Negative
# Neutral
# """
#
# print(generator(prompt,max_new_tokens=50)[0]["generated_text"])
# ```
#
# ---
#
# # Notebook 4: One-Shot Prompting
#
# ```python
# prompt = """
# Review:
# This movie was fantastic.
#
# Sentiment:
# Positive
#
# Review:
# The service was horrible.
#
# Sentiment:
# """
#
# print(generator(prompt,max_new_tokens=20)[0]["generated_text"])
# ```
#
# ---
#
# # Notebook 5: Few-Shot Prompting
#
# ```python
# prompt = """
# Review:
# Excellent service.
# Sentiment:
# Positive
#
# Review:
# Poor quality.
# Sentiment:
# Negative
#
# Review:
# Average experience.
# Sentiment:
# Neutral
#
# Review:
# Fast delivery but damaged packaging.
# Sentiment:
# """
#
# print(generator(prompt,max_new_tokens=20)[0]["generated_text"])
# ```
#
# ---
#
# # Notebook 6: Chain of Thought Prompting
#
# ```python
# prompt = """
# A shop gives 20% discount on ₹5000.
#
# Think step-by-step.
#
# What is the final price?
# """
#
# print(generator(prompt,max_new_tokens=200)[0]["generated_text"])
# ```
#
# ---
#
# # Notebook 7: Persona Prompting
#
# ```python
# prompt = """
# Act as a Senior Data Scientist.
#
# Explain Machine Learning to MBA students.
#
# Use real-world business examples.
# """
#
# print(generator(prompt,max_new_tokens=200)[0]["generated_text"])
# ```
#
# ---
#
# # Notebook 8: Structured Output Generation
#
# ## JSON Output
#
# ```python
# prompt = """
# Extract candidate information.
#
# Candidate:
# Rahul Sharma has 3 years experience in Python, SQL and Power BI.
#
# Output JSON only.
# """
#
# print(generator(prompt,max_new_tokens=200)[0]["generated_text"])
# ```
#
# Expected:
#
# ```json
# {
#   "name":"Rahul Sharma",
#   "experience":"3 years",
#   "skills":["Python","SQL","Power BI"]
# }
# ```
#
# ---
#
# # Notebook 9: Prompt Chaining
#
# ## Step 1
#
# ```python
# topic_prompt = """
# Generate a blog topic about Artificial Intelligence.
# """
#
# topic = generator(topic_prompt,max_new_tokens=50)[0]["generated_text"]
#
# print(topic)
# ```
#
# ---
#
# ## Step 2
#
# ```python
# outline_prompt = f"""
# Create blog outline.
#
# Topic:
# {topic}
# """
#
# outline = generator(outline_prompt,max_new_tokens=200)[0]["generated_text"]
#
# print(outline)
# ```
#
# ---
#
# ## Step 3
#
# ```python
# article_prompt = f"""
# Write complete article.
#
# Outline:
# {outline}
# """
#
# article = generator(article_prompt,max_new_tokens=500)[0]["generated_text"]
#
# print(article)
# ```
#
# ---
#
# # Notebook 10: Text Classification
#
# ```python
# from transformers import pipeline
#
# classifier = pipeline(
#     "text-classification",
#     model="distilbert-base-uncased-finetuned-sst-2-english"
# )
#
# classifier("This course is amazing")
# ```
#
# ---
#
# # Notebook 11: Sentiment Analysis
#
# ```python
# reviews = [
#     "I love this laptop",
#     "Worst phone ever",
#     "The product is okay"
# ]
#
# for review in reviews:
#     print(classifier(review))
# ```
#
# ---
#
# # Notebook 12: Embeddings Demo
#
# ```python
# from transformers import AutoTokenizer, AutoModel
# import torch
#
# tokenizer = AutoTokenizer.from_pretrained(
#     "sentence-transformers/all-MiniLM-L6-v2"
# )
#
# model = AutoModel.from_pretrained(
#     "sentence-transformers/all-MiniLM-L6-v2"
# )
#
# text = "Artificial Intelligence"
#
# inputs = tokenizer(
#     text,
#     return_tensors="pt"
# )
#
# outputs = model(**inputs)
#
# embedding = outputs.last_hidden_state.mean(dim=1)
#
# print(embedding.shape)
# ```
#
# ---
#
# # Notebook 13: Simple RAG Demo
#
# ## Install
#
# ```python
# !pip install faiss-cpu
# ```
#
# ---
#
# ## Create Knowledge Base
#
# ```python
# documents = [
#     "Python is a programming language",
#     "Machine Learning is a subset of AI",
#     "Deep Learning uses neural networks"
# ]
# ```
#
# ---
#
# ## Embed Documents
#
# ```python
# from sentence_transformers import SentenceTransformer
#
# embedder = SentenceTransformer(
#     "all-MiniLM-L6-v2"
# )
#
# embeddings = embedder.encode(documents)
# ```
#
# ---
#
# ## Store in FAISS
#
# ```python
# import faiss
# import numpy as np
#
# dimension = embeddings.shape[1]
#
# index = faiss.IndexFlatL2(dimension)
#
# index.add(np.array(embeddings))
# ```
#
# ---
#
# ## Search
#
# ```python
# query = "What is Deep Learning?"
#
# query_embedding = embedder.encode([query])
#
# D,I = index.search(
#     np.array(query_embedding),
#     k=2
# )
#
# print(I)
# ```
#
# ---
#
# # Notebook 14: Image Captioning
#
# ```python
# from transformers import pipeline
#
# captioner = pipeline(
#     "image-to-text",
#     model="Salesforce/blip-image-captioning-base"
# )
#
# result = captioner("image.jpg")
#
# print(result)
# ```
#
# ---
#
# # Notebook 15: Document Question Answering
#
# ```python
# from transformers import pipeline
#
# qa = pipeline(
#     "question-answering",
#     model="distilbert-base-cased-distilled-squad"
# )
#
# context = """
# Python is a programming language created by Guido van Rossum.
# """
#
# question = "Who created Python?"
#
# result = qa(
#     question=question,
#     context=context
# )
#
# print(result)
# ```
#
# ---
#
# # Notebook 16: AI Agent Simulation
#
# ```python
# def planner(task):
#
#     prompt = f"""
#     Break this task into steps:
#
#     {task}
#     """
#
#     return generator(
#         prompt,
#         max_new_tokens=200
#     )[0]["generated_text"]
# ```
#
# ```python
# task = "Build a Data Science Portfolio"
#
# print(planner(task))
# ```
#
# ---
#
# # Final Capstone Notebook
#
# ## AI Resume Reviewer
#
# Features:
#
# * Upload Resume PDF
# * Extract Text
# * Summarize Resume
# * Extract Skills
# * Match Job Description
# * Generate Interview Questions
# * Provide Feedback
#
# ### Models
#
# | Task             | Free Hugging Face Model                         |
# | ---------------- | ----------------------------------------------- |
# | Text Generation  | google/gemma-2b-it                              |
# | Classification   | distilbert-base-uncased-finetuned-sst-2-english |
# | Embeddings       | sentence-transformers/all-MiniLM-L6-v2          |
# | QA               | distilbert-base-cased-distilled-squad           |
# | Image Captioning | Salesforce/blip-image-captioning-base           |
#
# This collection of notebooks covers approximately **90% of the Prompt Engineering syllabus** and can be taught completely using free Hugging Face models with no paid API required.

# %% [markdown]
# # Prompt Evaluation & Optimization - Practical Code Examples
#
# ---
#
# # 1. Basic Prompt Evaluation Framework
#
# ```python
# # Install
#
# # pip install openai
#
# from openai import OpenAI
#
# client = OpenAI(api_key="YOUR_API_KEY")
#
# prompt = """
# Summarize the following text in 3 bullet points:
#
# Artificial Intelligence is transforming industries worldwide...
# """
#
# response = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {"role":"user","content":prompt}
#     ]
# )
#
# print(response.choices[0].message.content)
# ```
#
# ---
#
# # 2. Automated Prompt Evaluation
#
# Evaluate prompts based on:
#
# * Accuracy
# * Completeness
# * Clarity
# * Format Compliance
#
# ```python
# from openai import OpenAI
#
# client = OpenAI(api_key="YOUR_API_KEY")
#
# answer = """
# AI is changing healthcare through diagnostics and automation.
# """
#
# evaluation_prompt = f"""
# You are an AI evaluator.
#
# Evaluate the response on:
#
# 1. Accuracy (1-10)
# 2. Completeness (1-10)
# 3. Clarity (1-10)
#
# Response:
# {answer}
#
# Return JSON format.
# """
#
# response = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {"role":"user","content":evaluation_prompt}
#     ]
# )
#
# print(response.choices[0].message.content)
# ```
#
# ---
#
# # 3. A/B Prompt Testing
#
# Compare two prompts.
#
# ```python
# from openai import OpenAI
#
# client = OpenAI(api_key="YOUR_API_KEY")
#
# prompt_A = "Explain Machine Learning."
#
# prompt_B = """
# Explain Machine Learning for a 10-year-old child
# using simple examples.
# """
#
# for prompt in [prompt_A, prompt_B]:
#
#     response = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[
#             {"role":"user","content":prompt}
#         ]
#     )
#
#     print("\nPrompt:")
#     print(prompt)
#
#     print("\nResponse:")
#     print(response.choices[0].message.content)
# ```
#
# ---
#
# # 4. Hallucination Detection Prompt
#
# ```python
# from openai import OpenAI
#
# client = OpenAI(api_key="YOUR_API_KEY")
#
# generated_answer = """
# Python was created in 1985 by Elon Musk.
# """
#
# fact_check_prompt = f"""
# Check if the following statement contains
# hallucinations or factual errors.
#
# Statement:
# {generated_answer}
#
# Provide:
# 1. Correctness
# 2. Explanation
# 3. Correct Version
# """
#
# response = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {"role":"user","content":fact_check_prompt}
#     ]
# )
#
# print(response.choices[0].message.content)
# ```
#
# ---
#
# # 5. Prompt Optimization Loop
#
# Production systems continuously improve prompts.
#
# ```python
# from openai import OpenAI
#
# client = OpenAI(api_key="YOUR_API_KEY")
#
# user_query = "Explain Neural Networks"
#
# prompt = f"""
# Explain {user_query}
# using simple language.
# """
#
# response = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {"role":"user","content":prompt}
#     ]
# )
#
# answer = response.choices[0].message.content
#
# evaluation_prompt = f"""
# Rate this response from 1-10:
#
# {answer}
# """
#
# evaluation = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {"role":"user","content":evaluation_prompt}
#     ]
# )
#
# print("Answer:")
# print(answer)
#
# print("\nEvaluation:")
# print(evaluation.choices[0].message.content)
# ```
#
# ---
#
# # Production-Level GenAI Systems
#
# ---
#
# # Project Structure
#
# ```text
# genai_app/
#
# │
# ├── app.py
# ├── prompts/
# │     ├── summarizer.txt
# │     ├── classifier.txt
# │
# ├── services/
# │     ├── llm_service.py
# │     ├── evaluator.py
# │
# ├── logs/
# │
# ├── config.py
# │
# ├── requirements.txt
# │
# └── Dockerfile
# ```
#
# ---
#
# # 1. Prompt Versioning System
#
# ```python
# PROMPT_V1 = """
# Summarize the text.
# """
#
# PROMPT_V2 = """
# Summarize the text in 5 bullet points.
# """
#
# CURRENT_PROMPT = PROMPT_V2
# ```
#
# ---
#
# # 2. Centralized LLM Service
#
# ```python
# # services/llm_service.py
#
# from openai import OpenAI
#
# class LLMService:
#
#     def __init__(self, api_key):
#         self.client = OpenAI(api_key=api_key)
#
#     def generate(self, prompt):
#
#         response = self.client.chat.completions.create(
#             model="gpt-4o-mini",
#             messages=[
#                 {"role":"user","content":prompt}
#             ]
#         )
#
#         return response.choices[0].message.content
# ```
#
# ---
#
# # 3. Logging Responses
#
# ```python
# import logging
#
# logging.basicConfig(
#     filename="logs/app.log",
#     level=logging.INFO
# )
#
# logging.info("Prompt Executed")
# ```
#
# ---
#
# # 4. Output Guardrails
#
# Prevent invalid output.
#
# ```python
# import json
#
# def validate_output(output):
#
#     try:
#         json.loads(output)
#         return True
#
#     except:
#         return False
# ```
#
# ---
#
# # 5. Structured JSON Output
#
# ```python
# prompt = """
# Extract:
#
# 1. Name
# 2. Email
# 3. Skills
#
# Return ONLY JSON.
# """
#
# response = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {"role":"user","content":prompt}
#     ]
# )
#
# print(response.choices[0].message.content)
# ```
#
# Expected Output:
#
# ```json
# {
#   "name":"John",
#   "email":"john@gmail.com",
#   "skills":[
#       "Python",
#       "SQL",
#       "FastAPI"
#   ]
# }
# ```
#
# ---
#
# # 6. FastAPI Production API
#
# ```python
# from fastapi import FastAPI
# from openai import OpenAI
#
# app = FastAPI()
#
# client = OpenAI(api_key="YOUR_API_KEY")
#
# @app.post("/generate")
# def generate(text: str):
#
#     response = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[
#             {
#                 "role":"user",
#                 "content":text
#             }
#         ]
#     )
#
#     return {
#         "response":
#         response.choices[0].message.content
#     }
# ```
#
# Run:
#
# ```bash
# uvicorn app:app --reload
# ```
#
# ---
#
# # 7. Rate Limiting
#
# ```python
# from slowapi import Limiter
#
# limiter = Limiter(key_func=lambda: "global")
# ```
#
# ---
#
# # 8. Response Caching
#
# ```python
# from functools import lru_cache
#
# @lru_cache(maxsize=100)
# def get_response(prompt):
#     return llm.generate(prompt)
# ```
#
# ---
#
# # 9. Prompt Monitoring Dashboard Data
#
# ```python
# evaluation_metrics = {
#
#     "accuracy": 9,
#     "relevance": 8,
#     "latency": 2.1,
#     "cost": 0.003
# }
#
# print(evaluation_metrics)
# ```
#
# ---
#
# # 10. Enterprise Prompt Evaluation Pipeline
#
# ```python
# def evaluate_response(response):
#
#     score = {
#
#         "relevance": 0,
#         "accuracy": 0,
#         "clarity": 0,
#         "hallucination": 0
#     }
#
#     score["relevance"] = 9
#     score["accuracy"] = 8
#     score["clarity"] = 9
#     score["hallucination"] = 1
#
#     return score
# ```
#
# ---
#
# # Final Production-Level Capstone
#
# ## AI Resume Screening System
#
# ### Features
#
# * Resume Upload
# * JD Upload
# * Skill Extraction
# * Candidate Scoring
# * Interview Question Generation
# * Prompt Evaluation
# * Hallucination Detection
# * FastAPI Backend
# * Docker Deployment
# * Logging
# * Monitoring
#
# ### Tech Stack
#
# * Python
# * FastAPI
# * OpenAI/Gemini
# * LangChain
# * LangGraph
# * ChromaDB
# * PostgreSQL
# * Docker
# * GitHub Actions
# * Prometheus
# * Grafana
#
# ### Industry Skills Covered
#
# * Prompt Engineering
# * Prompt Evaluation
# * Guardrails
# * Structured Outputs
# * RAG
# * Agentic AI
# * LLMOps
# * GenAI Deployment
# * Monitoring & Observability
# * Production AI Architecture

# %%
# prompt Engineering
# RAG
# Vector Database
#

# %%
import transformers
import torch

model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

pipeline = transformers.pipeline(
    "text-generation",
    model=model_id,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device_map="auto",
)

messages = [
    {"role": "system", "content": "You are a pirate chatbot who always responds in pirate speak!"},
    {"role": "user", "content": "Who are you?"},
]

outputs = pipeline(
    messages,
    max_new_tokens=256,
)
print(outputs[0]["generated_text"][-1])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     401     try:
# --> 402         response.raise_for_status()
#     403     except HTTPError as e:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Meta-Llama-3.1-8B-Instruct/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...

# %%
import transformers
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "mistralai/Mistral-7B-Instruct-v0.2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    dtype=torch.bfloat16,
    device_map="auto"
)

prompt = """You are a customer support assistant.
Customer: My product is delayed. What should I do?
Assistant:"""

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
output = model.generate(**inputs, max_new_tokens=150)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu and disk.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ...

# %% [markdown]
# ### Skills for Teaching in Sequence:
#
# 1.  **Foundational Programming & AI/ML Libraries:**
#     *   Python proficiency.
#     *   Experience with AI/ML libraries like HuggingFace Transformers, LangChain, PyTorch, TensorFlow.
#
# 2.  **Understanding Large Language Models (LLMs):**
#     *   Conceptual understanding of LLMs.
#     *   Prompt Engineering techniques.
#     *   Understanding of Embeddings.
#
# 3.  **LLM Development & Deployment:**
#     *   Designing, developing, and deploying AI solutions using various LLMs (GPT, LLaMA, Claude, Mistral).
#     *   Fine-tuning and customizing pre-trained LLMs for specific use cases.
#     *   Working with closed-source models via APIs (e.g., OpenAI, Gemini).
#
# 4.  **Natural Language Processing (NLP) Pipelines:**
#     *   Building and maintaining NLP pipelines for tasks like classification, summarization, and semantic search.
#
# 5.  **Vector Databases:**
#     *   Building and maintaining vector database pipelines using tools like Milvus, Pinecone, or FAISS.
#
# 6.  **Model Deployment & MLOps:**
#     *   Deploying models using REST APIs, Docker, and cloud platforms (AWS/GCP/Azure).
#     *   Familiarity with MLOps and version control tools (Git, MLflow).
#     *   Knowledge of LLMOps platforms (e.g., LangSmith, Weights & Biases).
#
# 7.  **Performance Analysis:**
#     *   Analyzing and improving model performance using appropriate metrics.

# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=os.environ["HF_TOKEN"],
)

completion = client.chat.completions.create(
    model="meta-llama/Llama-3.1-8B-Instruct:novita",
    messages=[
        {
            "role": "user",
            "content": "What is   the capital of France?"
        }
    ],
)

print(completion.choices[0].message)
