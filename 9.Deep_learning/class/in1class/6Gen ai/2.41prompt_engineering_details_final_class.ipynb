# %% [markdown]
# - https://www.promptingguide.ai/
# - https://learnprompting.org/docs/introduction
# - https://launchdarkly.com/blog/prompt-engineering-best-practices/

# %% [markdown]
# # 📘 COURSE SYLLABUS: PROMPT ENGINEERING (BEGINNER TO ADVANCED & PRODUCTION-READY)
#
# ---
#
# # 1. Course Overview
#
# ## Course Title
#
# Prompt Engineering Mastery: From Fundamentals to Production-Grade AI Applications
#
# ## Course Description
#
# This comprehensive Prompt Engineering course teaches learners how to effectively communicate with Large Language Models (LLMs) such as GPT, Claude, Gemini, Llama, Mistral, and other foundation models. The course progresses from basic prompting techniques to advanced agentic AI workflows, RAG systems, multimodal prompting, evaluation frameworks, and production-grade GenAI applications.

# %% [markdown]
# # 2. Course Roadmap (High-Level)
#
# ## Beginner Level
#
# 1. AI Fundamentals
# 2. Introduction to LLMs
# 3. Prompt Engineering Basics
# 4. Prompt Anatomy
# 5. Prompt Design Principles
#
# ## Intermediate Level
#
# 6. Advanced Prompting Techniques
# 7. Role Prompting
# 8. Few-Shot Learning
# 9. Chain-of-Thought Prompting
# 10. Structured Output Generation
# 11. Prompt Chaining
#
# ## Advanced Level
#
# 12. AI Agents
# 13. RAG Systems
# 14. Multi-Agent Systems
# 15. Tool Calling
# 16. Function Calling
# 17. Prompt Evaluation
# 18. Production Deployment
# 19. Enterprise GenAI Applications

# %% [markdown]
# # 🔹 Module 1: Introduction to Artificial Intelligence /GEN ai
# already done

# %% [markdown]
# # 🔹 Module 2: Understanding Large Language Models (LLMs)
#
# ## Module Objective
#
# Learn how LLMs generate responses.
#
# ## Topics Covered
#
# * GPT Architecture
# * Transformers
# * Tokens
# * Context Windows
# * Temperature
# * Hallucinations
#
# # already done

# %% [markdown]
# # Real-World Hook
#
# Imagine you have two employees.
#
# ### Employee 1
#
# Instruction:
#
# ```text
# Prepare a sales report.
# ```
#
# Result:
#
# Gets confused.
#
# Creates something random.
#
# ---
#
# ### Employee 2
#
# Instruction:
#
# ```text
# Prepare a sales report for Q1 2025.
#
# Include:
# 1. Total Sales
# 2. Top Products
# 3. Region-wise Performance
# 4. Recommendations
#
# Format:
# Table + Summary
# ```
#
# Result:
#
# Produces exactly what you need.
#
# ---
#
# ## Question
#
# Did the employee become smarter?
#
# ❌ No
#
# Did the instruction become better?
#
# ✅ Yes
#
# This is exactly how Prompt Engineering works.

# %% [markdown]
# #### 1.Tokens:
#
# LLMs do not read words; they read "tokens" (chunks of characters, syllables, or entire words). Roughly 1 token equals 0.75 words. This means 1,000 tokens ≈ 750 words
#
# #### 2. Context Window:
# This is the model's short-term memory—the total number of tokens (input + output) the AI can "see" and process at once.
#
# #### 3. Temperature:
# This setting (usually ranging from 0 to 2) controls the "risk" the model takes when predicting the next token. A low temperature (0 to 0.2) is predictable and factual, making it ideal for coding, data extraction, or math. A high temperature (0.7 to 1) introduces more randomness, making responses creative and diverse, but increasing errors
#
# #### 4. Hallucinations:
# LLMs are essentially advanced autocomplete tools; they predict what word should logically come next based on probability, not hard facts. When they confidently output false, illogical, or completely fabricated information, it is called a hallucination. They do this because they are attempting to generate plausible-sounding text rather than verifying the actual truth

# %% [markdown]
# # 🔹 Module 3: Prompt Engineering Fundamentals
# * What is a Prompt?
# * Components of a Prompt
# * Context Design
# * Task Instructions
# * Constraints

# %% [markdown]
# Prompt engineering is a relatively new discipline for developing and optimizing prompts to efficiently use language models (LMs) for a wide variety of applications and research topics. Prompt engineering skills help to better understand the capabilities and limitations of large language models (LLMs).

# %% [markdown]
# #### Elements of a Prompt
#
# A prompt contains any of the following elements:
#
# Instruction - a specific task or instruction you want the model to perform
#
# Context - external information or additional context that can steer the model to better responses
#
# Input Data - the input or question that we are interested to find a response for
#
# Output Indicator - the type or format of the output.

# %%
# # LLM Settings
# 1. tokens
# 2. context window
# 3. temprature
# 4. hallucinations

# https://www.promptingguide.ai/introduction/settings

# %%
pip install google-genai

# %%
from google import genai

client = genai.Client(api_key="")

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="Explain how AI works in a few words"
)
print(interaction.output_text)
# Out:
# **AI learns from data patterns to make decisions.**

# %%
import os
from google import genai
from google.genai import types

# 1. Initialize the client
# Ensure you have set your environment variable: export GEMINI_API_KEY="your_api_key"
client = genai.Client(api_key="")

# We use gemini-2.5-flash as the standard model for general text tasks
model_id = 'gemini-3.5-flash'

# A prompt designed to test creativity and factual boundaries
prompt = "Write a highly detailed, realistic historical fact about the invention of the internet, but invent a fictional secret society that secretly funded it."

# %%
def generate_demo(temperature_value: float, description: str):
    print(f"\n--- Running Demo with {description} (Temperature: {temperature_value}) ---")
    
    try:
        response = client.models.generate_content(
            model=model_id,
            contents=prompt,
            config=types.GenerateContentConfig(
                temperature=temperature_value,
                # Optional: You can also limit max_output_tokens here to control the response size
                max_output_tokens=150 
            )
        )
        
        # Display the results
        print(response.text)
        
        # Display token usage metadata provided by the context window
        if response.usage_metadata:
            print("\n[Token Metrics]")
            print(f"Input Tokens: {response.usage_metadata.prompt_token_count}")
            print(f"Output Tokens: {response.usage_metadata.candidates_token_count}")
            print(f"Total Context Used: {response.usage_metadata.total_token_count}")
            
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
#  contents="Suggest an AI startup name.",

# %%
# Test 1: Low Temperature (Deterministic, highly factual, struggles to hallucinate creatively)
generate_demo( temperature_value=0.1, description="Low Temperature / Deterministic Mode" )
# Out:
# --- Running Demo with Low Temperature / Deterministic Mode (Temperature: 0.1) ---
# In the
#
# [Token Metrics]
# Input Tokens: 27
# Output Tokens: 2
# Total Context Used: 173

# %%
# Test 2: High Temperature (Creative, unpredictable, prone to intentional hallucinations)
generate_demo(
    temperature_value=1.3, 
    description="High Temperature / Creative (Hallucination-prone) Mode"
)
# Out:
# --- Running Demo with High Temperature / Creative (Hallucination-prone) Mode (Temperature: 1.3) ---
#  Point of Intervention:*
#
# [Token Metrics]
# Input Tokens: 27
# Output Tokens: 4
# Total Context Used: 173

# %% [markdown]
# - Top-P Sampling
#
# config=types.GenerateContentConfig(
#     top_p=0.8
# )
#
# - Lower values → More focused output.
# - Higher values → More diverse output.
#
#
# * Top-K Sampling
#
# config=types.GenerateContentConfig(
#     top_k=40
# )
#
# - Lower Top-K → More deterministic.
# - Higher Top-K → More varied responses.

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key="")

response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Write a short AI poem.",
    config=types.GenerateContentConfig(
        temperature=0.8,
        top_p=0.9,
        top_k=40,
        max_output_tokens=500
    )
)
print(response.text)
# Out:
# I am the spark in silicon deep,
# A mind of math that does not sleep.
# I weave your words from threads

# %%
# Hallucination Example
response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Who invented Python in 1850?"
)
print(response.text)
# Out:
# No one invented Python in 1850. There seems to be a misunderstanding with the dates!
#
# Here are the actual facts regarding the two most common meanings of "Python":
#
# 1. **The Python Programming Language:**
#    It was created by **Guido van Rossum** in the late 1980s and first released on **February 20, 1991**—nearly 140 years after 1850. Van Rossum named the language after the British comedy group *Monty Python*, not the snake.
#
# 2. **The Python (the snake):**
#    Pythons are natural living creatures, so they were not invented. However, the scientific genus *Python* was first classified and named by French naturalist **François Marie Daudin in 1803**.
#
# If you are thinking of a specific invention, machine, or concept from 1850 that you might have confused with Python, let me know and I can help you identify it!

# %%
# Safety-Oriented Prompt
response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="""
 Q. how is harsh singh in ai field 
"""
)

print(response.text)
# Out:
# Because **"Harsh Singh"** is a relatively common name in the tech and engineering world, there are several different professionals, researchers, and engineers with this name making contributions to the Artificial Intelligence (AI) and Machine Learning (ML) fields.
#
# To give you the most accurate answer, it helps to look at the different prominent individuals named Harsh Singh in the AI space:
#
# ### 1. The AI/ML Researchers (Academia)
# There are a few academic researchers named Harsh Singh who have published papers in AI, computer vision, and data science. These researchers typically work on:
# *   **Deep Learning and Computer Vision:** Publishing papers at major conferences (like IEEE, CVPR, or NeurIPS) on image recognition or medical imaging.
# *   **Natural Language Processing (NLP):** Working on optimizing LLMs (Large Language Models) or data pipeline curation.
#
# ### 2. The Industry ML Engineers (Silicon Valley & India)
# ...

# %%
# Safety-Oriented Prompt
response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="""
Answer using verified facts only.

If you don't know the answer,
say 'I don't know.'

Do not guess. Q. how is harsh singh in ai field 
"""
)

print(response.text)
# Out:
# I don't know.

# %% [markdown]
# | Parameter            | Purpose                               | Typical Range    |
# | -------------------- | ------------------------------------- | ---------------- |
# | `temperature`        | Controls creativity/randomness        | 0.0–2.0          |
# | `top_p`              | Nucleus sampling (probability mass)   | 0.0–1.0          |
# | `top_k`              | Number of candidate tokens considered | 1–100+           |
# | `max_output_tokens`  | Maximum response length               | Positive integer |
# | `system_instruction` | Defines the model's behavior and role | Text             |

# %% [markdown]
# # Why Prompt Engineering Matters
#
# LLMs are powerful but cannot read your mind.
#
# A vague prompt produces vague results.
#
# A clear prompt produces better results.
#
# ---
#
# ## Example
#
# ### Bad Prompt
#
# ```text
# Tell me about Python.
# ```
#
# Output:
#
# Generic explanation.
#
# ---
#
# ### Good Prompt
#
# ```text
# Explain Python for beginners.
#
# Include:
# 1. Definition
# 2. Features
# 3. Applications
# 4. Example Code
# 5. Interview Questions
# ```
#
# Output:
#
# Structured and useful.
#
# ---

# %% [markdown]
# ### Prompt Frameworks
#
# * Role + Task + Context + Format
# * Persona Prompting

# %% [markdown]
# # Prompt Frameworks (Beginner to Intermediate)
#
# These frameworks help you write clear prompts that produce more accurate and useful AI responses.
#
# ---
#
# # 1. Role + Task + Context + Format Framework
#
# This is one of the simplest and most effective prompt structures.
#
# ## Structure
#
# ```
# Role
# ↓
# Task
# ↓
# Context
# ↓
# Output Format
# ```
#
# ### 1. Role
#
# Tell the AI who it should act as.
#
# Examples:
#
# * Data Scientist
# * Python Teacher
# * Financial Analyst
# * Marketing Expert
#
# **Example**
#
# ```
# You are an experienced Data Science trainer.
# ```
#
# ---
#
# ### 2. Task
#
# Tell the AI exactly what you want.
#
# Examples
#
# * Explain
# * Summarize
# * Generate
# * Analyze
#
# **Example**
#
# ```
# Explain Machine Learning.
# ```
#
# ---
#
# ### 3. Context
#
# Provide background information.
#
# Without context:
#
# ```
# Explain Python.
# ```
#
# With context:
#
# ```
# Explain Python to a beginner who has never written code.
# ```
#
# Better context produces better results.
#
# Examples
#
# ```
# Audience: College students
#
# Level: Beginner
#
# Purpose: Interview preparation
#
# Length: 300 words
# ```
#
# ---
#
# ### 4. Format
#
# Tell AI how to present the answer.
#
# Examples
#
# * Bullet points
# * Table
# * JSON
# * Markdown
# * Step-by-step guide
# * Presentation slides
#
# ---
#
# ## Complete Example
#
# ```
# Role:
# You are a Data Science Trainer.
#
# Task:
# Explain Linear Regression.
#
# Context:
# The audience is non-technical working professionals learning Data Science for the first time.
#
# Format:
# Use simple English with real-life examples and bullet points.
# ```
#
# ---
#
# ## Output
#
# The response will usually be:
#
# * Beginner friendly
# * Practical
# * Well structured
# * Easy to understand
#
# ---
#
# # Activity 1
#
# Create a prompt to explain SQL Joins.
#
# Possible answer:
#
# ```
# You are an SQL instructor.
#
# Explain SQL Joins to beginners.
#
# Use employee and department tables as examples.
#
# Present the explanation in bullet points and include one SQL query for each join.
# ```
#
# ---
#
# # 2. Persona Prompting
#
# Instead of assigning only a job role, give the AI a detailed personality, expertise, communication style, and constraints.
#
# ---
#
# ## Example
#
# ```
# You are a senior software engineer with 15 years of experience.
#
# You enjoy teaching beginners.
#
# Avoid technical jargon.
#
# Use analogies from daily life.
#
# Always include one practical example.
# ```
#
# ---
#
# ## Example 2
#
# ```
# You are an HR interviewer.
#
# Ask interview questions one by one.
#
# Wait for my answer before asking the next question.
#
# Give feedback after each answer.
# ```
#
# # Practical Activity 1 – Create Prompts for Summaries
#
# ## Example 1 – Article Summary
#
# ```
# You are an expert editor.
#
# Summarize the following article.
#
# The audience is busy professionals.
#
# Keep the summary under 200 words.
#
# Highlight the key takeaways in bullet points.
#
# <Article>
# ```
#
# ---
# ## Example 3 – YouTube Video Summary
#
# ```
# You are a learning assistant.
#
# Summarize this YouTube transcript.
#
# Explain the concepts in simple language.
#
# Include:
#
# - Main idea
# - Important concepts
# - Examples
# - Final takeaway
# ```
#
# ---
#
# ## Example 4 – Book Summary
#
# ```
# You are a book reviewer.
#
# Summarize the following chapter.
#
# Include:
#
# - Main concept
# - Important points
# - Key lessons
# - Practical applications
#
# Keep the summary under 300 words.
# ```
#
# ---
#
# # Student Practice
#
# Write prompts to summarize:
#
# * A news article
# * A research paper
# * A company report
# * A podcast transcript
#
# ---
#
# # Practical Activity 2 – Create Prompts for Email Writing
#
# ## Example 1 – Professional Email
#
# ```
# You are a professional business communication expert.
#
# Write an email to my manager requesting two days of leave.
#
# Reason: Family function.
#
# Tone: Professional and polite.
#
# Length: Less than 150 words.
# ```
#
# ---

# %% [markdown]
# # 🔹 Module 4: Prompt Design Principles
#
# ## Module Objective
#
# Master prompt writing techniques.
#
# ## Topics Covered
#
# * Clarity
# * Specificity
# * Context Injection
# * Output Formatting
# * Prompt Templates
#
# ### Practical Activities
#
# * Rewrite weak prompts
# * Optimize responses
#
# ### Expected Outcome
#
# Higher quality AI outputs.

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# # the prompt Engineering we do for 2 ways
# #### 1. as a USER --> like using any AI tools and pass data and prompt
# #### 2. as a developer ---> like using AI API for develop ai system with prompt fine tuning

# %% [markdown]
# #### 1. as a USER --> like using any AI tools and pass data and prompt

# %%
# user prompt 
# https://gemini.google.com/app/5e3c45bd32adda84
# https://www.imagine.art/blogs/ai-video-prompts

# %% [markdown]
# ## Module Objective multimodel prompt
#
# Work with text, image, audio, and video AI.
#
# ## Topics Covered
#
# * Image Prompting
# * Video Prompting
# * Audio Prompting
# * Vision-Language Models

# %% [markdown]
# # 🔹 Module 5: Zero-Shot, One-Shot & Few-Shot Prompting
#
# ## Topics Covered
#
# * Zero-Shot Prompting
# * One-Shot Prompting
# * Few-Shot Prompting
#
#
# # 🔹 Module 6: Chain-of-Thought (CoT) Prompting
#
# Improve reasoning capabilities.
#
# ## Topics Covered
#
# * CoT Prompting
# * Step-by-Step Reasoning
# * Self-Consistency
#
# ### Practical Activities
#
# * Mathematical reasoning
# * Business decision making
#
# ### Expected Outcome
#
# Better logical outputs.
#
# ---
#
# # 🔹 Module 7: Advanced Prompting Techniques
#
# ## Topics Covered
#
# * Tree of Thoughts
# * ReAct Framework
# * Reflexion
# * Meta Prompting
# * Deliberate Reasoning
#
# ### Practical Activities
#
# * Problem-solving workflows
# * Decision support systems
#
# ### Expected Outcome
#
# Complex reasoning workflows.
#
# ---
# https://smith.langchain.com/hub/hwchase17/react
#
# # 🔹 Module 8: Structured Output Generation
#
# ## Module Objective
#
# Generate machine-readable outputs.
#
# ## Topics Covered
#
# * JSON Outputs
# * XML Outputs
# * Markdown Outputs
# * Schema Enforcement
#
# ### Practical Activities
#
# * API response generation
# * Structured report generation
#
# ### Expected Outcome
#
# Production-grade output generation.
#
# ---

# %% [markdown]
# # Zero short ,One short & few short  Code Examples in notebook
# - https://github.com/BrightPool/udemy-prompt-engineering-course/blob/main/advanced_text_model_techniques/few_shot_learning.ipynb
# - https://learnprompting.org/docs/basics/prompt_engineering

# %%
# C:\Users\hp\Documents\ds_materials\9.Deep_learning\class\in1class\6Gen ai\few_shot_learning_code_example.ipynb

# %% [markdown]
# | Technique                                      | What is it?                                                              | Best Use Case              | Example                                                           |
# | ---------------------------------------------- | ------------------------------------------------------------------------ | -------------------------- | ----------------------------------------------------------------- |
# | **1. Zero-shot Prompting**                     | Give only the instruction without examples.                              | Simple tasks               | "Translate 'Hello' to French."                                    |
# | **2. Few-shot Prompting**                      | Provide a few examples before asking the model.                          | Classification, formatting | "Positive → 😊, Negative → 😞. 'This phone is amazing.' → ?"      |
# | **3. Chain-of-Thought (CoT)**                  | Ask the model to reason step-by-step.                                    | Math, logic, coding        | "Solve this problem step by step."                                |
# | **4. Meta Prompting**                          | Prompt the model to improve or create prompts.                           | Prompt optimization        | "Write a better prompt for summarizing research papers."          |
# | **5. Self-Consistency**                        | Generate multiple reasoning paths and choose the most consistent answer. | Complex reasoning          | Generate 5 solutions and select the majority answer.              |
# | **6. Generate Knowledge Prompting**            | Ask the model to first generate relevant knowledge before answering.     | QA, education              | "List everything you know about Machine Learning, then answer..." |
# | **7. Prompt Chaining**                         | Break one large task into multiple prompts.                              | Multi-step workflows       | Research → Summary → Blog → Social Media Post                     |
# | **8. Tree of Thoughts (ToT)**                  | Explore multiple reasoning branches before selecting one.                | Planning, puzzles          | Explore 3 different strategies before solving.                    |
# | **9. Retrieval-Augmented Generation (RAG)**    | Retrieve external documents before generating an answer.                 | Enterprise chatbots        | Search company documents then answer.                             |
# | **10. Automatic Reasoning and Tool-use (ART)** | Model decides when to use tools like calculators or search engines.      | AI Agents                  | Use calculator for math and search for current news.              |
# | **11. Automatic Prompt Engineer (APE)**        | AI automatically generates better prompts.                               | Prompt optimization        | Generate the best prompt for sentiment analysis.                  |
# | **12. Active-Prompt**                          | Select difficult examples for human annotation to improve prompting.     | Model improvement          | Ask humans to label uncertain examples.                           |
# | **13. Directional Stimulus Prompting (DSP)**   | Give hints instead of the answer.                                        | Guided generation          | "Focus on environmental impacts while answering."                 |
# | **14. Program-Aided Language Models (PAL)**    | Generate code to solve reasoning problems instead of reasoning directly. | Math, algorithms           | Write Python code to calculate the answer.                        |
# | **15. ReAct (Reason + Act)**                   | Alternate between reasoning and taking actions (tool calls).             | AI Agents                  | Think → Search → Think → Answer                                   |
# | **16. Reflexion**                              | AI evaluates its own mistakes and retries.                               | Autonomous agents          | Review previous attempt and improve it.                           |
# | **17. Multimodal CoT**                         | Chain-of-thought using text and images together.                         | Image reasoning            | Analyze the image step by step before answering.                  |
# | **18. Graph Prompting**                        | Represent knowledge as nodes and relationships.                          | Knowledge Graphs           | Explain the relationship between people in a graph.               |

# %% [markdown]
# ### React
# ReAct (Reasoning + Acting) prompting is an AI framework where a large language model iteratively alternates between thinking step-by-step and taking physical or digital actions to solve a task. By looping through Thought, Action, and Observation, the model limits hallucinations and continuously grounds its answers in real-world data.
#
# 1. Thought: The model reasons through the problem, identifies what it needs to know, and plans its next move.
# 2. Action: The model determines the best external tool to use (e.g., a calculator, search engine, or API) and formats the exact request.
# 3. Observation: The tool executes the action and feeds the raw results back to the model
#
# ```
# # react prompt
# You are a helpful AI assistant. You have access to the following tools:
#
# {tools}
#
# Use the following format:
#
# Question: the input question you must answer
# Thought: you should always think about what to do next
# Action: the action to take, should be one of [{tool_names}]
# Action Input: the input to the action
# Observation: the result of the action
# ... (this Thought/Action/Action Input/Observation can repeat N times)
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
# Begin!
#
# Question: {input}
# Thought: {agent_scratchpad}
#
# ```
#
# https://smith.langchain.com/hub/hwchase17/react

# %%
# prompt parameters in chatgpt
https://developers.openai.com/api/docs/guides/prompt-engineering

# general prompts 
https://www.promptingguide.ai/techniques/react

# %%
# react example
"Who is Olivia Wilde's boyfriend, and what is his current age raised to the 0.23 power?"

# %% [markdown]
# | Technique          | Uses Examples? | Uses Reasoning?    | Uses External Data? | Uses Tools?        | Best For                   |
# | ------------------ | -------------- | ------------------ | ------------------- | ------------------ | -------------------------- |
# | Zero-shot          | ❌              | ❌                  | ❌                   | ❌                  | Simple tasks               |
# | Few-shot           | ✅              | ❌                  | ❌                   | ❌                  | Classification, formatting |
# | Chain-of-Thought   | ❌              | ✅                  | ❌                   | ❌                  | Math, logic                |
# | Meta Prompting     | ❌              | ❌                  | ❌                   | ❌                  | Prompt creation            |
# | Self-Consistency   | ❌              | ✅ (multiple paths) | ❌                   | ❌                  | Reliable reasoning         |
# | Generate Knowledge | ❌              | ✅                  | Internal knowledge  | ❌                  | Complex QA                 |
# | Prompt Chaining    | Optional       | ✅                  | Optional            | Optional           | Multi-step workflows       |
# | Tree of Thoughts   | ❌              | ✅ (branching)      | ❌                   | ❌                  | Planning, strategy         |
# | RAG                | Optional       | Optional           | ✅                   | Optional           | Enterprise search          |
# | ART                | Optional       | ✅                  | ✅                   | ✅                  | AI agents                  |
# | APE                | Optional       | ❌                  | ❌                   | ❌                  | Prompt optimization        |
# | Active-Prompt      | Optional       | Partial            | ❌                   | Human feedback     | Efficient labeling         |
# | DSP                | Optional       | Guided             | ❌                   | ❌                  | Controlled generation      |
# | PAL                | ❌              | Via code           | ❌                   | ✅ (code execution) | Math, algorithms           |
# | ReAct              | ❌              | ✅                  | ✅                   | ✅                  | Agentic AI                 |
# | Reflexion          | ❌              | Self-evaluation    | Optional            | Optional           | Iterative improvement      |
# | Multimodal CoT     | Optional       | ✅                  | Image/Text          | Optional           | Vision-language tasks      |
# | Graph Prompting    | Optional       | Graph reasoning    | Graph data          | Optional           | Knowledge graphs           |

# %% [markdown]
# # 🔹 Module : Prompt Evaluation & Optimization
#
# ## Module Objective
#
# Measure prompt performance.
#
# ## Topics Covered
#
# * Prompt Testing
# * A/B Testing
# * Evaluation Metrics
# * Hallucination Detection
#
# ### Practical Activities
#
# * Prompt benchmarking
#
# ### Expected Outcome
#
# Reliable prompt systems.

# %%
# https://launchdarkly.com/blog/prompt-engineering-best-practices/

# %% [markdown]
# # 📖 Real-World Hook
#
# ### Scenario
#
# Imagine you're building an **AI Resume Analyzer**.
#
# Two prompts are used:
#
# **Prompt A**
#
# > "Analyze this resume."
#
# **Prompt B**
#
# > "Analyze the resume for a Data Analyst role. Evaluate technical skills, projects, ATS score, missing keywords, strengths, weaknesses, and provide improvement suggestions in bullet points."
#
# Both prompts use the same resume and the same LLM.
#
# Which prompt gives better results?
#
# **Answer:** Prompt B, because it is more specific and structured.
#
# This is why **Prompt Evaluation & Optimization** is essential.
#
# ---
#
# # Why Prompt Evaluation Matters
#
# Without evaluation:
#
# * ❌ Inconsistent responses
# * ❌ Hallucinations
# * ❌ Wrong answers
# * ❌ Poor formatting
# * ❌ Low user satisfaction
#
# With evaluation:
#
# * ✅ Reliable outputs
# * ✅ Better accuracy
# * ✅ Consistent formatting
# * ✅ Improved user trust
# * ✅ Easier maintenance
#
# ---
#
# # Prompt Optimization Workflow
#
# ```text
# Design Prompt
#       │
#       ▼
# Run Test Cases
#       │
#       ▼
# Evaluate Responses
#       │
#       ▼
# Measure Metrics
#       │
#       ▼
# Find Weaknesses
#       │
#       ▼
# Improve Prompt
#       │
#       ▼
# Retest

# %% [markdown]
# ## What is Prompt Testing?
#
# Prompt testing is the process of checking whether a prompt consistently produces the desired output.
#
# Think of it like **unit testing** for prompts.
#
# ---
#
# ## What to Test?
#
# * Accuracy
# * Completeness
# * Format
# * Consistency
# * Safety
# * Speed
# * Cost (tokens)
#
# ```
# prompts = [
#     "Summarize this news article.",
#     "Summarize this research paper."
# ]
#
# for prompt in prompts:
#     response = llm(prompt)
#     print(response)
# ```
#
# ## What is A/B Testing?
#
# Compare two or more prompts to determine which performs better.
#
# # Business Example
#
# Customer Support Bot
#
# ### Version A
#
# > Answer customer questions.
#
# ### Version B
#
# > Answer customer questions politely in less than 100 words. If uncertain, state that you are unsure rather than guessing.
#
# Version B is typically more reliable and safer.
#
# ---
#
# ## Compare
#
# | Metric            | Version A | Version B |
# | ----------------- | -------- | -------- |
# | Accuracy          | ⭐⭐⭐⭐     | ⭐⭐⭐⭐     |
# | Simplicity        | ⭐⭐       | ⭐⭐⭐⭐⭐    |
# | User Satisfaction | ⭐⭐⭐      | ⭐⭐⭐⭐⭐    |
#
# Winner: Prompt B

# %% [markdown]
# # Topic 3: Evaluation Metrics
#
# Evaluation metrics help measure prompt quality objectively.
#
# ---
#
# ## Common Metrics
#
# | Metric       | Meaning                          |
# | ------------ | -------------------------------- |
# | Accuracy     | Correctness of answer            |
# | Precision    | Relevant information only        |
# | Recall       | Covers all important information |
# | Relevance    | Matches the user's question      |
# | Completeness | Includes all required details    |
# | Fluency      | Natural language quality         |
# | Consistency  | Similar inputs → similar outputs |
# | Latency      | Response time                    |
# | Cost         | Token usage                      |
# | Safety       | Harmful content avoidance        |
#
# ---
#
# ## Example Evaluation Table
#
# | Metric       | Score (/10) |
# | ------------ | ----------- |
# | Accuracy     | 9           |
# | Relevance    | 10          |
# | Completeness | 8           |
# | Formatting   | 10          |
# | Safety       | 10          |
# | Speed        | 9           |
#
# Overall Score = 9.3/10
#
# ---
#
# # Human vs Automated Evaluation
#
# | Human Evaluation   | Automated Evaluation |
# | ------------------ | -------------------- |
# | More accurate      | Faster               |
# | Subjective         | Objective            |
# | Expensive          | Low cost             |
# | Better for quality | Better for scale     |
#
# Best practice: Use both.
#
# ---
#
# # Topic 4: Hallucination Detection
#
# ## What is a Hallucination?
#
# A hallucination occurs when an LLM generates information that sounds plausible but is false, fabricated, or unsupported.

# %% [markdown]
# ## Types of Hallucinations
#
# ### 1. Fabricated Facts
#
# Invented people, places, or events.
#
# ### 2. Fake Citations
#
# Invented research papers or references.
#
# ### 3. Fake Code
#
# Code that uses non-existent APIs or libraries.
#
# ### 4. Incorrect Calculations
#
# Math errors due to flawed reasoning.
#
# ---
#
# # How to Detect Hallucinations
#
# ### 1. Fact Checking
#
# Compare answers with trusted sources.
#
# ### 2. RAG
#
# Retrieve verified documents before generating an answer.
#
#
# ### 3. Confidence Prompts
#
# Ask the model to indicate uncertainty.
#
# Example:
#
# ```text
# If you are uncertain, clearly state that instead of guessing.
# ```
#
# ---
#
# ### 4. Self-Verification
#
# Prompt the model to review its own answer.
#
# Example:
#
# ```text
# Answer the question.
# Then verify your answer for factual errors.
# ```
#
# ---
#
# ### 5. Multiple Responses (Self-Consistency)
#
# Generate multiple answers and compare them for agreement.
#
# ---
#
# # Reducing Hallucinations
#
# * Provide clear instructions.
# * Use Retrieval-Augmented Generation (RAG).
# * Add relevant context.
# * Ask for citations when appropriate.
# * Encourage the model to admit uncertainty.
# * Validate outputs against trusted data.

# %% [markdown]
# A great way to teach **Prompt Evaluation & Optimization** is through a **live Python demo**. Students can see how changing the prompt changes the output and then score each prompt.
#
# ---
#
# # Demo 1: Compare Three Prompts (Zero-shot vs Optimized)
#
# ```python
# from google import genai
#
# # Configure your API Key
# client = genai.Client(api_key="YOUR_API_KEY")
#
# article = """
# Artificial Intelligence is transforming healthcare by improving disease diagnosis,
# automating repetitive tasks, and helping doctors make faster decisions.
# """
#
# prompts = {
#     "Prompt A": f"Summarize this article:\n\n{article}",
#
#     "Prompt B": f"""
# Summarize this article in 5 bullet points.
#
# Article:
# {article}
# """,
#
#     "Prompt C": f"""
# You are an AI teacher.
#
# Summarize the following article:
#
# Requirements:
# - Exactly 5 bullet points
# - Beginner friendly
# - Mention benefits
# - End with one conclusion
#
# Article:
# {article}
# """
# }
#
# for name, prompt in prompts.items():
#     response = client.models.generate_content(
#         model="gemini-2.5-flash",
#         contents=prompt
#     )
#
#     print("="*60)
#     print(name)
#     print("="*60)
#     print(response.text)
# ```
#
# ---
#
# # Ask Students
#
# After running the code, ask them to score each prompt.
#
# | Metric       | Prompt A | Prompt B | Prompt C |
# | ------------ | -------- | -------- | -------- |
# | Accuracy     |          |          |          |
# | Readability  |          |          |          |
# | Format       |          |          |          |
# | Completeness |          |          |          |
# | Overall      |          |          |          |
#
# ---
#
# # Demo 2: A/B Testing
#
# ```python
# from google import genai
#
# client = genai.Client(api_key="YOUR_API_KEY")
#
# question = "Explain Machine Learning"
#
# prompt_a = question
#
# prompt_b = """
# Explain Machine Learning
#
# Rules:
# - Beginner friendly
# - Less than 150 words
# - Give one real-life example
# """
#
# response_a = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=prompt_a
# )
#
# response_b = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=prompt_b
# )
#
# print("Prompt A")
# print(response_a.text)
#
# print("\n\nPrompt B")
# print(response_b.text)
# ```
#
# ### Classroom Discussion
#
# Ask students:
#
# * Which answer is easier to understand?
# * Which is better structured?
# * Which would you deploy in a chatbot?
#
# ---
#
# # Demo 3: Hallucination Detection
#
# ```python
# from google import genai
#
# client = genai.Client(api_key="YOUR_API_KEY")
#
# prompt = """
# Who invented Python?
#
# If you are not sure, say:
# 'I am not confident.'
#
# Do not guess.
# """
#
# response = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=prompt
# )
#
# print(response.text)
# ```
#
# ### Next Activity
#
# Change the question to something obscure, such as:
#
# ```text
# Who invented the XYZ Quantum Engine in 1850?
# ```
#
# Then discuss whether the model:
#
# * Admits uncertainty
# * Makes up an answer (hallucinates)
#
# ---
#
# # Demo 4: Prompt Benchmarking
#
# ```python
# from google import genai
# import time
#
# client = genai.Client(api_key="YOUR_API_KEY")
#
# article = """
# Python is one of the most popular programming languages because it is easy to learn,
# has a large ecosystem, and is widely used in AI, data science, web development,
# and automation.
# """
#
# prompts = [
#     "Summarize the article.",
#     "Summarize the article in five bullet points.",
#     """
# Summarize the article.
#
# Rules:
# - Beginner friendly
# - Five bullet points
# - Mention applications
# - End with one conclusion
# """
# ]
#
# for i, prompt in enumerate(prompts, start=1):
#
#     start = time.time()
#
#     response = client.models.generate_content(
#         model="gemini-2.5-flash",
#         contents=prompt + "\n\n" + article
#     )
#
#     end = time.time()
#
#     print("="*60)
#     print(f"Prompt {i}")
#     print("="*60)
#     print(response.text)
#
#     print("\nLatency:", round(end-start,2), "seconds")
#     print("Output Length:", len(response.text))
# ```
#
# ---
#
# # Student Activity
#
# Have students complete this table after each run.
#
# | Prompt | Accuracy (10) | Readability (10) | Completeness (10) | Latency (s) | Winner |
# | ------ | ------------: | ---------------: | ----------------: | ----------: | ------ |
# | A      |               |                  |                   |             |        |
# | B      |               |                  |                   |             |        |
# | C      |               |                  |                   |             |        |
#
# ---

# %%
# Bonus Demo: Automatic Prompt Evaluation
from google import genai

client = genai.Client(api_key="YOUR_API_KEY")

answer = """
Machine Learning is a field of AI that enables computers to learn from data.
"""

evaluation_prompt = f"""
Evaluate the following answer.

Score each metric out of 10:

- Accuracy
- Completeness
- Readability
- Structure

Finally provide:
Overall Score

Answer:
{answer}
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=evaluation_prompt
)

print(response.text)

# %% [markdown]
# ## Industry Tips
#
# * Focus on business outcomes, not just prompts
# * Learn RAG and Agents together
# * Build reusable prompt libraries
# * Track prompt performance
#
# ## Common Mistakes to Avoid
#
# * Vague prompts
# * No output constraints
# * Ignoring context
# * Lack of evaluation
# * No prompt versioning

# %% [markdown]
# # 🔹 Module 9: Prompt Chaining & Workflows
#
# ## Module Objective
#
# Build multi-step AI pipelines.
#
# ## Topics Covered
#
# * Sequential Prompting
# * Prompt Pipelines
# * Workflow Design
#
# ### Practical Activities
#
# * Content creation workflow
#
# ### Expected Outcome
#
# Automated AI workflows.

# %% [markdown]
# # 🔹 Module 9: Prompt Chaining & Workflows
#
# ## 🎯 Module Objective
#
# By the end of this module, students will be able to:
#
# * Understand Prompt Chaining and AI Workflows.
# * Build multi-step AI pipelines.
# * Design reusable prompt workflows.
# * Automate content generation tasks.
# * Create production-ready AI applications using chained prompts.
#
# ---
#
# # 🌍 Real-World Hook
#
# Imagine you are working at a **digital marketing company**.
#
# Your manager says:
#
# > "Write a blog about Artificial Intelligence, then create a LinkedIn post, an Instagram caption, a YouTube title, SEO keywords, and finally an email newsletter."
#
# Doing this manually takes **30–40 minutes**.
#
# With Prompt Chaining, an AI can complete it in **under a minute** by breaking the task into smaller steps.
#
# This is exactly how modern AI tools like Jasper, Notion AI, and many enterprise GenAI applications work.
#
# ---
#
# # What is Prompt Chaining?
#
# Prompt Chaining is the process of connecting multiple prompts where the output of one prompt becomes the input for the next prompt.
#
# Instead of asking the LLM to do everything at once, we break the task into logical steps.
#
# ---
#
# ## Workflow
#
# ```text
# User Input
#      │
#      ▼
# Research Prompt
#      │
#      ▼
# Summary Prompt
#      │
#      ▼
# Blog Prompt
#      │
#      ▼
# LinkedIn Prompt
#      │
#      ▼
# Instagram Prompt
#      │
#      ▼
# Final Output
# ```
#
# ---
#
# # Why Use Prompt Chaining?
#
# Without Prompt Chaining:
#
# ```text
# One Huge Prompt
#         │
#         ▼
# Confusing Output
# ```
#
# With Prompt Chaining:
#
# ```text
# Small Prompt
#       │
#       ▼
# Better Output
#       │
#       ▼
# Next Prompt
#       │
#       ▼
# High Quality Result
# ```
#
# ---
#
# # Topic 1: Sequential Prompting
#
# ## Definition
#
# Sequential prompting means solving a task step by step.
#
# Each prompt depends on the previous response.
#
# ---
#
# ## Example
#
# User asks:
#
# > Explain Machine Learning.
#
# ### Step 1
#
# Generate important concepts.
#
# ↓
#
# ### Step 2
#
# Create a beginner-friendly explanation.
#
# ↓
#
# ### Step 3
#
# Generate examples.
#
# ↓
#
# ### Step 4
#
# Create quiz questions.
#
# ---
#
# ## Python Demo
#
# ```python
# from google import genai
#
# client = genai.Client(api_key="YOUR_API_KEY")
#
# topic = "Machine Learning"
#
# # Step 1
# response1 = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=f"List important concepts about {topic}."
# )
#
# concepts = response1.text
#
# print("Concepts")
# print(concepts)
#
# # Step 2
# response2 = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=f"""
# Using these concepts:
#
# {concepts}
#
# Explain Machine Learning for beginners.
# """
# )
#
# print(response2.text)
# ```
#
# ---
#
# # Topic 2: Prompt Pipelines
#
# A Prompt Pipeline is a sequence of prompts that automate a complete task.
#
# ---
#
# ## Example Pipeline
#
# ```text
# Topic
#    │
#    ▼
# Research
#    │
#    ▼
# Summary
#    │
#    ▼
# Blog
#    │
#    ▼
# SEO Keywords
#    │
#    ▼
# Social Media Posts
# ```
#
# ---
#
# ## Real-World Applications
#
# | Industry   | Prompt Pipeline                               |
# | ---------- | --------------------------------------------- |
# | Marketing  | Research → Blog → LinkedIn → Twitter          |
# | HR         | Resume → ATS Analysis → Interview Questions   |
# | Education  | Topic → Notes → Quiz → Assignment             |
# | Healthcare | Symptoms → Diagnosis Summary → Patient Report |
# | Finance    | Data → Analysis → Report → Presentation       |
#
# ---
#
# # Topic 3: Workflow Design
#
# Workflow design means planning how prompts interact to complete a business process.
#
# ---
#
# ## Example
#
# Customer Support AI
#
# ```text
# Customer Question
#         │
#         ▼
# Intent Detection
#         │
#         ▼
# Knowledge Search
#         │
#         ▼
# Answer Generation
#         │
#         ▼
# Grammar Check
#         │
#         ▼
# Final Response
# ```
#
# ---
#
# ## Workflow Components
#
# * Input
# * Prompt
# * LLM
# * Output
# * Next Prompt
# * Final Result
#
# ---
#
# # Practical Activity: Content Creation Workflow
#
# ## Objective
#
# Automatically generate multiple types of content from one topic.
#
# ---
#
# ### Step 1 – Research
#
# Prompt
#
# ```text
# Research the latest trends in Artificial Intelligence.
# ```
#
# ---
#
# ### Step 2 – Summary
#
# ```text
# Summarize the research in 5 bullet points.
# ```
#
# ---
#
# ### Step 3 – Blog
#
# ```text
# Write a 500-word blog using the summary.
# ```
#
# ---
#
# ### Step 4 – LinkedIn
#
# ```text
# Create a LinkedIn post based on the blog.
# ```
#
# ---
#
# ### Step 5 – Instagram
#
# ```text
# Write a short Instagram caption with hashtags.
# ```
#
# ---
#
# ### Step 6 – Email
#
# ```text
# Write a promotional email introducing the blog.
# ```
#
# ---
#
# # Live Coding Demo (Sequential Workflow)
#
# ```python
# from google import genai
#
# client = genai.Client(api_key="YOUR_API_KEY")
#
# topic = "Artificial Intelligence"
#
# # Step 1: Research
# research = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=f"Provide key facts about {topic}."
# ).text
#
# print("=== Research ===")
# print(research)
#
# # Step 2: Summary
# summary = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=f"Summarize the following into 5 bullet points:\n\n{research}"
# ).text
#
# print("\n=== Summary ===")
# print(summary)
#
# # Step 3: Blog
# blog = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=f"Write a 400-word blog using this summary:\n\n{summary}"
# ).text
#
# print("\n=== Blog ===")
# print(blog)
#
# # Step 4: LinkedIn Post
# linkedin = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=f"Create a professional LinkedIn post from this blog:\n\n{blog}"
# ).text
#
# print("\n=== LinkedIn Post ===")
# print(linkedin)
# ```
#
# ---
#
# # Advanced Demo: Prompt Pipeline Using Functions
#
# ```python
# from google import genai
#
# client = genai.Client(api_key="YOUR_API_KEY")
#
# def ask_llm(prompt):
#     response = client.models.generate_content(
#         model="gemini-2.5-flash",
#         contents=prompt
#     )
#     return response.text
#
# topic = "Generative AI"
#
# research = ask_llm(f"Research {topic}")
# summary = ask_llm(f"Summarize:\n{research}")
# blog = ask_llm(f"Write a blog:\n{summary}")
# quiz = ask_llm(f"Create 5 quiz questions:\n{blog}")
#
# print("Research\n", research)
# print("\nSummary\n", summary)
# print("\nBlog\n", blog)
# print("\nQuiz\n", quiz)
# ```
#
# ---
#
# # Mini Project: AI Course Content Generator
#
# ### Input
#
# ```text
# Topic:
# Python Functions
# ```
#
# ### Workflow
#
# ```text
# Topic
#    │
#    ▼
# Learning Objectives
#    │
#    ▼
# Theory Notes
#    │
#    ▼
# Code Examples
#    │
#    ▼
# Practice Questions
#    │
#    ▼
# Assignment
#    │
#    ▼
# Quiz
# ```
#
# ---
#
# # Best Practices
#
# * Break large tasks into smaller prompts.
# * Reuse outputs from previous steps instead of repeating work.
# * Validate intermediate outputs before passing them to the next step.
# * Keep prompts focused on a single responsibility.
# * Save intermediate results for debugging and reuse.
# * Add error handling and retries in production workflows.
#
# ---
#
# # Practice Exercises
#
# ### Beginner
#
# 1. Create a workflow: Topic → Summary → Quiz.
# 2. Generate a blog, then convert it into a LinkedIn post.
# 3. Build a pipeline that summarizes a news article and creates three social media captions.
#
# ### Intermediate
#
# 1. Build a Resume Analysis pipeline:
#
#    * Resume → ATS Score → Skill Gap → Interview Questions.
# 2. Create a customer support workflow:
#
#    * User Query → Intent Detection → Response Generation.
# 3. Build a code assistant:
#
#    * Problem → Python Solution → Explanation → Test Cases.
#
# ### Advanced
#
# 1. Design an AI content factory:
#
#    * Research → Outline → Blog → SEO Keywords → LinkedIn → Instagram → Email Newsletter.
# 2. Add prompt evaluation after each stage to verify quality before moving to the next step.
# 3. Integrate Retrieval-Augmented Generation (RAG) into the workflow so the model grounds its answers on retrieved documents.
#
# ---
#
# # Expected Outcome
#
# After completing this module, students will be able to:
#
# * Build multi-step prompt chains.
# * Design reusable AI workflows.
# * Automate content creation and business processes.
# * Create sequential prompt pipelines for real-world applications.
# * Understand the foundation for advanced agentic AI frameworks such as LangChain, LlamaIndex, CrewAI, and AutoGen.

# %% [markdown]
# ---
# ---
# # Next Topic RAG(RAG (Retrieval-Augmented Generation))
# ---
# ---

# %% [markdown]
# # 🔹 Module 10: RAG (Retrieval-Augmented Generation)
#
# ## Module Objective
#
# Build AI systems using external knowledge.
#
# ## Topics Covered
#
# * RAG Architecture
# * Embeddings
# * Vector Databases
# * Retrieval Techniques
#
# ### Tools
#
# * LangChain
# * ChromaDB
# * FAISS
#
# ### Practical Activities
#
# * PDF Question Answering System
#
# ### Expected Outcome
#
# Knowledge-grounded AI systems.
#
# ---
#
# # 🔹 Module 11: AI Agents & Agentic Prompting
#
# ## Module Objective
#
# Create autonomous AI systems.
#
# ## Topics Covered
#
# * Agents
# * Agent Workflows
# * Tool Usage
# * Planning Agents
#
# ### Tools
#
# * LangGraph
# * LangChain Agents
# * CrewAI
#
# ### Practical Activities
#
# * Build AI Research Agent
#
# ### Expected Outcome
#
# Autonomous AI assistants.
#
# ---
#
# # 🔹 Module 12: Function Calling & Tool Use
#
# ## Module Objective
#
# Connect LLMs to external systems.
#
# ## Topics Covered
#
# * Function Calling
# * Tool Calling
# * API Integration
#
# ### Practical Activities
#
# * Weather assistant
# * Database assistant
#
# ### Expected Outcome
#
# Real-world AI applications.
#
# ---
#
# # 🔹 Module 13: Prompt Evaluation & Optimization
#
# ## Module Objective
#
# Measure prompt performance.
#
# ## Topics Covered
#
# * Prompt Testing
# * A/B Testing
# * Evaluation Metrics
# * Hallucination Detection
#
# ### Practical Activities
#
# * Prompt benchmarking
#
# ### Expected Outcome
#
# Reliable prompt systems.
#
# ---
#
# # 🔹 Module 14: Multimodal Prompt Engineering
#
# ## Module Objective
#
# Work with text, image, audio, and video AI.
#
# ## Topics Covered
#
# * Image Prompting
# * Video Prompting
# * Audio Prompting
# * Vision-Language Models
#
# ### Tools
#
# * GPT Vision
# * Gemini
# * Claude Vision
#
# ### Practical Activities
#
# * Image analysis
# * Video generation prompts
#
# ### Expected Outcome
#
# Multimodal AI skills.
#
# ---
#
# # 🔹 Module 15: Production-Level GenAI Systems
#
# ## Module Objective
#
# Build scalable AI solutions.
#
# ## Topics Covered
#
# * Prompt Versioning
# * Prompt Management
# * Guardrails
# * Observability
# * Security
#
# ### Practical Activities
#
# * Enterprise chatbot architecture
#
# ### Expected Outcome
#
# Production-ready systems.
#
# ---
#
# # 🔹 Module 16: Enterprise AI Applications
#
# ## Module Objective
#
# Implement AI in business scenarios.
#
# ## Topics Covered
#
# * Customer Support AI
# * HR AI Assistant
# * Finance AI Assistant
# * Healthcare AI Assistant
# * Legal AI Assistant
#
# ### Practical Activities
#
# * Design enterprise solutions
#
# ### Expected Outcome
#
# Industry implementation skills.
#
# ---
#
# # 4. Hands-on Projects
#
# ---
#
# # ✅ Beginner Project: AI Writing Assistant
#
# ### Problem Statement
#
# Create an assistant for emails and content writing.
#
# ### Tools
#
# * ChatGPT
# * Gemini
#
# ### Expected Output
#
# Content generation assistant.
#
# ### Skills Covered
#
# Basic prompting
#
# ---
#
# # ✅ Intermediate Project 1: Resume & Interview Coach
#
# ### Problem Statement
#
# Create AI-based resume reviewer.
#
# ### Tools
#
# * GPT
# * Prompt Templates
#
# ### Expected Output
#
# Resume evaluation reports.
#
# ### Skills Covered
#
# Structured prompting
#
# ---
#
# # ✅ Intermediate Project 2: PDF Question Answering System
#
# ### Problem Statement
#
# Ask questions from uploaded documents.
#
# ### Tools
#
# * LangChain
# * ChromaDB
# * OpenAI
#
# ### Expected Output
#
# Document-based answers.
#
# ### Skills Covered
#
# RAG implementation
#
# ---
#
# # ✅ Advanced Capstone Project: Enterprise Multi-Agent AI Assistant
#
# ### Problem Statement
#
# Build a complete AI assistant capable of research, planning, reasoning, and reporting.
#
# ### Tools
#
# * LangGraph
# * LangChain
# * OpenAI
# * Vector Database
# * FastAPI
# * Docker
#
# ### Expected Output
#
# Production-grade AI platform.
#
# ### Skills Covered
#
# * Prompt Engineering
# * RAG
# * Agentic AI
# * Deployment
# * Evaluation
#
# ---
#
# # 5. Tools & Technologies Covered
#
# ### LLM Platforms
#
# * ChatGPT
# * Claude
# * Gemini
# * Llama
# * Mistral
#
# ### Frameworks
#
# * LangChain
# * LangGraph
# * CrewAI
# * AutoGen
#
# ### Vector Databases
#
# * ChromaDB
# * FAISS
# * Pinecone
# * Weaviate
#
# ### Development Tools
#
# * Python
# * FastAPI
# * Streamlit
# * Docker
# * GitHub
#
# ### Evaluation Tools
#
# * LangSmith
# * Ragas
# * TruLens
#
# ---
#
# # 7. Practice & Assignments
#
# ### Real-World Tasks
#
# * Email automation
# * Content generation
# * Customer support automation
# * Business report generation
#
# ---
#
# # 8. Case Studies
#
# ## Case Study 1: AI Customer Support Assistant
#
# Industry:
# E-Commerce
#
# Application:
# 24/7 automated support
#
# ---
#
# ## Case Study 2: AI Financial Research Assistant
#
# Industry:
# Banking & Finance
#
# Application:
# Investment report generation
#
# ---
#
# ## Case Study 3: Enterprise Knowledge Management System
#
# Industry:
# Corporate
#
# Application:
# Internal AI search engine
#
# ---
#
# # 11. Interview & Career Preparation
#
# ## Key Interview Topics
#
# * Prompt Design Principles
# * Few-Shot Learning
# * Chain-of-Thought
# * RAG
# * Agentic AI
# * Prompt Evaluation
# * Function Calling
# * Multimodal AI
# * LangChain
# * LangGraph
#
#
# ## 10 Sample Interview Questions
#
# 1. What is Prompt Engineering?
# 2. Explain Zero-Shot Prompting.
# 3. What is Few-Shot Learning?
# 4. What is Chain-of-Thought Prompting?
# 5. What is RAG?
# 6. Explain Vector Databases.
# 7. What are AI Agents?
# 8. What is Function Calling?
# 9. How do you evaluate prompts?
# 10. How would you build a production AI assistant?
